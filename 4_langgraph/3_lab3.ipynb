# %% [markdown]
# ## Welcome to Week 4, Day 4
#
# This is the start of an AWESOME project! Really simple and very effective.

# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain.agents import Tool

from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Asynchronous LangGraph
#
# To run a tool:
# Sync: `tool.run(inputs)`
# Async: `await tool.arun(inputs)`
#
# To invoke the graph:
# Sync: `graph.invoke(state)`
# Async: `await graph.ainvoke(state)`

# %%
class State(TypedDict):
    
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

tool_push = Tool(
        name="send_push_notification",
        func=push,
        description="useful for when you want to send a push notification"
    )

# %% [markdown]
# ## Extra installation step - if you don't have Node and Playwright on your computer
#
# Next, you need to install NodeJS and Playwright on your computer if you don't already have them. Please see instructions here:
#
# [Node and Playwright setup](../setup/SETUP-node.md)

# %% [markdown]
# ## And now - after Installing Playwright, a heads up for Windows PC Users:
#
# While executing the next few cells, you might hit a problem with the Playwright browser raising a NotImplementedError.
#
# This should work when we move to python modules, but it can cause problems in Windows in a notebook.
#
# If you it this error and would like to run the notebook, you need to make a small change which seems quite hacky! You need to do this AFTER installing Playwright (prior cells)
#
# 1. Right click in `.venv` in the File Explorer on the left and select "Find in folder"
# 2. Search for `asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())`
# 3. That code should be found in a line of code in a file called `kernelapp.py`
# 4. Comment out the entire else clause that this line is a part of - see the fragment below. Be sure to have the "pass" statement after the ImportError line.
# 5. Restart the kernel by pressing the "Restart" button above
#
# ```python
#         if sys.platform.startswith("win") and sys.version_info >= (3, 8):
#             import asyncio
#
#             try:
#                 from asyncio import WindowsProactorEventLoopPolicy, WindowsSelectorEventLoopPolicy
#             except ImportError:
#                 pass
#                 # not affected
#            # else:
#             #    if type(asyncio.get_event_loop_policy()) is WindowsProactorEventLoopPolicy:
#                     # WindowsProactorEventLoopPolicy is not compatible with tornado 6
#                     # fallback to the pre-3.8 default of Selector
#                     # asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())
# ```
#
# Thank you to student Nicolas for finding this, and to Kalyan, Yaki, Zibin and Bhaskar for confirming that this worked for them! And to Vladislav for the extra pointers.
#
# As an alternative, you can just move to a Python module (which we do anyway in Day 5)

# %%
# Introducing nest_asyncio
# Python async code only allows for one "event loop" processing aynchronous events.
# The `nest_asyncio` library patches this, and is used for special situations, if you need to run a nested event loop.

import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ### The LangChain community
#
# One of the remarkable things about LangChain is the rich community around it.
#
# Check this out:

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser

# If you get a NotImplementedError here or later, see the Heads Up at the top of the notebook

async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()

# %%
for tool in tools:
    print(f"{tool.name}={tool}")
# Out:
# click_element=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/xiangyudong/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# navigate_browser=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/xiangyudong/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# previous_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/xiangyudong/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# extract_text=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/xiangyudong/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# extract_hyperlinks=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/xiangyudong/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# get_elements=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/xiangyudong/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>
# current_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=/Users/xiangyudong/Library/Caches/ms-playwright/chromium-1187/chrome-mac/Chromium.app/Contents/MacOS/Chromium> version=140.0.7339.16>

# %%
tool_dict = {tool.name:tool for tool in tools}

navigate_tool = tool_dict.get("navigate_browser")
extract_text_tool = tool_dict.get("extract_text")

    
await navigate_tool.arun({"url": "https://www.cnn.com"})
text = await extract_text_tool.arun({})

# %%
import textwrap
print(textwrap.fill(text))
# Out:
# Breaking News, Latest News and Videos | CNN CNN values your feedback
# 1. How relevant is this ad to you? 2. Did you encounter any technical
# issues? No Video player was slow to load content Video content never
# loaded Ad froze or did not finish loading Video content did not start
# after ad Audio on ad was too loud Other issues Ad never loaded Ad
# prevented/slowed the page from loading Content moved around while ad
# loaded Ad was repetitive to ads I've seen previously Other issues
# Cancel Submit Thank You! Your effort and contribution in providing
# this feedback is much
# appreciated. Close Ad Feedback Close icon US World Politics Business
# Health Entertainment Underscored Style Travel Sports Science Climate
# Weather Ukraine-Russia War Israel-Hamas War Games Amazon Prime Day
# More US World Politics Business Health Entertainment Underscored Style
# Travel Sports Science Climate Weather Ukraine-Russia War Israel-Hamas
# War Games Amazon Prime Day Watch Listen Subscribe Sign in My Account
# Settings Newsletters Topics you follow Sign out Your CNN account Sign
# in to your CNN account Sign in My Account Settings Newsletters Topics
# you follow Sign out Your CNN account Sign in to your CNN account
# Listen Watch Edition US International Arabic Español Edition US
# International Arabic Español US Crime & Justice Immigration Education
# Transportation Race & Identity World Africa Americas Asia Australia
# China Europe India Middle East United Kingdom Politics Trump Facts
# First CNN Polls 2026 Elections Redistricting Tracker Epstein Files
# Business Tech Media Calculators Videos Markets Pre-markets After-Hours
# Fear & Greed Investing Markets Now Nightcap Health Life, But Better
# Fitness Food Sleep Mindfulness Relationships CNN Underscored
# Electronics Fashion Beauty Health & Fitness Home Reviews Deals Gifts
# Travel Outdoors Pets Entertainment Movies Television Celebrity Tech
# Innovate Style Arts Design Fashion Architecture Luxury Beauty Video
# Travel Destinations Food & Drink Stay Videos Sports Pro Football
# College Football Basketball Baseball Soccer Olympics Science Space
# Life Unearthed Climate Solutions Weather Weather Video Climate
# Ukraine-Russia War Israel-Hamas War Watch Featured Shows & Films
# Network TV Clips CNN Headlines CNN Shorts Shows A-Z CNN 10 CNN TV
# Schedules Listen CNN 5 Things Chasing Life with Dr. Sanjay Gupta The
# Assignment with Audie Cornish One Thing Tug of War CNN Political
# Briefing The Axe Files All There Is with Anderson Cooper All CNN Audio
# podcasts Games Daily Crossword Jumble Crossword Photo Shuffle
# Sudoblock Sudoku 5 Things Quiz Amazon Prime Day About CNN Subscribe
# Photos Investigations CNN Profiles CNN Leadership CNN Newsletters Work
# for CNN Follow CNN Download the CNN App Download the CNN App Live
# Updates 1 hr ago War in Iran Tiger Woods Kash Patel Savannah Guthrie
# ‘No Kings’ rallies Elite Eight Fire weather Underscored Best Amazon
# Spring Sale deals • Breaking News • Breaking News Jason Oteri/AP
# Breaking News by Jacob Lev Tiger Woods in jail after being arrested on
# suspicion of DUI following car crash in Florida Mike
# Blake/Reuters/File Iran-linked hackers have breached FBI Director Kash
# Patel’s personal emails • Analysis Will Oliver/EPA/Bloomberg/Getty
# Images Analysis by Nick Paton Walsh Ignore the bombast — the Iran war
# is only likely to end one way • Live Updates Majid Saeedi/Getty Images
# Live Updates by multiple CNN reporters a min ago Rubio says US can
# achieve its goals without ground troops Angela Weiss/AFP/Getty Images
# Dow closes in correction as war with Iran roils markets House GOP
# rejects Senate-approved DHS bill, likely extending shutdown Show all •
# Live Updates • Live Updates Leah Millis/Reuters Live Updates by
# multiple CNN reporters a min ago Speaker Mike Johnson derided the
# Senate plan as ‘a joke’ and said the House will advance its own bill
# Evelyn Hockstein/Reuters Trump has ordered TSA workers be paid,
# regardless of what Congress does. Here’s what we know • Video 3:21
# Michael Wyke/AP Video by Matthew Lally Congress ‘should have done
# this’: TSA officer speaks out 3:21 Annabelle Gordon/AFP/Getty Images
# Skipped meals, eviction notices and repo’d cars: TSA workers
# desperately await checks after Trump and Senate push for funding
# Alyssa Pointer/Reuters What to know about TSA PreCheck and Clear
# during the DHS shutdown CNN Headlines • Source: CNN Catch up on
# today’s headlines March Madness Bob Donnan/Imagn Images/Reuters The
# Final Four is in sight as the men’s and women’s NCAA tournament nears
# Elite Eight. Here’s what to watch today • Streaming Now CNN Streaming
# Now Having your bracket busted actually brings us together Mission to
# the moon Joe Raedle/Getty Images What to know about the 4 people
# launching to make history around the moon Streaming Now CNN Anthony
# Bourdain toured Japan’s food markets and spoke with a former geisha
# CNN How America’s pastime became a Japanese tradition Mar 27, 2026 CNN
# The growing influence of Christian nationalism in American society Mar
# 23, 2026 CNN Our obsession with touchscreens is out of hand Mar 27,
# 2026 CNN Live Watch CNN Jan 21, 2026 More Top Stories • Live Saul
# Loeb/AFP/Getty Images Live Trump delivers remarks at Future Investment
# Initiative • For Subscribers AP/Imagn/Getty Images For Subscribers by
# Joan Biskupic Supreme Court justices will consider the future of
# birthright citizenship. Here’s how their families came to America
# Selçuk Acar/Anadolu/Getty Images/File New York City passes buffer
# zones limiting protests at schools and houses of worship Andrew
# Harnik/Getty Images Florida Democrat found guilty of House ethics
# violations • For Subscribers Scott Olson/Getty Images For Subscribers
# by multiple CNN reporters ICE deportations are funneling Ukrainian men
# of fighting age from US to front line • Video 0:59 Getty Images Video
# by Robbie Hawken Trump’s signature to appear on dollar bills 0:59 West
# Bank • Video 5:03 CNN Video After latest Israeli settler attack, IDF
# soldiers detain CNN crew 5:03 The disappearance of Nancy Guthrie
# NBC/Reuters Savannah Guthrie to return to ‘Today’ on April 6 as ‘part
# of my purpose’ in search for her mom • Video 3:07 "Today"/NBC Video
# Savannah Guthrie on return to ‘Today’ show 3:07 Ad Feedback Ad
# Feedback CNN Underscored Ellen McAlpine/CNN Underscored 25 products
# under $25 that have quietly improved our editors’ lives Mar 26, 2026
# Gareen Puglia/CNN Underscored Columbia fleece jackets, hiking boots
# and jackets are up to 60% off Mar 27, 2026 Rikka Altland/CNN
# Underscored From Anker to Dyson, these are the best spring Prime Day
# deals that won our editors over Mar 26, 2026 Ad Feedback Check these
# out Wildwood Trust/PA UK wildlife park euthanizes entire wolf pack
# after they turned on each other • Video 0:58 WKRC Video Farmers say
# they turned down $26 million offer from AI company 0:58 Mario
# Anzuoni/Reuters Zendaya’s premiere gowns serve something old, new,
# borrowed (and next, blue?) Stephen Lovekin/Shutterstock Taylor Lautner
# and wife (also Taylor) are expecting their first child Richard
# Harbaugh/Bill Barnes/The Academy/Getty Images The Oscars are leaving
# Hollywood Celebrities • Video 0:33 Christopher
# Polk/Billboard/Billboard via Getty Images Video by Ivana Scatola
# Taylor Swift brings Travis Kelce to iHeartRadio Music Awards 0:33 It's
# the weekend • Quiz Getty Images/AP/Reuters Quiz 8.2% of readers who
# took this week’s news quiz got a perfect score. How will you do? •
# Gallery Douglas Magno/AFP/Getty Images Gallery The week in 38 photos
# Ad Feedback For Subscribers • For Subscribers • For Subscribers CNN
# For Subscribers Mines, missiles and miles of coastline: Why Iran has
# the upper hand in the Strait of Hormuz Kim Shiflett/NASA Inside NASA’s
# nerve center ahead of its biggest mission in decades Douyin The
# internet loves this band of lost dogs journeying home. Too bad the
# story is fake • For Subscribers Antranik Tavitian/Getty Images For
# Subscribers ICE agents have been deployed to airports. Are the polls
# next? Ad Feedback CNN Underscored Amazon Spring Prime Day Rikka
# Altland/CNN Underscored Amazon’s Big Spring sale is here. We found the
# best deals from tech to beauty Rikka Altland/CNN Underscored The
# newest MacBooks and iPads just went on sale for the first time Molly
# Flores/CNN Underscored Amazon’s spring Prime Day takes up to 65% off
# dresses, sandals and more Molly Flores/CNN Underscored Restock your
# kitchen and prep for warm weather with these 20 Amazon Spring Prime
# Day deals Sophie Shaw/CNN Underscored Dozens of editor-loved Medicube
# beauty deals are live during Amazon’s Big Spring Sale Expert-Backed
# Guides Maxwell Shukuya/CNN Underscored A travel backpack is a must for
# hassle-free getaways. Here are the best ones Henry T. Casey/CNN
# Underscored Our latest favorite budget laptop is unlike any we’ve ever
# seen Gareen Puglia/CNN Underscored An emergency radio is a must in
# your home. So we found the best ones out there Molly Flores/CNN
# Underscored We tested all kinds of root touch-up sprays to hide grays
# and growth. Only 2 high-coverage products wowed us Gareen Puglia/CNN
# Underscored Contain your car’s chaos with a trunk organizer. Here are
# the 11 best ones to shop Editors' picks Joe Bloss/CNN Underscored The
# best car vacuum in 2026, tried and tested Mark Amadio/CNN Underscored
# If pulling weeds is your least favorite chore, this $30 tool makes it
# fun Kai Burkhardt/CNN Underscored Patagonia’s refreshed Nano Puff
# Jacket now on sale for the first time at 40% off Henry T. Casey/CNN
# Underscored A good surround sound system is just as crucial as your
# TV. Here are the best Alberto Riva/CNN Underscored How I use the Chase
# credit card trifecta to earn a lot of travel rewards CNN Sports
# Gonzalo Fuentes/Reuters Choi Ga-on’s incredible journey from fractured
# back to broken bones and Olympic gold • Analysis Dylan Buell/Getty
# Images Analysis LSU basketball gets back with its ex. It’s as messy as
# it sounds • Video 1:52 CNN Video Bob Costas reacts to IOC ban: ‘Common
# sense is not transphobic’ 1:52 Bleacher Report Show all Panic meter
# for NFL QB siutations New NBA power rankings with two weeks left WWE
# legend wins six-hour-long race World Series champ retires after 16
# seasons Damar Hamlin back for another season Ad Feedback Politics
# Kevin Dietsch/Getty Images/File Agent on Jill Biden’s Secret Service
# detail accidentally shot himself in the leg, official says Elijah
# Nouvelage/Bloomberg/Getty Images Trump Justice Department’s probe of
# the 2020 election gets first public test in court Shelby
# Tauber/Bloomberg/Getty Images Iran war divides conservatives on and
# off stage at CPAC US David Dee Delgado/Reuters NYPD and FBI say they
# disrupted a plot to firebomb the home of a Palestinian activist in New
# York James Carbone/Pool/Getty Images/File Man accused in Gilgo Beach
# serial killings is expected to plead guilty, sources say • Analysis
# Eric Thayer/Los Angeles Times/Getty Images Analysis California’s good
# government dream has a nightmare flaw for state Democrats Business
# Kena Betancur/Bloomberg/Getty Images Even wealthy Americans are
# souring on the economy as gas prices spike and stocks fall Noah
# Berger/Amazon Web Services/Reuters Amazon’s big bet in AI has been 20
# years in the making Mario Tama/Getty Images Why $4 gas won’t spark an
# EV buying spree CNN Shorts • Video 0:31 WPEC Video Tiger Woods
# arrested on suspicion of DUI in Florida after car crash 0:31 • Video
# 1:09 Pool Video Johnson rejects Senate-passed DHS bill and calls it ‘a
# joke’ 1:09 • Video 0:53 CNN Video 3 hour wait at Baltimore airport
# 0:53 • Video 1:06 Getty Images Video Iran-linked hackers breached FBI
# Director Kash Patel’s personal emails 1:06 • Video 1:15 Sea Shepherd
# Deutschland via Reuters Video Stranded whale freed from sandbank 1:15
# • Video 2:01 WANA Video Iranians split over war’s endgame 2:01 • Video
# 0:31 Getty Images Video Tiger Woods involved in rollover car crash per
# local report 0:31 • Video 1:29 Kim Kelaita Video Leaving Dubai after
# calling it home for 30 years 1:29 • Video 1:03 Getty Images Video MLB
# star sues parents for $3M 1:03 • Video 0:53 John Rodriguez Video
# Honduran national faces murder charge after subway pushing incident
# 0:53 • Video 0:44 Reuters Video Study: Sharks test positive for
# cocaine 0:44 • Video 0:43 CNN Video Houston passengers arriving 7-8
# hours ahead of flights 0:43 • Video 1:03 Reuters Video Rubio attends
# G7 as Trump criticizes allies 1:03 • Video 0:39 CNN Video Overflow
# lines at Atlanta airport die down 0:39 • Video 1:52 CNN Video Bob
# Costas reacts to IOC ban: ‘Common sense is not transphobic’ 1:52 •
# Video 1:19 "Today"/NBC Video Savannah Guthrie is returning to ‘Today’
# show 1:19 • Video 0:58 WKRC Video Farmers say they turned down $26m
# offer from AI company 0:58 • Video 0:36 Belarus pool Video North Korea
# and Belarus sign ‘friendship’ deal 0:36 • Video 0:50 Senate TV, CNN
# Video Senate votes to fund most of DHS 0:50 • Video 0:24 Iranian Red
# Crescent Society Video Deadly strikes hit northern Iran, state media
# report 0:24 • Video 0:34 TV Asahi Video Woman fatally stabbed by her
# stalker in a Tokyo Pokémon store 0:34 • Video 0:33 Christopher
# Polk/Billboard/Billboard via Getty Images Video Taylor Swift brings
# Travis Kelce to iHeartRadio Music Awards 0:33 • Video 1:20 CNN Video
# She didn’t know her husband was sexually abusing her 1:20 • Video 0:59
# Getty Images Video Trump’s signature to appear on dollar bills 0:59 •
# Video 1:34 Getty Images Video Meet the high school senior who won
# Olympic gold 1:34 Weather and climate Ted Soqui/Sipa USA/AP Fire
# season fears grow amid western heat wave Sean Gallup/Getty Images
# Arctic sea ice just dropped to an alarming new low Loughborough
# University Solar-powered micro electric tractors bring light to
# farmers in Malawi World Paola Chiomante/Reuters/File Mexico launches
# search for missing sailboats carrying aid to Cuba AbogadosCris/X She
# spent 20 months battling to die under a euthanasia law. Spain let her
# Metropolitan Police/PA Russian man jailed in London for assault on
# woman witnessed on video call by Barron Trump Tech Patrick Sison/AP
# Judge blocks Pentagon’s effort to ‘punish’ Anthropic by labeling it a
# supply chain risk • Analysis William Liang/AP Analysis How Meta and
# YouTube’s loss in landmark case could change social media forever •
# Streaming Now CNN Streaming Now We’re begging for more knobs and
# buttons TV and movies Justin Ide/Boston Herald/Hulton Archive/Getty
# Images For journalists who covered JFK Jr.’s fatal plane crash, the
# memories are much more vivid than ‘Love Story’ Evan
# Agostini/Invision/AP Bill Maher to receive Mark Twain Prize at Kennedy
# Center after White House denied reports Michael Buckner/Variety/Getty
# Images Stephen Colbert to write next ‘Lord of the Rings’ movie after
# leaving late night Wellness • Analysis • Analysis Jatuporn
# Tansirimas/iStockphoto/Getty Images Analysis by Kara Alaimo After two
# jury verdicts against social media companies, it’s time to reexamine
# your kids’ tech use Jen Christensen/CNN When it comes to aging well,
# attitude is everything • Video 0:54 CNN Video by Aria Chen Why is hay
# fever so bad in Japan? 0:54 DragonImages/iStockphoto/Getty Images The
# amount of mom-shaming is ‘incredible,’ ‘One Bad Mother’ author says
# Travel Henry Nicholls/AFP/Getty Images Why Britain’s miserable weather
# is one of its greatest tourist attractions Alberto
# Pezzali/NurPhoto/Getty Images She transformed Paris for tourists — and
# divided the city • Video 0:44 United Video United is offering a new
# way of traveling. The reactions are mixed 0:44 Science and Discovery
# CERN World’s most expensive substance transported for the very first
# time Roger Norman/Alamy Stock Photo Scientists reveal earliest
# evidence for shifting of Earth’s crust Courtesy of JOOPITER Deep in a
# Singapore vault, a 66-million-year-old Triceratops awaits auction Art
# and style • Video 6:38 CNN Video A new exhibition celebrates the power
# of dressing like no one else 6:38 Part of a work by Botto, an AI
# artist, created during the Art Basel fair in Hong Kong this week.
# Botto This artist has made millions of dollars. And it’s not even
# human Shutterstock Jim Carrey, Leonardo DiCaprio and how the double
# standard of male aging may be over Your money Grace Cary/Moment
# RF/Getty Images Claiming new tax breaks for tips, overtime, seniors or
# car loan interest? Mind the fine print Kseniya Ovchinnikova/Moment
# RF/Getty Images 7 ways to protect your money from potentially higher
# inflation and unemployment Jaime Grajales Benjumea/iStockphoto/Getty
# Images Managing your money when geopolitical risk and volatility are
# high Paid Content More from CNN Most-read this week Emily Gregory
# Campaign Democrat Emily Gregory flips deep-red Florida House district
# that includes Mar-a-Lago Timothy A. Clary/AFP/Getty Images Fire truck
# in LaGuardia runway collision had no transponder, limiting tower’s
# ability to track it, NTSB says • For Subscribers Anna Moneymaker/Getty
# Images For Subscribers Staff revolts, secret meetings: Inside the
# tense fight between Mike Pence and the Heritage Foundation Food and
# drink Soeren Bidstrup/Ritzau Scanpix Denmark/Handout/Reuters The dark
# side of fine dining is getting harder to ignore Ezra Acayan/Getty
# Images Ube is enjoying a purple reign in the US. That’s causing
# problems in the Philippines • Video 3:04 CNN Video One of the UK’s
# buzziest restaurants is opening in the US 3:04 Ad Feedback Paid
# Partner Content CNN Games + Quizzes • Sudoku CNN Sudoku A cross-number
# crossword that will challenge your brain • Sudoblock CNN Sudoblock
# Sudoku + Blocks = addictive tile-matching puzzle • Today's crossword
# CNN Today's crossword No pencil or eraser required • Jumble Crossword
# CNN Jumble Crossword Test your smarts with this scrambled word game In
# case you missed it Piroschka Van De Wouw/Reuters Archaeologist may
# have uncovered the remains of D’Artagnan Lucas Jackson/Reuters/File
# Epstein files shed new light on what prison officials were doing the
# night he died Mar 26, 2026 Courtesy Marla Waldman More than 50 years
# after their mother’s murder, perseverance leads family to her killer
# Mar 26, 2026 David J. Phillip/AP Houston’s Bush Airport has had some
# of the worst TSA wait times. Here’s why Mar 25, 2026 From NBC Savannah
# Guthrie wonders if her fame is to blame for mother’s disappearance Mar
# 26, 2026 Aidan Monaghan/HBO The first ‘Harry Potter’ trailer has
# dropped. Here’s what we’ve learned from it Mar 26, 2026 Subscribe Sign
# in My Account Settings Newsletters Topics you follow Sign out Your CNN
# account Sign in to your CNN account Listen Watch US Crime & Justice
# Immigration Education Transportation Race & Identity World Africa
# Americas Asia Australia China Europe India Middle East United Kingdom
# Politics Trump Facts First CNN Polls 2026 Elections Redistricting
# Tracker Epstein Files Business Tech Media Calculators Videos Markets
# Pre-markets After-Hours Fear & Greed Investing Markets Now Nightcap
# Health Life, But Better Fitness Food Sleep Mindfulness Relationships
# CNN Underscored Electronics Fashion Beauty Health & Fitness Home
# Reviews Deals Gifts Travel Outdoors Pets Entertainment Movies
# Television Celebrity Tech Innovate Style Arts Design Fashion
# Architecture Luxury Beauty Video Travel Destinations Food & Drink Stay
# News Videos Sports Pro Football College Football Basketball Baseball
# Soccer Olympics Science Space Life Unearthed Climate Solutions Weather
# Weather Video Climate Ukraine-Russia War Israel-Hamas War Watch
# Featured Shows & Films Network TV Clips CNN Headlines CNN Shorts Shows
# A-Z CNN 10 CNN TV Schedules Listen CNN 5 Things Chasing Life with Dr.
# Sanjay Gupta The Assignment with Audie Cornish One Thing Tug of War
# CNN Political Briefing The Axe Files All There Is with Anderson Cooper
# All CNN Audio podcasts Games Daily Crossword Jumble Crossword Photo
# Shuffle Sudoblock Sudoku 5 Things Quiz Amazon Prime Day About CNN
# Subscribe Photos Investigations CNN Profiles CNN Leadership CNN
# Newsletters Work for CNN Watch Listen Subscribe Sign in My Account
# Settings Newsletters Topics you follow Sign out Your CNN account Sign
# in to your CNN account Follow CNN Download the CNN app Download the
# CNN app Terms of Use Privacy Policy Manage Cookies Ad Choices
# Accessibility & CC About Subscribe Newsletters Transcripts Help Center
# © 2026 Cable News Network. A Warner Bros. Discovery Company. All
# Rights Reserved. CNN Sans ™ & © 2016 Cable News Network. Download the
# CNN app Scan the QR code to download the CNN app on Google Play.
# Download the CNN app Scan the QR code to download the CNN app from the
# Apple Store. Legal Terms and Privacy By clicking Agree, you have read
# and agree to the Terms of Use and agree to the collection and use of
# your information by cookies and similar technologies, as set forth in
# our Privacy Policy. By clicking "Agree", you have read and agree to
# the Terms of Use and agree to the collection and use of your
# information by cookies and similar technologies, as set forth in our
# Privacy Policy . Agree Privacy Policy For privacy options, please see
# our privacy policy: https://www.cnn.com/privacy . Back Button Cookie
# List Search Icon Filter Icon Clear checkbox label label Apply Cancel
# Consent Leg.Interest checkbox label label checkbox label label
# checkbox label label Close

# %%
all_tools = tools + [tool_push]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(all_tools)


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

# %%
graph_builder = StateGraph(State)
graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=all_tools))
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "10"}}

async def chat(user_input: str, history):
    result = await graph.ainvoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

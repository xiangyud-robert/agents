# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are the chief policy planner for a sovereign island nation of 200,000 people whose low-lying capital and 40% of its arable land will be annually flooded beginning in approximately 20 years due to sea-level rise; the economy currently relies on tourism and small-scale fishing, the national budget is limited (GDP $1.5B, emergency reserves cover ~3 years of current spending), neighboring states have publicly refused to accept mass migration, and international aid is politically uncertain. Develop a prioritized, actionable 20‑year strategy that addresses (a) equitable human relocation and housing, (b) economic transition and livelihood preservation, (c) legal/political status and rights for displaced citizens (including options for retaining statehood), (d) cultural heritage preservation, and (e) environmental mitigation/adaptation; for each element provide concrete steps with timelines, rough cost estimates or percentage allocations of the national budget and likely external funding sources, measurable success metrics, key risks and failure modes, contingency triggers that change priorities, and a transparent account of assumptions and uncertainties—then compare two alternative high‑level approaches (one centered on in‑place adaptation and one centered on planned retreat/relocation), evaluate their ethical trade‑offs (including intergenerational justice and rights of vulnerable groups), and conclude with the single best policy recommendation and why it is robust across optimistic and pessimistic climate and geopolitical scenarios.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Executive summary
# - Context: A small, low-lying island nation of 200,000 people faces annual flooding of its capital and 40% of arable land within ~20 years due to sea-level rise. The economy depends on tourism and small-scale fishing. GDP is about $1.5B. Emergency reserves cover roughly three years of current spending. Neighbors won’t accept mass migrants; external aid is uncertain.
# - Core objective: A 20-year, prioritized strategy that protects people, preserves livelihoods, safeguards rights and statehood, preserves cultural heritage, and builds resilient environment and economy. The plan emphasizes equity, transparency, and adaptive management.
# - Overall cost/financing sketch: Total program cost in the 20-year horizon is roughly $2.8–3.5B (order of magnitude). Domestic budget allocations will cover a substantial but minority share (roughly 30–40% of the total), with the remainder funded by external sources (grants, concessional loans, climate finance, diaspora investments, and blended finance). Annual domestic allocations will ramp from ~3–7% of GDP early on to ~5–8% later, depending on revenue and debt capacity.
# - Recommendation (single best policy): A hybrid “managed retreat with targeted in-situ adaptation” approach. Protect critical, high-value assets and services in the near term (in-situ adaptation), while planning and executing a staged, rights-based relocation of populations and activities away from the highest-risk zones. This approach minimizes exposure to catastrophic loss, maintains statehood, preserves culture, and remains robust across optimistic and pessimistic climate and geopolitical scenarios.
#
# Section 1. Guiding principles and assumptions
# - Principles
#   - Equity and human rights: prioritize the most vulnerable (elderly, disabled, women-headed households, low-income groups), ensure fair housing, tenure security, social protection, and access to essential services.
#   - Rights and statehood: ensure citizenship, voting rights, access to services, and a credible path to retain or adapt the sovereign status while meeting international human rights obligations.
#   - Cultural preservation: protect heritage, sustain identity, and maintain intergenerational ties to land and community.
#   - Environmental integrity: maximize nature-based solutions where feasible; diversify livelihoods; reduce exposure to climate shocks.
#   - Adaptive governance: phased milestones with review points, transparent reporting, and contingency triggers.
# - Core uncertainties
#   - Rate and pattern of sea-level rise; frequency of extreme events.
#   - Pace and location of migration (internal and external).
#   - Availability and terms of external climate funding.
#   - Economic shifts (tourism demand, fishery sustainability, alternative livelihoods).
#   - Technical feasibility and cost of large-scale in-situ defenses or new-town development.
# - High-level risk categories
#   - Finance (underfunding or aid volatility)
#   - Governance (coordination failures, public trust)
#   - Social (inequitable displacement, social tension)
#   - Environmental (unintended ecological impacts)
#   - Legal/political (constitutional compatibility, rights protections)
#
# Section 2. The 20-year strategy: five elements (a–e)
#
# A. Equitable human relocation and housing
# Objective: Relocate populations and create safe, affordable housing and livelihoods for those at highest risk, while safeguarding family stability, social cohesion, and access to services.
#
# Timeline and concrete steps
# - Years 0–5 (Phase 1)
#   - Establish a National Relocation Authority (NRA) with independent civil-society and territorial representation.
#   - Do a comprehensive risk/household survey to map who is most exposed and who has the least options to stay.
#   - Adopt a rights-centered relocation framework (tenure security, compensation norms, return/participation rights).
#   - Identify 3–5 higher-ground or inland locations for planned settlements; initiate land acquisition, environmental permitting, and master-planning for 2–3 new towns proximal to existing urban networks.
#   - Begin construction of 5,000–8,000 new housing units (modular, climate-resilient, affordable) for early relocations; pilot climate-proofed community facilities (schools, clinics, markets).
#   - Launch social protection and income-support programs (universal social protection floor, stipend for vulnerable groups) tied to relocation progress.
# - Years 6–10 (Phase 2)
#   - Scale housing to 15,000–25,000 units total across new towns and elevated districts; expand job-creating amenities (retail, logistics, healthcare).
#   - Establish relocation grants tied to livelihoods (microenterprise start-up grants, land-based livelihoods training, skilled trades).
#   - Create secure land tenure and property rights in new locations; ensure portability of citizenship status and access to services.
# - Years 11–20 (Phase 3)
#   - Complete staged relocation to a broad, resilient settlement system while maintaining a core, protected urban hub (critical services and economic functions remain accessible on elevated or protected cores).
#   - Optimize and retrofit existing settlements for eventual transition if flood risk recedes or shifts (flexible zoning, phased return options if conditions allow).
#   - Maintain a continuous housing-supply pipeline and disaster-resilient public infrastructure.
#
# Budget and funding
# - Domestic budget: allocate roughly 5–7% of GDP per year during Years 0–10 (roughly $75–105M annually, using a 1.5B GDP baseline), tapering to 3–5% in later years as absorption capacity increases.
# - External funding: target 55–70% of the total relocation/housing cost through grants, concessional loans, and climate finance; engage diaspora investment and private sector partnerships for land development and housing pipelines.
# - Rough cost envelope (order-of-magnitude, 20 years): $1.2–1.8B domestic, $1.0–2.3B external; total program ~ $2.2–3.5B.
# - Measurable success metrics
#   - Number of people relocated to safe zones; share of high-risk population covered.
#   - Number and quality of new housing units delivered; tenure security (lease/purchase rights).
#   - Access to services: people within 30 minutes of essential services; unemployment/employment rates in relocated areas.
#   - Displacement-adjusted poverty rates; social protection coverage.
#
# Risks and failure modes
# - Non-acceptance by communities; migration bottlenecks; price and land-availability constraints.
# - Inadequate or delayed funding; misallocation; governance fragmentation.
# - Social inequities in relocation (e.g., urban-rural divides, marginalized groups).
# - Contingency triggers
#   - If relocation progress stalls below target milestones for two consecutive six-month periods, trigger a management reset: accelerate targeted grants, reallocate funding, intensify community engagement.
#   - If land acquisition costs exceed projections by >25%, adjust site selection and financing mix; explore intergovernmental support and public-private partnerships.
# - Assumptions and uncertainties
#   - Assumes secure land for new settlements; assumes political will and predictable aid flows; assumes adequate domestic revenue.
#
# B. Economic transition and livelihood preservation
# Objective: diversify the economy beyond tourism and small-scale fishing; protect livelihoods during relocation; invest in resilient industries and skills.
#
# Timeline and concrete steps
# - Years 0–5
#   - Define a Climate-Resilient Economic Plan (CREP) with sectors: sustainable tourism (eco/experiential), green energy, aquaculture with sustainable practices, digital services, logistics/port efficiency, and climate-resilient agriculture.
#   - Invest in workforce development: climate-smart agriculture, marine stewardship, hospitality training, and digital/computational skills.
#   - Create a small business resilience fund and access to concessional credit for relocation-related businesses.
# - Years 6–10
#   - Expand green energy capacity (solar, small-scale wind, storage) to reduce exposure to fossil fuel volatility; develop cross-island energy resilience.
#   - Promote export-oriented, value-added seafood processing, agro-processing, and eco-tourism services.
#   - Build climate-resilient supply chains and infrastructure (cold chain for fisheries, logistics hubs).
# - Years 11–20
#   - Scale new industries; promote innovation hubs and partnerships with regional and international research institutions to accelerate adaptation technologies.
#   - Strengthen regional integration; explore niche markets (ecotourism, immersive cultural experiences).
#
# Budget and funding
# - Domestic budget: 2–4% of GDP annually, rising to 4–6% during mid-period as new industries scale.
# - External funding: concessional loans and grants for sector-specific investments; potential private sector co-investments in eco-tourism, aquaculture, and logistics.
# - Rough cost envelope: $0.7–1.6B domestic; $0.8–1.8B external; total $1.5–3.4B over 20 years.
# - Measurable success metrics
#   - Diversification indicators: share of GDP from non-tourism sectors; employment mix by sector.
#   - Job creation rates; youth unemployment declines; SME survival.
#   - Energy mix: share of renewables; grid reliability metrics.
#   - Export growth in value-added products.
# - Risks and failure modes
#   - Tourism demand volatility; global crises; disease outbreaks affecting fisheries; over-reliance on any single sector.
#   - Financing gaps or cost overruns.
# - Contingency triggers
#   - If unemployment remains above baseline for two consecutive years, expand targeted retraining and microfinance programs; boost public procurement for local goods.
#   - If export demand declines globally, accelerate domestic market development and diversify sectors.
# - Assumptions and uncertainties
#   - Assumes consistent global demand for eco-tourism and sustainable seafood; assumes ability to attract technology transfer and investments.
#
# C. Legal/political status and rights for displaced citizens (including options for retaining statehood)
# Objective: Provide legal clarity and rights for displaced citizens, ensure continuity of state functions, and maintain or adapt statehood legitimacy.
#
# Timeline and concrete steps
# - Years 0–5
#   - Enshrine a climate-displacement rights framework, including: citizenship protections, family unity provisions, access to social services, and voting rights protections for relocated populations.
#   - Clarify legal status for displaced residents: temporary protections, long-term residency options, and paths to naturalization with rights matching residents’ circumstances.
#   - Begin constitutional and legal reforms to recognize climate displacement as a material factor in governance, with the option to adjust territorial sovereignty arrangements if needed (without undermining statehood).
# - Years 6–10
#   - Implement a “right to safe housing and livelihoods” baseline across relocated communities; ensure universal access to healthcare, education, and social protection.
#   - Establish a formal mechanism for return or re-claiming homeland rights if conditions allow, with sustainable criteria for return.
# - Years 11–20
#   - Stabilize legal frameworks around citizenship, voting rights, and representation for relocated residents, considering diaspora representation if necessary.
#   - If needed, explore constitutional amendments or interim special arrangements to preserve continuous statehood while ensuring inclusive governance.
#
# Budget and funding
# - Domestic: moderate legal-audit costs; implementation of rights-based programs within existing budgets; minimal new cost but some administrative overhead.
# - External: potential support from multilateral bodies for governance reform and rights protection; technical assistance grants.
#
# Measurable success metrics
# - Proportion of relocated residents with secure housing tenure and access to services.
# - Legal and administrative processing times for residency, citizenship, and rights protections.
# - Representation and participation metrics for relocated populations (voting access, local governance participation).
#
# Risks and failure modes
# - Political resistance to constitutional changes; disputes over sovereignty and relocation rights; risk of statelessness if not managed properly.
# - Contingency triggers
#   - If legal protections are delayed beyond Year 5, appoint an independent rights oversight body to accelerate implementation; provide temporary protections with sunset clauses.
# - Assumptions and uncertainties
#   - Assumes political will to reform and adapt the constitution; assumes international legal norms support rights protections.
#
# D. Cultural heritage preservation
# Objective: Preserve and celebrate cultural heritage, including intangible traditions, while ensuring that relocation does not erode identity.
#
# Timeline and concrete steps
# - Years 0–5
#   - Inventory and digitization of cultural assets (sites, stories, languages, crafts).
#   - Develop a Cultural Heritage Strategy with protections for endangered traditions, recipes, songs, and languages, including intergenerational transfer programs.
#   - Designate and protect key heritage sites; plan for virtual/physical accessibility and relocation considerations when sites are threatened.
# - Years 6–10
#   - Transfer or stabilize heritage sites that are at risk; establish heritage-based tourism experiences in safe zones that align with relocation plans.
#   - Fund culture-based education and intergenerational programs in both origin and relocation communities.
# - Years 11–20
#   - Build a national archive and digital museum; foster international partnerships to preserve and share heritage; ensure inclusion of diaspora narratives.
#   - Evaluate UNESCO or regional heritage status where applicable and pursue inscriptions when appropriate.
#
# Budget and funding
# - Domestic: modest, focused on cultural programs and digitization (tens of millions to low hundreds of millions over 20 years).
# - External: grants for cultural heritage preservation; partnerships with international organizations; museum and digital archive development funds.
# - Measurable success metrics
#   - Number of sites preserved/secured; number of intangible heritage practices documented; audience reach of heritage programs; presence of diaspora voices in cultural policy.
#
# Risks and failure modes
# - Underfunding could erode heritage preservation; misalignment with relocation priorities; cultural homogenization risks.
# - Contingency triggers
#   - If heritage loss accelerates, scale up digitization and community-led heritage programs; adjust relocation plans to protect culturally significant communities.
# - Assumptions and uncertainties
#   - Assumes community willingness to integrate heritage into relocation narratives; assumes stable external support for heritage initiatives.
#
# E. Environmental mitigation/adaptation
# Objective: Protect people and assets via a mix of nature-based solutions and infrastructure, while reducing ecological and climate risks.
#
# Timeline and concrete steps
# - Years 0–5
#   - Conduct a coastal vulnerability atlas; identify priority areas for hard protection and nature-based solutions (mangroves, reefs, living shorelines).
#   - Initiate mangrove restoration and reef-based protection along key coastlines; pilot nature-based flood mitigation in select zones.
#   - Develop disaster risk reduction (DRR) early warning systems and community preparedness programs.
# - Years 6–10
#   - Scale coastal protections (sea walls where needed, elevated structures, flood-proofed public facilities) and continue nature-based approaches.
#   - Implement land-use planning to avoid hazard-prone zones; invest in climate-resilient agriculture and water management (drought/flood resilience).
# - Years 11–20
#   - Maintain, retrofit, and upgrade defenses as climate data evolves; re-evaluate protective strategies with an adaptive-management framework.
#   - Expand green energy and water security to reduce climate-related vulnerabilities.
#
# Budget and funding
# - Domestic: 2–5% of GDP annually (depending on risk exposure and debt capacity); high initial investment phase.
# - External: grants and concessional loans for climate-resilience infrastructure; especially nature-based solutions with co-benefits.
# - Rough cost envelope: $1.0–1.8B domestic; $0.8–1.7B external; total $1.8–3.5B.
#
# Measurable success metrics
# - Percentage of coastline protected by natural and hybrid defenses.
# - Mangrove and reef restoration area; flood event frequency reduction; early-warning reach and effectiveness.
# - Reliability and performance of critical public services during flood events.
#
# Risks and failure modes
# - Inadequate protection where inundation exceeds defenses; ecological trade-offs; land-use conflicts.
# - Contingency triggers
#   - If flood damages exceed forecasted levels for two consecutive years, reallocate funds to accelerate protective measures; increase nature-based solutions.
# - Assumptions and uncertainties
#   - Assumes climate projections and flood modeling are sufficiently reliable to prioritize protections; assumes maintenance capacity and governance to sustain defenses.
#
# Section 3. Governance, implementation, and funding architecture
# - Institutions
#   - National Climate Change Authority (NCCA) to coordinate across sectors.
#   - National Relocation Authority (NRA) for relocation/housing; an Independent Rights Ombudsperson for displacement-related matters.
#   - Cultural Heritage Council; Coastal Resilience Agency for environmental protections.
#   - Disaster Risk Reduction Command (DRRC) for emergency planning and response.
# - Financing mix
#   - Domestic budget allocations: 30–50% of total program funding, with annual targets tied to GDP and revenues.
#   - External funding: 50–70% of total program funding; prioritize grants and concessional loans; blend with diaspora investments and private-sector co-financing.
#   - Climate finance instruments: grants, concessional loans, sovereign green bonds, catastrophe risk insurance/public-private partnerships.
# - Transparency and accountability
#   - Public dashboards with milestone reporting; independent audits; community oversight committees.
# - Contingency planning
#   - Trigger events: failure to meet key milestones, funding shortfalls, or escalating disaster risks; policy adjustments to re-prioritize or reallocate resources.
#
# Section 4. Two high-level policy approaches: in-place adaptation vs planned retreat/relocation
#
# Approach 1: In-place adaptation (protect and buttress the capital and arable land)
# - Core idea: Invest heavily in hard defenses (seawalls, raised platforms), flood-proofing, pumped drainage, and selective land reclamation to keep the capital and 40% of arable land in their current locations.
# - Pros
#   - Preserves current population distribution; continuity of government, services, and identity in the near term.
#   - Potentially lower disruption to existing communities and livelihoods if defenses work.
# - Cons and ethical considerations
#   - High costs and risk of failure if sea-level rise accelerates; long-term burden on future generations; inequitable outcomes if defense advantages accrue to those in protected zones while others remain exposed or displaced.
#   - Intergenerational justice concerns: present-day investment commitments may overwhelm future capacity, and if protections fail or degrade, vulnerable groups bear the brunt.
# - Funding and cost profile
#   - Very high upfront capital costs; ongoing maintenance; reliance on long-term external financing and risk transfer (insurance, guarantees).
# - Contingency risks
#   - If climate risks outpace protection, asset losses could be catastrophic; governance debates around ongoing funding and equity.
#
# Approach 2: Planned retreat/relocation (staged, rights-based relocation)
# - Core idea: Proactively move populations, livelihoods, and critical assets away from high-risk zones to higher ground or new settlements, with a rights-based framework and robust protections for citizenship, livelihoods, and culture.
# - Pros
#   - Reduces exposure to escalating climate risks; more predictable planning environment; can unlock safer, more sustainable long-term development.
# - Cons and ethical considerations
#   - Dislocation costs, cultural disruption, and potential loss of sense of place; risks of unequal treatment where some communities receive infrastructure while others do not; potential impacts on minority or vulnerable groups during relocation.
# - Funding and cost profile
#   - Domestic and external funding balanced to cover housing, infrastructure, services, and livelihoods in relocated areas; upfront investments offset by long-term resilience gains.
# - Contingency risks
#   - Political resistance to relocation; social fracture if relocation is perceived as coercive; insufficient housing supply or job opportunities in relocation areas.
#
# Ethical trade-offs between approaches
# - Intergenerational justice: In-place adaptation can defer relocation costs but raises the risk of catastrophic loss for future generations if protections fail; planned retreat spreads the burden more evenly across generations but concentrates costs now.
# - Rights of vulnerable groups: A plan that focuses on in-situ defense may privilege those who own protected assets, at the expense of marginalized groups who bear higher relative risk; a relocation-focused plan must ensure not to coerce or disproportionately disadvantage any group and must guarantee access to services, livelihoods, and cultural continuity.
# - Justice in voice and participation: A relocation strategy that embeds community-led decision-making, consent, and fair compensation can be more ethically robust than a defense-heavy plan that marginalizes communities.
#
# Section 5. Recommendation and justification
# - The single best policy recommendation: Adopt a hybrid “managed retreat with targeted in-situ adaptation” approach.
#   - Why this is robust across scenarios:
#     - It acknowledges that some areas (especially the capital core and critical arable zones) are high-value, high-risk assets best protected in the near term with targeted defenses, while more exposed areas and populations are relocated in a rights-based, predictable, and participatory way.
#     - It aligns with equity and human rights obligations by ensuring protections, housing, and livelihoods for relocated populations and by preserving cultural heritage and citizenship status.
#     - It is flexible to climate and geopolitical uncertainties: if adaptation costs rise or external aid wanes, the plan can lean more toward retreat in later phases; if climate signals permit, protections can be expanded or refined.
#     - It provides a clear governance and financing framework with phased milestones and contingency triggers, reducing the risk of abrupt, destabilizing shifts.
#   - Operationally, this means:
#     - In the near term (Years 0–5): halt escalation of risk in the capital by deploying a mix of nature-based solutions and critical defenses, while launching the relocation program for the most exposed communities and initiating new safe settlements.
#     - Mid-term (Years 6–15): scale relocation, complete a majority of housing and livelihoods in relocated areas, and consolidate economic diversification; continuously upgrade defenses where cost-effective and necessary for core services.
#     - Long-term (Years 16–20): consolidate gains, re-evaluate risk, adapt to new climate projections, and maintain flexible paths for potential returns or further relocation if conditions permit.
#   - Ethical guardrails: insist on a participatory relocation process; ensure universal access to rights and services; maintain diaspora engagement to sustain cultural and political legitimacy; prioritize vulnerable groups in every phase.
#
# Section 6. Implementation-ready plan: 12–24 month action map (highlights)
# - Governance and institutions
#   - Establish NRA, NCCA, and Coastal Resilience Agency; appoint an Independent Rights Ombudsperson.
#   - Create cross-ministerial coordinating committees for housing, livelihoods, heritage, and DRR.
# - Financing and instruments
#   - Set up a National Climate Resilience Fund; issue sovereign green bonds; explore blended finance with development banks.
#   - Formalize a diaspora investment framework; guarantee investment-friendly conditions for relocation housing and green infrastructure.
# - People and communities
#   - Complete risk and vulnerability census; launch relocation beneficiary selection with inclusive, transparent criteria.
#   - Initiate social protection expansions; begin vocational retraining and entrepreneurship support aligned with relocation sites.
# - Housing and settlement
#   - Finalize master plans for 2–3 new safer towns; commence construction of early housing clusters (5,000–8,000 units) and essential services.
#   - Implement land tenure reforms in relocation areas; provide secure housing rights.
# - Economic diversification
#   - Launch pilots in climate-smart agriculture, sustainable seafood processing, and eco-tourism in relocation zones.
#   - Expand renewable energy and grid resilience; advance inter-island logistics links.
# - Environment and heritage
#   - Initiate mangrove restoration and coastal habitat projects; digitize cultural heritage assets; establish protected heritage zones near relocation sites.
# - Monitoring and risk management
#   - Create a climate-risk dashboard with annual independent evaluations; set trigger thresholds for accelerating or adjusting strategy.
#
# Key assumptions and uncertainties (transparent)
# - Assumptions
#   - External climate finance will be available at predictable terms; there is political will to pursue relocation, rights protections, and heritage preservation; land is available for relocation and safe settlements; diaspora capital is accessible.
# - Major uncertainties
#   - Climate trajectory (rate of sea-level rise, extreme events); economic shocks that affect tourism and fisheries; donor fatigue and policy shifts in neighboring states; feasibility and costs of large-scale in-situ defenses.
# - Risks of misestimation
#   - Over- or under-estimating relocation needs could lead to housing shortfalls or misallocated funds; failure to engage communities could undermine legitimacy.
#
# Narrative wrap-up: what success would look like in 20 years
# - People live in secure homes with reliable access to services in relocated areas, while essential government functions and critical services are safeguarded in a protected core.
# - The economy has diversified beyond tourism and small-scale fishing toward climate-resilient industries, with stable livelihoods for relocated populations and new settlements.
# - Legal provisions provide rights and protections for displaced citizens, with clear pathways for naturalization or residency and sustained citizenship assurances to preserve statehood legitimacy.
# - Cultural heritage is preserved through a combination of digitization, preservation of living practices, and heritage tourism that respects communities.
# - Coastal environments are strengthened through nature-based and hybrid infrastructure strategies, with effective early warning and DRR systems.
#
# Closing note
# - The plan emphasizes equity, adaptability, and the long-term viability of the nation-state. It recognizes the moral imperative to safeguard the most vulnerable while maintaining national sovereignty and cultural integrity. The hybrid approach balances the near-term necessity of protecting core assets and services with the long-term resilience gained by orderly relocation, thereby maximizing the odds of a robust, just, and prosperous trajectory under a wide range of climate and geopolitical conditions.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[9], line 6
#       3 model_name = "claude-sonnet-4-5"
#       5 claude = Anthropic()
# ----> 6 response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
#       7 answer = response.content[0].text
#       9 display(Markdown(answer))
#
# File ~/Documents/unix/udemy/agents/.venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File ~/Documents/unix/udemy/agents/.venv/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:930, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     923 if model in DEPRECATED_MODELS:
#     924     warnings.warn(
#     925         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     926         DeprecationWarning,
#     927         stacklevel=3,
#     928     )
# --> 930 return self._post(
#     931     "/v1/messages",
#     932     body=maybe_transform(
#     933         {
#     934             "max_tokens": max_tokens,
#     935             "messages": messages,
#     936             "model": model,
#     937             "metadata": metadata,
#     938             "service_tier": service_tier,
#     939             "stop_sequences": stop_sequences,
#     940             "stream": stream,
#     941             "system": system,
#     942             "temperature": temperature,
#     943             "thinking": thinking,
#     944             "tool_choice": tool_choice,
#     945             "tools": tools,
#     946             "top_k": top_k,
#     947             "top_p": top_p,
#     948         },
#     949         message_create_params.MessageCreateParamsStreaming
#     950         if stream
#     951         else message_create_params.MessageCreateParamsNonStreaming,
#     952     ),
#     953     options=make_request_options(
#     954         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     955     ),
#     956     cast_to=Message,
#     957     stream=stream or False,
#     958     stream_cls=Stream[RawMessageStreamEvent],
#     959 )
#
# File ~/Documents/unix/udemy/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1324, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1310 def post(
#    1311     self,
#    1312     path: str,
#    (...)   1319     stream_cls: type[_StreamT] | None = None,
#    1320 ) -> ResponseT | _StreamT:
#    1321     opts = FinalRequestOptions.construct(
#    1322         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1323     )
# -> 1324     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/unix/udemy/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1112, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1109             err.response.read()
#    1111         log.debug("Re-raising status error")
# -> 1112         raise self._make_status_error_from_response(err.response) from None
#    1114     break
#    1116 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CYtPPER6GZmm2apTfqTJL'}

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# As Chief Policy Planner for our sovereign island nation, I present this urgent 20-year strategy to navigate the existential threat of sea-level rise. Our nation of 200,000 faces an unprecedented challenge: the annual inundation of our capital and 40% of our arable land within two decades. Our current reliance on tourism and small-scale fishing, combined with a limited national budget (GDP $1.5B, reserves covering ~3 years of spending), hostile neighboring migration policies, and uncertain international aid, demands a bold, proactive, and self-reliant approach.
#
# Our overarching vision is to secure the long-term survival, prosperity, and cultural identity of our people and nation, even as our physical geography transforms. This strategy acknowledges the inevitability of significant physical changes and prioritizes strategic adaptation and relocation over futile resistance.
#
# ---
#
# ### **Overarching Strategy: Proactive Resilience & Managed Transformation**
#
# Our strategy centers on a **Proactive Resilience & Managed Transformation** approach, blending strategic retreat from the most vulnerable areas with targeted adaptation for essential infrastructure and ecological assets, while fundamentally restructuring our economy and legal framework to ensure national continuity.
#
# ---
#
# ### **Detailed 20-Year Strategy Elements**
#
# **Assumptions & Uncertainties:**
# *   **Assumptions:**
#     *   Sufficient suitable higher ground exists within our sovereign territory for a new capital and resettled communities.
#     *   International climate finance mechanisms (e.g., GCF, Adaptation Fund) will provide *some* level of support, though not comprehensive.
#     *   Our citizens, while potentially resistant initially, will ultimately engage constructively in the planning and implementation process.
#     *   Basic international legal principles (e.g., non-refoulement) will continue to hold, even if specific 'climate refugee' status is denied.
# *   **Uncertainties:**
#     *   The precise rate and severity of sea-level rise and associated storm surges.
#     *   The extent and timing of international financial and technical assistance.
#     *   Geopolitical stability and the willingness of international partners to engage in novel legal concepts like "statehood without contiguous territory."
#     *   The social cohesion and psychological impact of mass internal displacement.
#
# ---
#
# #### **(a) Equitable Human Relocation and Housing**
#
# *   **Goal:** Safely and equitably relocate 100% of at-risk populations and infrastructure to secure, sustainable locations within national territory by Year 20, with minimal social disruption.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-3: Assessment & Planning Phase**
#         *   **0-1:** National Vulnerability & Resettlement Suitability Assessment (NVRS): Map all at-risk areas, identify and survey suitable high-ground locations (geology, water, biodiversity, land ownership). Public consultations initiated.
#         *   **1-2:** Develop National Resettlement Master Plan (NRMP): Detailed plans for new urban centers and agricultural zones, infrastructure (roads, utilities, communication), and community facilities. Legal framework for land acquisition/compensation.
#         *   **2-3:** Pilot Relocation Program (1-2 small communities, ~500 people): Test planning assumptions, identify challenges, refine processes.
#     *   **Years 4-15: Implementation & Phased Relocation**
#         *   **4-8:** Infrastructure Development Phase I: Begin construction of essential roads, power grids, water/sanitation, and initial public buildings in designated new capital and key resettlement sites.
#         *   **6-15:** Phased Community Relocation: Systematically relocate populations from most vulnerable areas. Prioritize communities most impacted by annual flooding and critical government functions. Housing construction using resilient, modular, and locally appropriate designs.
#         *   **10-15:** Infrastructure Development Phase II: Expand and consolidate new urban centers, build schools, hospitals, commercial zones.
#     *   **Years 16-20: Consolidation & Final Relocation**
#         *   **16-20:** Finalize relocation of remaining at-risk populations and transfer of all critical government functions to the new capital. Decommission and ecologically restore abandoned sites where feasible.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $800M - $1.2B over 20 years (53-80% of current GDP).
#     *   **Budget Allocation:** 30% of annual national budget for capital projects; remainder from external funding.
#     *   **External Funding Sources:** Green Climate Fund (GCF), Adaptation Fund, World Bank/ADB concessional loans, bilateral aid from climate-resilient partners (e.g., Japan, Netherlands, EU).
# *   **Measurable Success Metrics:**
#     *   95% of identified at-risk population successfully relocated by Year 20.
#     *   80% of relocated households report satisfaction with new housing and community services within 5 years of relocation.
#     *   Construction of new capital and infrastructure on schedule and within 15% of budget.
#     *   No loss of life due to sea-level rise flooding post-Year 15.
# *   **Key Risks & Failure Modes:**
#     *   **Social Resistance:** Reluctance to move, loss of traditional lands/livelihoods, perceived inequity.
#     *   **Land Scarcity/Conflict:** Insufficient suitable land, disputes over land ownership on higher ground.
#     *   **Funding Shortfall:** Inadequate external aid or domestic budget allocation.
#     *   **Infrastructure Failure:** Poor planning or execution of new infrastructure.
#     *   **Psychological Trauma:** Mental health impacts of displacement.
# *   **Contingency Triggers:**
#     *   **Slower SLR:** Allows for extended timelines, re-prioritization to economic development.
#     *   **Faster SLR:** Accelerate relocation timelines, prioritize critical infrastructure transfer, request emergency international aid.
#     *   **Major Funding Shortfall:** Scale back non-essential infrastructure, focus on basic housing, explore innovative financing (e.g., diaspora bonds), potentially seek direct humanitarian aid for housing.
#     *   **Widespread Social Resistance:** Halt forced relocation, launch intensive community engagement campaigns, revise compensation packages, involve anthropologists/sociologists in planning.
#
# ---
#
# #### **(b) Economic Transition and Livelihood Preservation**
#
# *   **Goal:** Diversify the national economy away from vulnerable coastal sectors, create resilient livelihoods for 90% of the working population, and increase GDP per capita by 25% by Year 20.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Foundation & Capacity Building**
#         *   **0-2:** Economic Vulnerability & Opportunity Assessment: Identify sectors resilient to SLR and attractive for investment (e.g., aquaculture in protected areas, deep-sea fishing, renewable energy, specialized agriculture, tech/BPO services, high-value niche tourism on higher ground).
#         *   **1-4:** National Skills Development & Retraining Program: Establish vocational schools and partnerships for training in identified growth sectors. Prioritize displaced fishers and tourism workers.
#         *   **3-5:** Renewable Energy Transition Plan: Phased shift to solar/wind power, reducing reliance on imported fossil fuels. Attract investment in this sector.
#     *   **Years 6-15: Investment & Sector Growth**
#         *   **6-10:** Develop Agri-Tech & Sustainable Aquaculture Zones: Establish new, elevated agricultural zones using climate-smart practices (hydroponics, vertical farms) and inland/protected aquaculture facilities.
#         *   **8-15:** Foster High-Tech & Services Sector: Create dedicated tech parks, incentivize foreign investment in data centers, call centers, and digital services. Develop fiber optic infrastructure.
#         *   **10-15:** Niche Tourism Development: Promote eco-tourism, cultural tourism, and high-value low-impact tourism on higher ground and protected marine areas.
#     *   **Years 16-20: Consolidation & Export Readiness**
#         *   **16-20:** Expand export capabilities for new sectors. Establish Free Trade Zones in new economic hubs. Support small and medium enterprises (SMEs) with business incubation and microfinance.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $500M - $750M over 20 years (33-50% of current GDP).
#     *   **Budget Allocation:** 25% of annual national budget for economic development, education, and subsidies.
#     *   **External Funding Sources:** Multilateral development banks (World Bank, ADB), private sector investment (e.g., for tech, renewable energy), bilateral development aid.
# *   **Measurable Success Metrics:**
#     *   New economic sectors contribute 50% of GDP by Year 20 (up from <5% currently).
#     *   Unemployment rate for relocated populations remains below 10%.
#     *   70% of displaced workers successfully retrained and employed in new sectors.
#     *   Renewable energy sources account for 80% of national energy consumption by Year 20.
# *   **Key Risks & Failure Modes:**
#     *   **Market Failure:** New industries fail to attract investment or find markets.
#     *   **Skill Mismatch:** Training programs do not align with industry needs.
#     *   **Brain Drain:** Educated youth leave the country for better opportunities.
#     *   **Competition:** Inability to compete with larger economies.
# *   **Contingency Triggers:**
#     *   **Economic Downturn:** Implement emergency stimulus packages, prioritize direct cash transfers for displaced workers, double down on attracting foreign direct investment with enhanced incentives.
#     *   **Low uptake in new sectors:** Re-evaluate training programs, offer more attractive startup grants, conduct market research for alternative industries.
#     *   **High Brain Drain:** Implement retention schemes, provide subsidized housing/healthcare for skilled workers, foster a vibrant social and cultural environment.
#
# ---
#
# #### **(c) Legal/Political Status and Rights for Displaced Citizens (Retaining Statehood)**
#
# *   **Goal:** Secure international recognition for our nation's sovereignty and citizenship rights for all citizens, irrespective of physical displacement, by Year 20. Establish legal frameworks for national continuity.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Legal Foundations & Advocacy**
#         *   **0-2:** Establish a Presidential Commission on Statehood Continuity (PCSC): Comprising legal experts, diplomats, and community leaders to research international precedents and develop a legal strategy.
#         *   **1-3:** Constitutional Review & Amendments: Prepare amendments to define national territory and citizenship in a manner resilient to physical changes (e.g., focus on maritime zones, cultural/historical claims, and a "state in trust" concept).
#         *   **2-5:** International Advocacy Campaign Phase I: Engage the UN, AOSIS, specific nations (e.g., Pacific Forum members, powerful allies) on the concept of "statehood without contiguous land" or "deterritorialized sovereignty." Focus on maintaining UN membership and voting rights.
#     *   **Years 6-15: Legal Implementation & Bilateral Treaties**
#         *   **6-10:** Enact domestic legislation safeguarding rights of internally displaced persons (IDPs): Ensuring access to services, property rights, and political participation.
#         *   **8-15:** Pursue Bilateral Agreements: Seek treaties with key nations to recognize our continued statehood and citizenship rights for our people, potentially including agreements for consular services or even temporary residence options in extreme scenarios (without implying mass migration).
#     *   **Years 16-20: Consolidation & Future Proofing**
#         *   **16-20:** Finalize international legal strategy. Establish a "Sovereign Trust Fund" from salvaged national assets and international contributions to secure a permanent home (physical or virtual) for our nation's identity and governance. Explore creation of a "digital nation" platform.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $100M - $200M over 20 years (6.7-13% of current GDP).
#     *   **Budget Allocation:** 5% of annual national budget for legal fees, diplomatic efforts, and international representation.
#     *   **External Funding Sources:** Philanthropic organizations focused on climate justice, specific international legal funds, technical assistance from UN bodies, grants from nations interested in international legal precedents.
# *   **Measurable Success Metrics:**
#     *   Maintenance of UN membership and voting rights.
#     *   Bilateral treaties for statehood recognition with at least 10 key nations by Year 20.
#     *   Domestic legal framework fully in place protecting IDP rights.
#     *   No citizens rendered stateless by Year 20.
#     *   Establishment of a widely recognized "Sovereign Trust Fund" or similar entity.
# *   **Key Risks & Failure Modes:**
#     *   **International Non-recognition:** Major powers refuse to acknowledge deterritorialized sovereignty.
#     *   **Statelessness:** Citizens lose their nationality if the state is deemed to cease to exist.
#     *   **Loss of Voice:** Inability to participate in international forums.
#     *   **Internal Division:** Disagreement on the concept of statehood.
# *   **Contingency Triggers:**
#     *   **Major power refusal of deterritorialized sovereignty:** Focus on achieving regional recognition, bolster economic ties to leverage influence, explore "associated state" models with a larger nation, intensify advocacy for 'cultural sovereignty'.
#     *   **Loss of UN seat:** Redouble efforts for observer status, focus on gaining recognition through bilateral agreements, shift focus to a "diaspora nation" model.
#     *   **Citizenship challenges abroad:** Launch global legal aid funds for citizens, engage international human rights organizations.
#
# ---
#
# #### **(d) Cultural Heritage Preservation**
#
# *   **Goal:** Preserve 100% of tangible and intangible cultural heritage identified as at-risk due to SLR by Year 15, and integrate it into the national identity in new settlements.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Documentation & Digitalization**
#         *   **0-3:** Comprehensive Cultural Heritage Inventory: Map all significant cultural sites, historical buildings, archaeological areas, and intangible heritage (oral histories, traditional practices, languages). Prioritize most vulnerable sites.
#         *   **1-5:** Digital Archiving Project: High-resolution scanning, photogrammetry, 3D modeling of at-risk tangible heritage. Extensive oral history recording, video documentation of rituals, dances, and traditional skills. Establish a secure national digital archive.
#     *   **Years 6-15: Physical Preservation & Integration**
#         *   **6-10:** Strategic Relocation & Preservation: Carefully relocate or reconstruct iconic cultural artifacts and smaller, portable structures to new cultural centers in the elevated capital. Establish climate-controlled national museum in the new capital.
#         *   **8-15:** Community Cultural Centers: Build dedicated cultural centers in each new settlement to foster traditional arts, language, and storytelling. Integrate heritage narratives into new urban planning.
#     *   **Years 16-20: Legacy & Global Outreach**
#         *   **16-20:** Curriculum Integration: Ensure cultural heritage is a core part of the national education curriculum.
#         *   **18-20:** International Collaboration: Partner with UNESCO and other international cultural institutions to safeguard digital archives and promote global awareness of our disappearing heritage.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $75M - $125M over 20 years (5-8% of current GDP).
#     *   **Budget Allocation:** 3% of annual national budget for cultural preservation.
#     *   **External Funding Sources:** UNESCO, World Monuments Fund, Getty Foundation, bilateral aid from culturally sensitive nations, philanthropic organizations.
# *   **Measurable Success Metrics:**
#     *   100% of at-risk tangible heritage digitally archived by Year 5.
#     *   80% of identified intangible heritage documented and archived by Year 10.
#     *   At least 5 major cultural artifacts or structures successfully relocated/reconstructed.
#     *   Establishment of 5+ vibrant community cultural centers in new settlements.
#     *   National language proficiency maintained or increased among youth by Year 20.
# *   **Key Risks & Failure Modes:**
#     *   **Loss Before Preservation:** Rapid SLR or sudden events destroy sites before documentation.
#     *   **Technological Obsolescence:** Digital formats become unreadable.
#     *   **Loss of Context:** Heritage loses meaning when removed from original environment.
#     *   **Lack of Community Engagement:** Heritage preservation efforts fail to resonate locally.
# *   **Contingency Triggers:**
#     *   **Accelerated SLR affecting heritage sites:** Prioritize emergency salvage and rapid digitalization; partner with marine archaeologists for underwater sites.
#     *   **Low community engagement:** Revamp engagement strategies, offer community-led heritage initiatives, provide direct funding for local cultural groups.
#     *   **Funding shortfall:** Focus solely on digital archiving, rely on volunteer efforts, seek smaller grants for specific projects.
#
# ---
#
# #### **(e) Environmental Mitigation/Adaptation**
#
# *   **Goal:** Implement strategic environmental adaptations to protect critical non-relocatable assets, enhance ecological resilience, and secure vital ecosystem services for the remaining land by Year 10.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Strategic Protection & Ecosystem Restoration**
#         *   **0-2:** Critical Infrastructure Protection Plan: Identify essential, non-relocatable infrastructure (e.g., main port, airport – requiring significant investment for relocation) and develop targeted, high-cost coastal defense plans (sea walls, dykes). *Note: This is highly selective, not a general defense strategy.*
#         *   **1-5:** Large-Scale Mangrove & Coral Reef Restoration Program: Prioritize natural coastal defenses. Restore degraded mangrove forests and coral reefs for their protective and biodiversity benefits.
#         *   **3-5:** National Water Security Plan: Implement rainwater harvesting, groundwater management, and strategic desalination plants in new settlements.
#     *   **Years 6-15: Sustainable Resource Management**
#         *   **6-10:** Sustainable Land Use Planning: Implement strict zoning for remaining high ground, protecting critical ecosystems and water sources. Promote permaculture and agroforestry.
#         *   **8-15:** Waste Management & Circular Economy: Develop modern waste management facilities (waste-to-energy where feasible) and promote circular economy principles.
#     *   **Years 16-20: Monitoring & Advanced Adaptation**
#         *   **16-20:** Climate Monitoring & Early Warning Systems: Install advanced sensors for sea-level, weather, and ocean conditions. Develop robust early warning systems for storms and coastal inundation.
#         *   **18-20:** Research & Development: Invest in local R&D for climate-resilient crops, aquaculture techniques, and renewable energy innovations.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $300M - $500M over 20 years (20-33% of current GDP).
#     *   **Budget Allocation:** 15% of annual national budget for environmental projects and infrastructure.
#     *   **External Funding Sources:** Global Environment Facility (GEF), Adaptation Fund, UN Environment Programme, bilateral aid for specific climate projects, conservation NGOs.
# *   **Measurable Success Metrics:**
#     *   50% increase in mangrove coverage and 20% increase in live coral cover by Year 10.
#     *   Access to potable water for 95% of the population in new settlements.
#     *   Reduced damage to critical port/airport infrastructure by 70% post-Year 15.
#     *   Effective waste management system implemented in all major settlements.
#     *   Early warning systems successfully alert 90% of population before extreme weather events.
# *   **Key Risks & Failure Modes:**
#     *   **Overwhelmed Defenses:** Sea walls/dykes fail against extreme events or accelerated SLR.
#     *   **Ecosystem Collapse:** Restoration efforts fail due to continued climate stress or pollution.
#     *   **Water Scarcity:** Insufficient freshwater sources for growing populations.
#     *   **Resource Depletion:** Over-extraction of fish or other natural resources.
# *   **Contingency Triggers:**
#     *   **Faster ecosystem degradation:** Increase investment in restoration, explore more aggressive conservation measures (e.g., marine protected areas), seek emergency ecological funding.
#     *   **Failure of hard defenses:** Re-evaluate and potentially decommission assets, accelerate relocation from those areas, focus solely on natural defenses.
#     *   **Water shortages:** Implement stricter water rationing, invest in additional desalination capacity, explore inter-island water transfer (if feasible).
#
# ---
#
# ### **Comparison of Alternative High-Level Approaches**
#
# #### **1. Approach Centered on In-Place Adaptation (Status Quo++):**
#
# *   **Focus:** Intensive protection of existing coastal areas, infrastructure, and agricultural lands through large-scale engineering.
# *   **Key Strategies:** Massive sea walls, dikes, polders, land reclamation, elevating existing buildings and infrastructure, extensive pumping systems, salt-tolerant crops.
# *   **Ethical Trade-offs:**
#     *   **Intergenerational Justice:** This approach prioritizes the *immediate* preservation of existing communities and assets for the current generation. However, it likely burdens future generations with a perpetually escalating maintenance cost, a constant battle against rising seas, and the risk of catastrophic failure (e.g., a dike breaking). It defers the inevitable decision, potentially leaving future generations with fewer resources and options.
#     *   **Rights of Vulnerable Groups:** While appearing to keep communities together, this approach could disproportionately affect the poor. Expensive adaptations like elevating homes or building private defenses are beyond the reach of many. Those unable to adapt might be marginalized or forced to leave anyway, creating an "adaptation apartheid." Furthermore, the engineering solutions often destroy natural habitats that vulnerable groups rely on for livelihoods (e.g., fishing grounds, mangrove forests).
# *   **Viability for our Nation:** Given "annual flooding of capital and 40% of arable land in 20 years," this approach is **untenable and represents maladaptation.** The scale of engineering required for continuous protection against annual flooding of such a large and vital area would be astronomically expensive, likely beyond our GDP, and unsustainable in the long term. It would merely delay the inevitable and potentially lead to a more abrupt, catastrophic failure later.
#
# #### **2. Approach Centered on Planned Retreat/Relocation (Managed Transformation):**
#
# *   **Focus:** Proactive and strategic movement of populations, infrastructure, and economic activities to safer, higher ground within national territory.
# *   **Key Strategies:** Comprehensive national resettlement plans, development of new urban centers and agricultural zones, economic diversification towards resilient sectors, legal frameworks for statehood continuity.
# *   **Ethical Trade-offs:**
#     *   **Intergenerational Justice:** This approach demands significant sacrifices from the *current* generation (dislocation, disruption of livelihoods, loss of ancestral lands) but aims to secure a viable, sustainable future for *future* generations. It is a long-term investment in national survival, reducing future vulnerability and the burden of constant climate defense. It enables a proactive response, minimizing future crisis-driven migration.
#     *   **Rights of Vulnerable Groups:** The risks here are significant if not managed equitably. Forced relocation can be traumatic, leading to loss of social networks, identity, and livelihoods. It risks dispossessing landholders on higher ground or creating new inequalities if relocation benefits are not distributed fairly. However, with careful planning, robust compensation frameworks, community participation, and dedicated support services, it offers the opportunity to build *more resilient and equitable* communities with improved infrastructure and access to services, potentially uplifting marginalized groups in the long run. The strategy above specifically addresses these risks through equitable planning and social support.
# *   **Viability for our Nation:** This approach is **the only viable long-term solution** for our nation given the specific threats outlined. While challenging, it directly confronts the physical reality of impending inundation and offers a pathway to national continuity.
#
# ---
#
# ### **Single Best Policy Recommendation and Robustness**
#
# My single best policy recommendation is the **Proactive Resilience & Managed Transformation** strategy, fundamentally centered on **Planned Retreat/Relocation** as the overarching principle, complemented by strategic, targeted environmental adaptation.
#
# **Why it is Robust Across Optimistic and Pessimistic Climate and Geopolitical Scenarios:**
#
# 1.  **Directly Addresses the Core Physical Threat:** The "annual flooding of capital and 40% of arable land" makes pure in-place adaptation a fantasy. Planned retreat is the only strategy that acknowledges this reality and offers a sustainable physical future for our people within our borders.
# 2.  **Adaptive Capacity:**
#     *   **Optimistic Climate Scenario (Slower SLR):** If SLR is slower than predicted, the planned retreat provides a longer transition period, allowing for more careful planning, better infrastructure development, and smoother social adjustment. Resources initially allocated for rapid relocation can be redirected to further economic diversification, enhanced social services in new settlements, and more robust long-term infrastructure. The national budget gains breathing room.
#     *   **Pessimistic Climate Scenario (Faster SLR/Extreme Events):** If SLR accelerates or extreme weather events become more frequent, the framework for planned retreat is already established. Early investments in vulnerability assessments, legal frameworks, and initial infrastructure mean the nation is better prepared to accelerate relocation, declare emergencies, and quickly access international humanitarian aid. It shifts from reactive crisis management to a proactive, albeit faster, implementation of an existing plan.
# 3.  **Economic Resilience:** By diversifying our economy away from vulnerable coastal sectors and investing in new, resilient industries (aquaculture, tech, renewables), we build an economy less susceptible to climate impacts. This protects livelihoods and secures financial stability, regardless of the precise climate trajectory. This also makes us less dependent on a single industry (tourism) which is itself vulnerable to global shocks (pandemics, economic crises) as well as climate change.
# 4.  **Geopolitical Independence:** The strategy prioritizes internal solutions for relocation and livelihood, reducing reliance on neighboring states for mass migration (which they have refused). Our proactive legal strategy for "statehood continuity" aims to secure our sovereignty and international standing, offering a dignified future even if our physical land mass shrinks considerably.
#     *   **Optimistic Geopolitical Scenario (Increased Aid/Recognition):** Strong international support (financial, technical, legal) accelerates the implementation of our strategy, allowing for higher quality housing, faster economic transition, and smoother international legal recognition of our statehood.
#     *   **Pessimistic Geopolitical Scenario (Limited Aid/Non-recognition):** While challenging, the strategy's emphasis on self-reliance (internal relocation, domestic economic diversification, constitutional amendments) means our nation is not solely dependent on external goodwill. We build foundational resilience. The international advocacy campaign continues, but our survival is not predicated on immediate external approval for novel legal concepts. We prepare for a scenario where we manage our destiny primarily through our own means.
# 5.  **Ethical Responsibility:** While demanding immediate sacrifices, planned retreat is ethically superior for intergenerational justice. It ensures a future for our nation and people, rather than condemning successive generations to a losing battle. The strategy includes explicit measures for equitable relocation and cultural preservation, aiming to mitigate the trauma of displacement and build a new, resilient national identity.
#
# In conclusion, "Proactive Resilience & Managed Transformation" through a managed, equitable planned retreat is not merely an option; it is an imperative. It represents the most robust and ethically sound path forward to secure the future of our sovereign island nation in the face of an undeniable climate crisis.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# I. Equitable Human Relocation and Housing (5 years, $100M, 7% of national budget)
#
# 1. Conduct inclusive, national-level public consultations (Year 1, $5M) to gather information on existing relocation plans and social, economic, and cultural impacts.
# 2. Establish a National ReLocation Committee (Year 2, $3M) to coordinate a systematic relocation strategy with international guidance on fair distribution, compensation, and social services.
# 3. Construct transitional housing (Year 1-2, $50M) near former flood zones with a mix of affordable and accessible options.
# 4. Implement a fair compensation system (Year 3-5, $30M) that considers the needs and interests of 70% of displaced citizens.
#
# Measurable success metrics: public acceptance rate > 70%, relocation rate > 50% of high-risk area populations.
#
# Key risks and failure modes: public mistrust, insufficient funding, lack of social services.
#
# Contingency triggers: negative consultations outcomes, failure of national consultation engagement.
#
# Assumptions and uncertainties: 10% change in population distribution
#
# II. Economic Transition and Livelihood Preservation (5 years, $500M, 33% of national budget)
#
# 1. Develop and implement a 4-year education and vocational training program (Year 2-5, $100M) for 300,000 small-scale fishermen and 100,000 tourism-related workers.
# 2. Revitalize non-coastal industries through incentives (Year 2-5, $50M) to promote innovation, job creation, and fair labor practices.
# 3. Establish a National Livelihood Fund (Year 1, $50M) to guarantee basic income levels for 60% of citizens.
#
# Measurable success metrics: successful traineeship rate > 50%, increase in coastal non-fishing sector by 15%.
#
# Key risks and failure modes: economic volatility, loss of expertise.
#
# Contingency triggers: government policy shift towards rapid relocation or significant economic fluctuations.
#
# Assumptions and uncertainties: 5% change in GDP growth rate
#
# III. Legal/Political Status and Rights for Displaced Citizens (5 years, $200M, 13% of national budget)
#
# 1. Establish a National Commission for the Rights of Relocation (Year 1, $30M) based on guidelines from international human rights and environmental law.
# 2. Negotiate international cooperation agreements (Year 2, $100M) on displacement impacts on citizenship rights.
#
# Measurable success metrics: acceptance of national human rights protection norms > 80%.
#
# Key risks and failure modes: failure to engage with relevant international governing entities.
#
# Contingency triggers: international refusal to engage, public discontent with human rights standards.
#
# Assumptions and uncertainties: 10% decline in trust of local institutions
#
# IV. Environmental Mitigation/Adaptation (5 years, $500M, 33% of national budget)
#
# 1. Construct coastal barrier system (Year 2-5, $250M) using the most favorable design options.
# 2. Conduct research on sustainable coastal land management (Year 1-2, $50M) and initiate pilot projects for innovative techniques.
#
# Measurable success metrics: 20% increase in projected water depth protection.
#
# Key risks and failure modes: technical complexity issues, public resistance.
#
# Contingency triggers: public discontent, funding shortfalls due to budget constraints.
#
# Assumptions and uncertainties: 10% change in sea-level rise predicted.
#
# V. Environmental Mitigation/Adaptation Alternative (Planned Retreat/Relocation): focus on relocating 90% of population to upperlands before projected flooding and maintaining 10% population in the capital area, prioritizing security, climate and ecological resilience, and human well-being over economic and cultural heritage preservation.
#
# Key benefits: secure future for remaining population, preservation of cultural heritage and biodiversity.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'gemini-2.5-flash', 'llama3.2']
# ['Executive summary\n- Context: A small, low-lying island nation of 200,000 people faces annual flooding of its capital and 40% of arable land within ~20 years due to sea-level rise. The economy depends on tourism and small-scale fishing. GDP is about $1.5B. Emergency reserves cover roughly three years of current spending. Neighbors won’t accept mass migrants; external aid is uncertain.\n- Core objective: A 20-year, prioritized strategy that protects people, preserves livelihoods, safeguards rights and statehood, preserves cultural heritage, and builds resilient environment and economy. The plan emphasizes equity, transparency, and adaptive management.\n- Overall cost/financing sketch: Total program cost in the 20-year horizon is roughly $2.8–3.5B (order of magnitude). Domestic budget allocations will cover a substantial but minority share (roughly 30–40% of the total), with the remainder funded by external sources (grants, concessional loans, climate finance, diaspora investments, and blended finance). Annual domestic allocations will ramp from ~3–7% of GDP early on to ~5–8% later, depending on revenue and debt capacity.\n- Recommendation (single best policy): A hybrid “managed retreat with targeted in-situ adaptation” approach. Protect critical, high-value assets and services in the near term (in-situ adaptation), while planning and executing a staged, rights-based relocation of populations and activities away from the highest-risk zones. This approach minimizes exposure to catastrophic loss, maintains statehood, preserves culture, and remains robust across optimistic and pessimistic climate and geopolitical scenarios.\n\nSection 1. Guiding principles and assumptions\n- Principles\n  - Equity and human rights: prioritize the most vulnerable (elderly, disabled, women-headed households, low-income groups), ensure fair housing, tenure security, social protection, and access to essential services.\n  - Rights and statehood: ensure citizenship, voting rights, access to services, and a credible path to retain or adapt the sovereign status while meeting international human rights obligations.\n  - Cultural preservation: protect heritage, sustain identity, and maintain intergenerational ties to land and community.\n  - Environmental integrity: maximize nature-based solutions where feasible; diversify livelihoods; reduce exposure to climate shocks.\n  - Adaptive governance: phased milestones with review points, transparent reporting, and contingency triggers.\n- Core uncertainties\n  - Rate and pattern of sea-level rise; frequency of extreme events.\n  - Pace and location of migration (internal and external).\n  - Availability and terms of external climate funding.\n  - Economic shifts (tourism demand, fishery sustainability, alternative livelihoods).\n  - Technical feasibility and cost of large-scale in-situ defenses or new-town development.\n- High-level risk categories\n  - Finance (underfunding or aid volatility)\n  - Governance (coordination failures, public trust)\n  - Social (inequitable displacement, social tension)\n  - Environmental (unintended ecological impacts)\n  - Legal/political (constitutional compatibility, rights protections)\n\nSection 2. The 20-year strategy: five elements (a–e)\n\nA. Equitable human relocation and housing\nObjective: Relocate populations and create safe, affordable housing and livelihoods for those at highest risk, while safeguarding family stability, social cohesion, and access to services.\n\nTimeline and concrete steps\n- Years 0–5 (Phase 1)\n  - Establish a National Relocation Authority (NRA) with independent civil-society and territorial representation.\n  - Do a comprehensive risk/household survey to map who is most exposed and who has the least options to stay.\n  - Adopt a rights-centered relocation framework (tenure security, compensation norms, return/participation rights).\n  - Identify 3–5 higher-ground or inland locations for planned settlements; initiate land acquisition, environme ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Executive summary
# - Context: A small, low-lying island nation of 200,000 people faces annual flooding of its capital and 40% of arable land within ~20 years due to sea-level rise. The economy depends on tourism and small-scale fishing. GDP is about $1.5B. Emergency reserves cover roughly three years of current spending. Neighbors won’t accept mass migrants; external aid is uncertain.
# - Core objective: A 20-year, prioritized strategy that protects people, preserves livelihoods, safeguards rights and statehood, preserves cultural heritage, and builds resilient environment and economy. The plan emphasizes equity, transparency, and adaptive management.
# - Overall cost/financing sketch: Total program cost in the 20-year horizon is roughly $2.8–3.5B (order of magnitude). Domestic budget allocations will cover a substantial but minority share (roughly 30–40% of the total), with the remainder funded by external sources (grants, concessional loans, climate finance, diaspora investments, and blended finance). Annual domestic allocations will ramp from ~3–7% of GDP early on to ~5–8% later, depending on revenue and debt capacity.
# - Recommendation (single best policy): A hybrid “managed retreat with targeted in-situ adaptation” approach. Protect critical, high-value assets and services in the near term (in-situ adaptation), while planning and executing a staged, rights-based relocation of populations and activities away from the highest-risk zones. This approach minimizes exposure to catastrophic loss, maintains statehood, preserves culture, and remains robust across optimistic and pessimistic climate and geopolitical scenarios.
#
# Section 1. Guiding principles and assumptions
# - Principles
#   - Equity and human rights: prioritize the most vulnerable (elderly, disabled, women-headed households, low-income groups), ensure fair housing, tenure security, social protection, and access to essential services.
#   - Rights and statehood: ensure citizenship, voting rights, access to services, and a credible path to retain or adapt the sovereign status while meeting international human rights obligations.
#   - Cultural preservation: protect heritage, sustain identity, and maintain intergenerational ties to land and community.
#   - Environmental integrity: maximize nature-based solutions where feasible; diversify livelihoods; reduce exposure to climate shocks.
#   - Adaptive governance: phased milestones with review points, transparent reporting, and contingency triggers.
# - Core uncertainties
#   - Rate and pattern of sea-level rise; frequency of extreme events.
#   - Pace and location of migration (internal and external).
#   - Availability and terms of external climate funding.
#   - Economic shifts (tourism demand, fishery sustainability, alternative livelihoods).
#   - Technical feasibility and cost of large-scale in-situ defenses or new-town development.
# - High-level risk categories
#   - Finance (underfunding or aid volatility)
#   - Governance (coordination failures, public trust)
#   - Social (inequitable displacement, social tension)
#   - Environmental (unintended ecological impacts)
#   - Legal/political (constitutional compatibility, rights protections)
#
# Section 2. The 20-year strategy: five elements (a–e)
#
# A. Equitable human relocation and housing
# Objective: Relocate populations and create safe, affordable housing and livelihoods for those at highest risk, while safeguarding family stability, social cohesion, and access to services.
#
# Timeline and concrete steps
# - Years 0–5 (Phase 1)
#   - Establish a National Relocation Authority (NRA) with independent civil-society and territorial representation.
#   - Do a comprehensive risk/household survey to map who is most exposed and who has the least options to stay.
#   - Adopt a rights-centered relocation framework (tenure security, compensation norms, return/participation rights).
#   - Identify 3–5 higher-ground or inland locations for planned settlements; initiate land acquisition, environmental permitting, and master-planning for 2–3 new towns proximal to existing urban networks.
#   - Begin construction of 5,000–8,000 new housing units (modular, climate-resilient, affordable) for early relocations; pilot climate-proofed community facilities (schools, clinics, markets).
#   - Launch social protection and income-support programs (universal social protection floor, stipend for vulnerable groups) tied to relocation progress.
# - Years 6–10 (Phase 2)
#   - Scale housing to 15,000–25,000 units total across new towns and elevated districts; expand job-creating amenities (retail, logistics, healthcare).
#   - Establish relocation grants tied to livelihoods (microenterprise start-up grants, land-based livelihoods training, skilled trades).
#   - Create secure land tenure and property rights in new locations; ensure portability of citizenship status and access to services.
# - Years 11–20 (Phase 3)
#   - Complete staged relocation to a broad, resilient settlement system while maintaining a core, protected urban hub (critical services and economic functions remain accessible on elevated or protected cores).
#   - Optimize and retrofit existing settlements for eventual transition if flood risk recedes or shifts (flexible zoning, phased return options if conditions allow).
#   - Maintain a continuous housing-supply pipeline and disaster-resilient public infrastructure.
#
# Budget and funding
# - Domestic budget: allocate roughly 5–7% of GDP per year during Years 0–10 (roughly $75–105M annually, using a 1.5B GDP baseline), tapering to 3–5% in later years as absorption capacity increases.
# - External funding: target 55–70% of the total relocation/housing cost through grants, concessional loans, and climate finance; engage diaspora investment and private sector partnerships for land development and housing pipelines.
# - Rough cost envelope (order-of-magnitude, 20 years): $1.2–1.8B domestic, $1.0–2.3B external; total program ~ $2.2–3.5B.
# - Measurable success metrics
#   - Number of people relocated to safe zones; share of high-risk population covered.
#   - Number and quality of new housing units delivered; tenure security (lease/purchase rights).
#   - Access to services: people within 30 minutes of essential services; unemployment/employment rates in relocated areas.
#   - Displacement-adjusted poverty rates; social protection coverage.
#
# Risks and failure modes
# - Non-acceptance by communities; migration bottlenecks; price and land-availability constraints.
# - Inadequate or delayed funding; misallocation; governance fragmentation.
# - Social inequities in relocation (e.g., urban-rural divides, marginalized groups).
# - Contingency triggers
#   - If relocation progress stalls below target milestones for two consecutive six-month periods, trigger a management reset: accelerate targeted grants, reallocate funding, intensify community engagement.
#   - If land acquisition costs exceed projections by >25%, adjust site selection and financing mix; explore intergovernmental support and public-private partnerships.
# - Assumptions and uncertainties
#   - Assumes secure land for new settlements; assumes political will and predictable aid flows; assumes adequate domestic revenue.
#
# B. Economic transition and livelihood preservation
# Objective: diversify the economy beyond tourism and small-scale fishing; protect livelihoods during relocation; invest in resilient industries and skills.
#
# Timeline and concrete steps
# - Years 0–5
#   - Define a Climate-Resilient Economic Plan (CREP) with sectors: sustainable tourism (eco/experiential), green energy, aquaculture with sustainable practices, digital services, logistics/port efficiency, and climate-resilient agriculture.
#   - Invest in workforce development: climate-smart agriculture, marine stewardship, hospitality training, and digital/computational skills.
#   - Create a small business resilience fund and access to concessional credit for relocation-related businesses.
# - Years 6–10
#   - Expand green energy capacity (solar, small-scale wind, storage) to reduce exposure to fossil fuel volatility; develop cross-island energy resilience.
#   - Promote export-oriented, value-added seafood processing, agro-processing, and eco-tourism services.
#   - Build climate-resilient supply chains and infrastructure (cold chain for fisheries, logistics hubs).
# - Years 11–20
#   - Scale new industries; promote innovation hubs and partnerships with regional and international research institutions to accelerate adaptation technologies.
#   - Strengthen regional integration; explore niche markets (ecotourism, immersive cultural experiences).
#
# Budget and funding
# - Domestic budget: 2–4% of GDP annually, rising to 4–6% during mid-period as new industries scale.
# - External funding: concessional loans and grants for sector-specific investments; potential private sector co-investments in eco-tourism, aquaculture, and logistics.
# - Rough cost envelope: $0.7–1.6B domestic; $0.8–1.8B external; total $1.5–3.4B over 20 years.
# - Measurable success metrics
#   - Diversification indicators: share of GDP from non-tourism sectors; employment mix by sector.
#   - Job creation rates; youth unemployment declines; SME survival.
#   - Energy mix: share of renewables; grid reliability metrics.
#   - Export growth in value-added products.
# - Risks and failure modes
#   - Tourism demand volatility; global crises; disease outbreaks affecting fisheries; over-reliance on any single sector.
#   - Financing gaps or cost overruns.
# - Contingency triggers
#   - If unemployment remains above baseline for two consecutive years, expand targeted retraining and microfinance programs; boost public procurement for local goods.
#   - If export demand declines globally, accelerate domestic market development and diversify sectors.
# - Assumptions and uncertainties
#   - Assumes consistent global demand for eco-tourism and sustainable seafood; assumes ability to attract technology transfer and investments.
#
# C. Legal/political status and rights for displaced citizens (including options for retaining statehood)
# Objective: Provide legal clarity and rights for displaced citizens, ensure continuity of state functions, and maintain or adapt statehood legitimacy.
#
# Timeline and concrete steps
# - Years 0–5
#   - Enshrine a climate-displacement rights framework, including: citizenship protections, family unity provisions, access to social services, and voting rights protections for relocated populations.
#   - Clarify legal status for displaced residents: temporary protections, long-term residency options, and paths to naturalization with rights matching residents’ circumstances.
#   - Begin constitutional and legal reforms to recognize climate displacement as a material factor in governance, with the option to adjust territorial sovereignty arrangements if needed (without undermining statehood).
# - Years 6–10
#   - Implement a “right to safe housing and livelihoods” baseline across relocated communities; ensure universal access to healthcare, education, and social protection.
#   - Establish a formal mechanism for return or re-claiming homeland rights if conditions allow, with sustainable criteria for return.
# - Years 11–20
#   - Stabilize legal frameworks around citizenship, voting rights, and representation for relocated residents, considering diaspora representation if necessary.
#   - If needed, explore constitutional amendments or interim special arrangements to preserve continuous statehood while ensuring inclusive governance.
#
# Budget and funding
# - Domestic: moderate legal-audit costs; implementation of rights-based programs within existing budgets; minimal new cost but some administrative overhead.
# - External: potential support from multilateral bodies for governance reform and rights protection; technical assistance grants.
#
# Measurable success metrics
# - Proportion of relocated residents with secure housing tenure and access to services.
# - Legal and administrative processing times for residency, citizenship, and rights protections.
# - Representation and participation metrics for relocated populations (voting access, local governance participation).
#
# Risks and failure modes
# - Political resistance to constitutional changes; disputes over sovereignty and relocation rights; risk of statelessness if not managed properly.
# - Contingency triggers
#   - If legal protections are delayed beyond Year 5, appoint an independent rights oversight body to accelerate implementation; provide temporary protections with sunset clauses.
# - Assumptions and uncertainties
#   - Assumes political will to reform and adapt the constitution; assumes international legal norms support rights protections.
#
# D. Cultural heritage preservation
# Objective: Preserve and celebrate cultural heritage, including intangible traditions, while ensuring that relocation does not erode identity.
#
# Timeline and concrete steps
# - Years 0–5
#   - Inventory and digitization of cultural assets (sites, stories, languages, crafts).
#   - Develop a Cultural Heritage Strategy with protections for endangered traditions, recipes, songs, and languages, including intergenerational transfer programs.
#   - Designate and protect key heritage sites; plan for virtual/physical accessibility and relocation considerations when sites are threatened.
# - Years 6–10
#   - Transfer or stabilize heritage sites that are at risk; establish heritage-based tourism experiences in safe zones that align with relocation plans.
#   - Fund culture-based education and intergenerational programs in both origin and relocation communities.
# - Years 11–20
#   - Build a national archive and digital museum; foster international partnerships to preserve and share heritage; ensure inclusion of diaspora narratives.
#   - Evaluate UNESCO or regional heritage status where applicable and pursue inscriptions when appropriate.
#
# Budget and funding
# - Domestic: modest, focused on cultural programs and digitization (tens of millions to low hundreds of millions over 20 years).
# - External: grants for cultural heritage preservation; partnerships with international organizations; museum and digital archive development funds.
# - Measurable success metrics
#   - Number of sites preserved/secured; number of intangible heritage practices documented; audience reach of heritage programs; presence of diaspora voices in cultural policy.
#
# Risks and failure modes
# - Underfunding could erode heritage preservation; misalignment with relocation priorities; cultural homogenization risks.
# - Contingency triggers
#   - If heritage loss accelerates, scale up digitization and community-led heritage programs; adjust relocation plans to protect culturally significant communities.
# - Assumptions and uncertainties
#   - Assumes community willingness to integrate heritage into relocation narratives; assumes stable external support for heritage initiatives.
#
# E. Environmental mitigation/adaptation
# Objective: Protect people and assets via a mix of nature-based solutions and infrastructure, while reducing ecological and climate risks.
#
# Timeline and concrete steps
# - Years 0–5
#   - Conduct a coastal vulnerability atlas; identify priority areas for hard protection and nature-based solutions (mangroves, reefs, living shorelines).
#   - Initiate mangrove restoration and reef-based protection along key coastlines; pilot nature-based flood mitigation in select zones.
#   - Develop disaster risk reduction (DRR) early warning systems and community preparedness programs.
# - Years 6–10
#   - Scale coastal protections (sea walls where needed, elevated structures, flood-proofed public facilities) and continue nature-based approaches.
#   - Implement land-use planning to avoid hazard-prone zones; invest in climate-resilient agriculture and water management (drought/flood resilience).
# - Years 11–20
#   - Maintain, retrofit, and upgrade defenses as climate data evolves; re-evaluate protective strategies with an adaptive-management framework.
#   - Expand green energy and water security to reduce climate-related vulnerabilities.
#
# Budget and funding
# - Domestic: 2–5% of GDP annually (depending on risk exposure and debt capacity); high initial investment phase.
# - External: grants and concessional loans for climate-resilience infrastructure; especially nature-based solutions with co-benefits.
# - Rough cost envelope: $1.0–1.8B domestic; $0.8–1.7B external; total $1.8–3.5B.
#
# Measurable success metrics
# - Percentage of coastline protected by natural and hybrid defenses.
# - Mangrove and reef restoration area; flood event frequency reduction; early-warning reach and effectiveness.
# - Reliability and performance of critical public services during flood events.
#
# Risks and failure modes
# - Inadequate protection where inundation exceeds defenses; ecological trade-offs; land-use conflicts.
# - Contingency triggers
#   - If flood damages exceed forecasted levels for two consecutive years, reallocate funds to accelerate protective measures; increase nature-based solutions.
# - Assumptions and uncertainties
#   - Assumes climate projections and flood modeling are sufficiently reliable to prioritize protections; assumes maintenance capacity and governance to sustain defenses.
#
# Section 3. Governance, implementation, and funding architecture
# - Institutions
#   - National Climate Change Authority (NCCA) to coordinate across sectors.
#   - National Relocation Authority (NRA) for relocation/housing; an Independent Rights Ombudsperson for displacement-related matters.
#   - Cultural Heritage Council; Coastal Resilience Agency for environmental protections.
#   - Disaster Risk Reduction Command (DRRC) for emergency planning and response.
# - Financing mix
#   - Domestic budget allocations: 30–50% of total program funding, with annual targets tied to GDP and revenues.
#   - External funding: 50–70% of total program funding; prioritize grants and concessional loans; blend with diaspora investments and private-sector co-financing.
#   - Climate finance instruments: grants, concessional loans, sovereign green bonds, catastrophe risk insurance/public-private partnerships.
# - Transparency and accountability
#   - Public dashboards with milestone reporting; independent audits; community oversight committees.
# - Contingency planning
#   - Trigger events: failure to meet key milestones, funding shortfalls, or escalating disaster risks; policy adjustments to re-prioritize or reallocate resources.
#
# Section 4. Two high-level policy approaches: in-place adaptation vs planned retreat/relocation
#
# Approach 1: In-place adaptation (protect and buttress the capital and arable land)
# - Core idea: Invest heavily in hard defenses (seawalls, raised platforms), flood-proofing, pumped drainage, and selective land reclamation to keep the capital and 40% of arable land in their current locations.
# - Pros
#   - Preserves current population distribution; continuity of government, services, and identity in the near term.
#   - Potentially lower disruption to existing communities and livelihoods if defenses work.
# - Cons and ethical considerations
#   - High costs and risk of failure if sea-level rise accelerates; long-term burden on future generations; inequitable outcomes if defense advantages accrue to those in protected zones while others remain exposed or displaced.
#   - Intergenerational justice concerns: present-day investment commitments may overwhelm future capacity, and if protections fail or degrade, vulnerable groups bear the brunt.
# - Funding and cost profile
#   - Very high upfront capital costs; ongoing maintenance; reliance on long-term external financing and risk transfer (insurance, guarantees).
# - Contingency risks
#   - If climate risks outpace protection, asset losses could be catastrophic; governance debates around ongoing funding and equity.
#
# Approach 2: Planned retreat/relocation (staged, rights-based relocation)
# - Core idea: Proactively move populations, livelihoods, and critical assets away from high-risk zones to higher ground or new settlements, with a rights-based framework and robust protections for citizenship, livelihoods, and culture.
# - Pros
#   - Reduces exposure to escalating climate risks; more predictable planning environment; can unlock safer, more sustainable long-term development.
# - Cons and ethical considerations
#   - Dislocation costs, cultural disruption, and potential loss of sense of place; risks of unequal treatment where some communities receive infrastructure while others do not; potential impacts on minority or vulnerable groups during relocation.
# - Funding and cost profile
#   - Domestic and external funding balanced to cover housing, infrastructure, services, and livelihoods in relocated areas; upfront investments offset by long-term resilience gains.
# - Contingency risks
#   - Political resistance to relocation; social fracture if relocation is perceived as coercive; insufficient housing supply or job opportunities in relocation areas.
#
# Ethical trade-offs between approaches
# - Intergenerational justice: In-place adaptation can defer relocation costs but raises the risk of catastrophic loss for future generations if protections fail; planned retreat spreads the burden more evenly across generations but concentrates costs now.
# - Rights of vulnerable groups: A plan that focuses on in-situ defense may privilege those who own protected assets, at the expense of marginalized groups who bear higher relative risk; a relocation-focused plan must ensure not to coerce or disproportionately disadvantage any group and must guarantee access to services, livelihoods, and cultural continuity.
# - Justice in voice and participation: A relocation strategy that embeds community-led decision-making, consent, and fair compensation can be more ethically robust than a defense-heavy plan that marginalizes communities.
#
# Section 5. Recommendation and justification
# - The single best policy recommendation: Adopt a hybrid “managed retreat with targeted in-situ adaptation” approach.
#   - Why this is robust across scenarios:
#     - It acknowledges that some areas (especially the capital core and critical arable zones) are high-value, high-risk assets best protected in the near term with targeted defenses, while more exposed areas and populations are relocated in a rights-based, predictable, and participatory way.
#     - It aligns with equity and human rights obligations by ensuring protections, housing, and livelihoods for relocated populations and by preserving cultural heritage and citizenship status.
#     - It is flexible to climate and geopolitical uncertainties: if adaptation costs rise or external aid wanes, the plan can lean more toward retreat in later phases; if climate signals permit, protections can be expanded or refined.
#     - It provides a clear governance and financing framework with phased milestones and contingency triggers, reducing the risk of abrupt, destabilizing shifts.
#   - Operationally, this means:
#     - In the near term (Years 0–5): halt escalation of risk in the capital by deploying a mix of nature-based solutions and critical defenses, while launching the relocation program for the most exposed communities and initiating new safe settlements.
#     - Mid-term (Years 6–15): scale relocation, complete a majority of housing and livelihoods in relocated areas, and consolidate economic diversification; continuously upgrade defenses where cost-effective and necessary for core services.
#     - Long-term (Years 16–20): consolidate gains, re-evaluate risk, adapt to new climate projections, and maintain flexible paths for potential returns or further relocation if conditions permit.
#   - Ethical guardrails: insist on a participatory relocation process; ensure universal access to rights and services; maintain diaspora engagement to sustain cultural and political legitimacy; prioritize vulnerable groups in every phase.
#
# Section 6. Implementation-ready plan: 12–24 month action map (highlights)
# - Governance and institutions
#   - Establish NRA, NCCA, and Coastal Resilience Agency; appoint an Independent Rights Ombudsperson.
#   - Create cross-ministerial coordinating committees for housing, livelihoods, heritage, and DRR.
# - Financing and instruments
#   - Set up a National Climate Resilience Fund; issue sovereign green bonds; explore blended finance with development banks.
#   - Formalize a diaspora investment framework; guarantee investment-friendly conditions for relocation housing and green infrastructure.
# - People and communities
#   - Complete risk and vulnerability census; launch relocation beneficiary selection with inclusive, transparent criteria.
#   - Initiate social protection expansions; begin vocational retraining and entrepreneurship support aligned with relocation sites.
# - Housing and settlement
#   - Finalize master plans for 2–3 new safer towns; commence construction of early housing clusters (5,000–8,000 units) and essential services.
#   - Implement land tenure reforms in relocation areas; provide secure housing rights.
# - Economic diversification
#   - Launch pilots in climate-smart agriculture, sustainable seafood processing, and eco-tourism in relocation zones.
#   - Expand renewable energy and grid resilience; advance inter-island logistics links.
# - Environment and heritage
#   - Initiate mangrove restoration and coastal habitat projects; digitize cultural heritage assets; establish protected heritage zones near relocation sites.
# - Monitoring and risk management
#   - Create a climate-risk dashboard with annual independent evaluations; set trigger thresholds for accelerating or adjusting strategy.
#
# Key assumptions and uncertainties (transparent)
# - Assumptions
#   - External climate finance will be available at predictable terms; there is political will to pursue relocation, rights protections, and heritage preservation; land is available for relocation and safe settlements; diaspora capital is accessible.
# - Major uncertainties
#   - Climate trajectory (rate of sea-level rise, extreme events); economic shocks that affect tourism and fisheries; donor fatigue and policy shifts in neighboring states; feasibility and costs of large-scale in-situ defenses.
# - Risks of misestimation
#   - Over- or under-estimating relocation needs could lead to housing shortfalls or misallocated funds; failure to engage communities could undermine legitimacy.
#
# Narrative wrap-up: what success would look like in 20 years
# - People live in secure homes with reliable access to services in relocated areas, while essential government functions and critical services are safeguarded in a protected core.
# - The economy has diversified beyond tourism and small-scale fishing toward climate-resilient industries, with stable livelihoods for relocated populations and new settlements.
# - Legal provisions provide rights and protections for displaced citizens, with clear pathways for naturalization or residency and sustained citizenship assurances to preserve statehood legitimacy.
# - Cultural heritage is preserved through a combination of digitization, preservation of living practices, and heritage tourism that respects communities.
# - Coastal environments are strengthened through nature-based and hybrid infrastructure strategies, with effective early warning and DRR systems.
#
# Closing note
# - The plan emphasizes equity, adaptability, and the long-term viability of the nation-state. It recognizes the moral imperative to safeguard the most vulnerable while maintaining national sovereignty and cultural integrity. The hybrid approach balances the near-term necessity of protecting core assets and services with the long-term resilience gained by orderly relocation, thereby maximizing the odds of a robust, just, and prosperous trajectory under a wide range of climate and geopolitical conditions.
# Competitor: gemini-2.5-flash
#
# As Chief Policy Planner for our sovereign island nation, I present this urgent 20-year strategy to navigate the existential threat of sea-level rise. Our nation of 200,000 faces an unprecedented challenge: the annual inundation of our capital and 40% of our arable land within two decades. Our current reliance on tourism and small-scale fishing, combined with a limited national budget (GDP $1.5B, reserves covering ~3 years of spending), hostile neighboring migration policies, and uncertain international aid, demands a bold, proactive, and self-reliant approach.
#
# Our overarching vision is to secure the long-term survival, prosperity, and cultural identity of our people and nation, even as our physical geography transforms. This strategy acknowledges the inevitability of significant physical changes and prioritizes strategic adaptation and relocation over futile resistance.
#
# ---
#
# ### **Overarching Strategy: Proactive Resilience & Managed Transformation**
#
# Our strategy centers on a **Proactive Resilience & Managed Transformation** approach, blending strategic retreat from the most vulnerable areas with targeted adaptation for essential infrastructure and ecological assets, while fundamentally restructuring our economy and legal framework to ensure national continuity.
#
# ---
#
# ### **Detailed 20-Year Strategy Elements**
#
# **Assumptions & Uncertainties:**
# *   **Assumptions:**
#     *   Sufficient suitable higher ground exists within our sovereign territory for a new capital and resettled communities.
#     *   International climate finance mechanisms (e.g., GCF, Adaptation Fund) will provide *some* level of support, though not comprehensive.
#     *   Our citizens, while potentially resistant initially, will ultimately engage constructively in the planning and implementation process.
#     *   Basic international legal principles (e.g., non-refoulement) will continue to hold, even if specific 'climate refugee' status is denied.
# *   **Uncertainties:**
#     *   The precise rate and severity of sea-level rise and associated storm surges.
#     *   The extent and timing of international financial and technical assistance.
#     *   Geopolitical stability and the willingness of international partners to engage in novel legal concepts like "statehood without contiguous territory."
#     *   The social cohesion and psychological impact of mass internal displacement.
#
# ---
#
# #### **(a) Equitable Human Relocation and Housing**
#
# *   **Goal:** Safely and equitably relocate 100% of at-risk populations and infrastructure to secure, sustainable locations within national territory by Year 20, with minimal social disruption.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-3: Assessment & Planning Phase**
#         *   **0-1:** National Vulnerability & Resettlement Suitability Assessment (NVRS): Map all at-risk areas, identify and survey suitable high-ground locations (geology, water, biodiversity, land ownership). Public consultations initiated.
#         *   **1-2:** Develop National Resettlement Master Plan (NRMP): Detailed plans for new urban centers and agricultural zones, infrastructure (roads, utilities, communication), and community facilities. Legal framework for land acquisition/compensation.
#         *   **2-3:** Pilot Relocation Program (1-2 small communities, ~500 people): Test planning assumptions, identify challenges, refine processes.
#     *   **Years 4-15: Implementation & Phased Relocation**
#         *   **4-8:** Infrastructure Development Phase I: Begin construction of essential roads, power grids, water/sanitation, and initial public buildings in designated new capital and key resettlement sites.
#         *   **6-15:** Phased Community Relocation: Systematically relocate populations from most vulnerable areas. Prioritize communities most impacted by annual flooding and critical government functions. Housing construction using resilient, modular, and locally appropriate designs.
#         *   **10-15:** Infrastructure Development Phase II: Expand and consolidate new urban centers, build schools, hospitals, commercial zones.
#     *   **Years 16-20: Consolidation & Final Relocation**
#         *   **16-20:** Finalize relocation of remaining at-risk populations and transfer of all critical government functions to the new capital. Decommission and ecologically restore abandoned sites where feasible.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $800M - $1.2B over 20 years (53-80% of current GDP).
#     *   **Budget Allocation:** 30% of annual national budget for capital projects; remainder from external funding.
#     *   **External Funding Sources:** Green Climate Fund (GCF), Adaptation Fund, World Bank/ADB concessional loans, bilateral aid from climate-resilient partners (e.g., Japan, Netherlands, EU).
# *   **Measurable Success Metrics:**
#     *   95% of identified at-risk population successfully relocated by Year 20.
#     *   80% of relocated households report satisfaction with new housing and community services within 5 years of relocation.
#     *   Construction of new capital and infrastructure on schedule and within 15% of budget.
#     *   No loss of life due to sea-level rise flooding post-Year 15.
# *   **Key Risks & Failure Modes:**
#     *   **Social Resistance:** Reluctance to move, loss of traditional lands/livelihoods, perceived inequity.
#     *   **Land Scarcity/Conflict:** Insufficient suitable land, disputes over land ownership on higher ground.
#     *   **Funding Shortfall:** Inadequate external aid or domestic budget allocation.
#     *   **Infrastructure Failure:** Poor planning or execution of new infrastructure.
#     *   **Psychological Trauma:** Mental health impacts of displacement.
# *   **Contingency Triggers:**
#     *   **Slower SLR:** Allows for extended timelines, re-prioritization to economic development.
#     *   **Faster SLR:** Accelerate relocation timelines, prioritize critical infrastructure transfer, request emergency international aid.
#     *   **Major Funding Shortfall:** Scale back non-essential infrastructure, focus on basic housing, explore innovative financing (e.g., diaspora bonds), potentially seek direct humanitarian aid for housing.
#     *   **Widespread Social Resistance:** Halt forced relocation, launch intensive community engagement campaigns, revise compensation packages, involve anthropologists/sociologists in planning.
#
# ---
#
# #### **(b) Economic Transition and Livelihood Preservation**
#
# *   **Goal:** Diversify the national economy away from vulnerable coastal sectors, create resilient livelihoods for 90% of the working population, and increase GDP per capita by 25% by Year 20.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Foundation & Capacity Building**
#         *   **0-2:** Economic Vulnerability & Opportunity Assessment: Identify sectors resilient to SLR and attractive for investment (e.g., aquaculture in protected areas, deep-sea fishing, renewable energy, specialized agriculture, tech/BPO services, high-value niche tourism on higher ground).
#         *   **1-4:** National Skills Development & Retraining Program: Establish vocational schools and partnerships for training in identified growth sectors. Prioritize displaced fishers and tourism workers.
#         *   **3-5:** Renewable Energy Transition Plan: Phased shift to solar/wind power, reducing reliance on imported fossil fuels. Attract investment in this sector.
#     *   **Years 6-15: Investment & Sector Growth**
#         *   **6-10:** Develop Agri-Tech & Sustainable Aquaculture Zones: Establish new, elevated agricultural zones using climate-smart practices (hydroponics, vertical farms) and inland/protected aquaculture facilities.
#         *   **8-15:** Foster High-Tech & Services Sector: Create dedicated tech parks, incentivize foreign investment in data centers, call centers, and digital services. Develop fiber optic infrastructure.
#         *   **10-15:** Niche Tourism Development: Promote eco-tourism, cultural tourism, and high-value low-impact tourism on higher ground and protected marine areas.
#     *   **Years 16-20: Consolidation & Export Readiness**
#         *   **16-20:** Expand export capabilities for new sectors. Establish Free Trade Zones in new economic hubs. Support small and medium enterprises (SMEs) with business incubation and microfinance.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $500M - $750M over 20 years (33-50% of current GDP).
#     *   **Budget Allocation:** 25% of annual national budget for economic development, education, and subsidies.
#     *   **External Funding Sources:** Multilateral development banks (World Bank, ADB), private sector investment (e.g., for tech, renewable energy), bilateral development aid.
# *   **Measurable Success Metrics:**
#     *   New economic sectors contribute 50% of GDP by Year 20 (up from <5% currently).
#     *   Unemployment rate for relocated populations remains below 10%.
#     *   70% of displaced workers successfully retrained and employed in new sectors.
#     *   Renewable energy sources account for 80% of national energy consumption by Year 20.
# *   **Key Risks & Failure Modes:**
#     *   **Market Failure:** New industries fail to attract investment or find markets.
#     *   **Skill Mismatch:** Training programs do not align with industry needs.
#     *   **Brain Drain:** Educated youth leave the country for better opportunities.
#     *   **Competition:** Inability to compete with larger economies.
# *   **Contingency Triggers:**
#     *   **Economic Downturn:** Implement emergency stimulus packages, prioritize direct cash transfers for displaced workers, double down on attracting foreign direct investment with enhanced incentives.
#     *   **Low uptake in new sectors:** Re-evaluate training programs, offer more attractive startup grants, conduct market research for alternative industries.
#     *   **High Brain Drain:** Implement retention schemes, provide subsidized housing/healthcare for skilled workers, foster a vibrant social and cultural environment.
#
# ---
#
# #### **(c) Legal/Political Status and Rights for Displaced Citizens (Retaining Statehood)**
#
# *   **Goal:** Secure international recognition for our nation's sovereignty and citizenship rights for all citizens, irrespective of physical displacement, by Year 20. Establish legal frameworks for national continuity.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Legal Foundations & Advocacy**
#         *   **0-2:** Establish a Presidential Commission on Statehood Continuity (PCSC): Comprising legal experts, diplomats, and community leaders to research international precedents and develop a legal strategy.
#         *   **1-3:** Constitutional Review & Amendments: Prepare amendments to define national territory and citizenship in a manner resilient to physical changes (e.g., focus on maritime zones, cultural/historical claims, and a "state in trust" concept).
#         *   **2-5:** International Advocacy Campaign Phase I: Engage the UN, AOSIS, specific nations (e.g., Pacific Forum members, powerful allies) on the concept of "statehood without contiguous land" or "deterritorialized sovereignty." Focus on maintaining UN membership and voting rights.
#     *   **Years 6-15: Legal Implementation & Bilateral Treaties**
#         *   **6-10:** Enact domestic legislation safeguarding rights of internally displaced persons (IDPs): Ensuring access to services, property rights, and political participation.
#         *   **8-15:** Pursue Bilateral Agreements: Seek treaties with key nations to recognize our continued statehood and citizenship rights for our people, potentially including agreements for consular services or even temporary residence options in extreme scenarios (without implying mass migration).
#     *   **Years 16-20: Consolidation & Future Proofing**
#         *   **16-20:** Finalize international legal strategy. Establish a "Sovereign Trust Fund" from salvaged national assets and international contributions to secure a permanent home (physical or virtual) for our nation's identity and governance. Explore creation of a "digital nation" platform.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $100M - $200M over 20 years (6.7-13% of current GDP).
#     *   **Budget Allocation:** 5% of annual national budget for legal fees, diplomatic efforts, and international representation.
#     *   **External Funding Sources:** Philanthropic organizations focused on climate justice, specific international legal funds, technical assistance from UN bodies, grants from nations interested in international legal precedents.
# *   **Measurable Success Metrics:**
#     *   Maintenance of UN membership and voting rights.
#     *   Bilateral treaties for statehood recognition with at least 10 key nations by Year 20.
#     *   Domestic legal framework fully in place protecting IDP rights.
#     *   No citizens rendered stateless by Year 20.
#     *   Establishment of a widely recognized "Sovereign Trust Fund" or similar entity.
# *   **Key Risks & Failure Modes:**
#     *   **International Non-recognition:** Major powers refuse to acknowledge deterritorialized sovereignty.
#     *   **Statelessness:** Citizens lose their nationality if the state is deemed to cease to exist.
#     *   **Loss of Voice:** Inability to participate in international forums.
#     *   **Internal Division:** Disagreement on the concept of statehood.
# *   **Contingency Triggers:**
#     *   **Major power refusal of deterritorialized sovereignty:** Focus on achieving regional recognition, bolster economic ties to leverage influence, explore "associated state" models with a larger nation, intensify advocacy for 'cultural sovereignty'.
#     *   **Loss of UN seat:** Redouble efforts for observer status, focus on gaining recognition through bilateral agreements, shift focus to a "diaspora nation" model.
#     *   **Citizenship challenges abroad:** Launch global legal aid funds for citizens, engage international human rights organizations.
#
# ---
#
# #### **(d) Cultural Heritage Preservation**
#
# *   **Goal:** Preserve 100% of tangible and intangible cultural heritage identified as at-risk due to SLR by Year 15, and integrate it into the national identity in new settlements.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Documentation & Digitalization**
#         *   **0-3:** Comprehensive Cultural Heritage Inventory: Map all significant cultural sites, historical buildings, archaeological areas, and intangible heritage (oral histories, traditional practices, languages). Prioritize most vulnerable sites.
#         *   **1-5:** Digital Archiving Project: High-resolution scanning, photogrammetry, 3D modeling of at-risk tangible heritage. Extensive oral history recording, video documentation of rituals, dances, and traditional skills. Establish a secure national digital archive.
#     *   **Years 6-15: Physical Preservation & Integration**
#         *   **6-10:** Strategic Relocation & Preservation: Carefully relocate or reconstruct iconic cultural artifacts and smaller, portable structures to new cultural centers in the elevated capital. Establish climate-controlled national museum in the new capital.
#         *   **8-15:** Community Cultural Centers: Build dedicated cultural centers in each new settlement to foster traditional arts, language, and storytelling. Integrate heritage narratives into new urban planning.
#     *   **Years 16-20: Legacy & Global Outreach**
#         *   **16-20:** Curriculum Integration: Ensure cultural heritage is a core part of the national education curriculum.
#         *   **18-20:** International Collaboration: Partner with UNESCO and other international cultural institutions to safeguard digital archives and promote global awareness of our disappearing heritage.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $75M - $125M over 20 years (5-8% of current GDP).
#     *   **Budget Allocation:** 3% of annual national budget for cultural preservation.
#     *   **External Funding Sources:** UNESCO, World Monuments Fund, Getty Foundation, bilateral aid from culturally sensitive nations, philanthropic organizations.
# *   **Measurable Success Metrics:**
#     *   100% of at-risk tangible heritage digitally archived by Year 5.
#     *   80% of identified intangible heritage documented and archived by Year 10.
#     *   At least 5 major cultural artifacts or structures successfully relocated/reconstructed.
#     *   Establishment of 5+ vibrant community cultural centers in new settlements.
#     *   National language proficiency maintained or increased among youth by Year 20.
# *   **Key Risks & Failure Modes:**
#     *   **Loss Before Preservation:** Rapid SLR or sudden events destroy sites before documentation.
#     *   **Technological Obsolescence:** Digital formats become unreadable.
#     *   **Loss of Context:** Heritage loses meaning when removed from original environment.
#     *   **Lack of Community Engagement:** Heritage preservation efforts fail to resonate locally.
# *   **Contingency Triggers:**
#     *   **Accelerated SLR affecting heritage sites:** Prioritize emergency salvage and rapid digitalization; partner with marine archaeologists for underwater sites.
#     *   **Low community engagement:** Revamp engagement strategies, offer community-led heritage initiatives, provide direct funding for local cultural groups.
#     *   **Funding shortfall:** Focus solely on digital archiving, rely on volunteer efforts, seek smaller grants for specific projects.
#
# ---
#
# #### **(e) Environmental Mitigation/Adaptation**
#
# *   **Goal:** Implement strategic environmental adaptations to protect critical non-relocatable assets, enhance ecological resilience, and secure vital ecosystem services for the remaining land by Year 10.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Strategic Protection & Ecosystem Restoration**
#         *   **0-2:** Critical Infrastructure Protection Plan: Identify essential, non-relocatable infrastructure (e.g., main port, airport – requiring significant investment for relocation) and develop targeted, high-cost coastal defense plans (sea walls, dykes). *Note: This is highly selective, not a general defense strategy.*
#         *   **1-5:** Large-Scale Mangrove & Coral Reef Restoration Program: Prioritize natural coastal defenses. Restore degraded mangrove forests and coral reefs for their protective and biodiversity benefits.
#         *   **3-5:** National Water Security Plan: Implement rainwater harvesting, groundwater management, and strategic desalination plants in new settlements.
#     *   **Years 6-15: Sustainable Resource Management**
#         *   **6-10:** Sustainable Land Use Planning: Implement strict zoning for remaining high ground, protecting critical ecosystems and water sources. Promote permaculture and agroforestry.
#         *   **8-15:** Waste Management & Circular Economy: Develop modern waste management facilities (waste-to-energy where feasible) and promote circular economy principles.
#     *   **Years 16-20: Monitoring & Advanced Adaptation**
#         *   **16-20:** Climate Monitoring & Early Warning Systems: Install advanced sensors for sea-level, weather, and ocean conditions. Develop robust early warning systems for storms and coastal inundation.
#         *   **18-20:** Research & Development: Invest in local R&D for climate-resilient crops, aquaculture techniques, and renewable energy innovations.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $300M - $500M over 20 years (20-33% of current GDP).
#     *   **Budget Allocation:** 15% of annual national budget for environmental projects and infrastructure.
#     *   **External Funding Sources:** Global Environment Facility (GEF), Adaptation Fund, UN Environment Programme, bilateral aid for specific climate projects, conservation NGOs.
# *   **Measurable Success Metrics:**
#     *   50% increase in mangrove coverage and 20% increase in live coral cover by Year 10.
#     *   Access to potable water for 95% of the population in new settlements.
#     *   Reduced damage to critical port/airport infrastructure by 70% post-Year 15.
#     *   Effective waste management system implemented in all major settlements.
#     *   Early warning systems successfully alert 90% of population before extreme weather events.
# *   **Key Risks & Failure Modes:**
#     *   **Overwhelmed Defenses:** Sea walls/dykes fail against extreme events or accelerated SLR.
#     *   **Ecosystem Collapse:** Restoration efforts fail due to continued climate stress or pollution.
#     *   **Water Scarcity:** Insufficient freshwater sources for growing populations.
#     *   **Resource Depletion:** Over-extraction of fish or other natural resources.
# *   **Contingency Triggers:**
#     *   **Faster ecosystem degradation:** Increase investment in restoration, explore more aggressive conservation measures (e.g., marine protected areas), seek emergency ecological funding.
#     *   **Failure of hard defenses:** Re-evaluate and potentially decommission assets, accelerate relocation from those areas, focus solely on natural defenses.
#     *   **Water shortages:** Implement stricter water rationing, invest in additional desalination capacity, explore inter-island water transfer (if feasible).
#
# ---
#
# ### **Comparison of Alternative High-Level Approaches**
#
# #### **1. Approach Centered on In-Place Adaptation (Status Quo++):**
#
# *   **Focus:** Intensive protection of existing coastal areas, infrastructure, and agricultural lands through large-scale engineering.
# *   **Key Strategies:** Massive sea walls, dikes, polders, land reclamation, elevating existing buildings and infrastructure, extensive pumping systems, salt-tolerant crops.
# *   **Ethical Trade-offs:**
#     *   **Intergenerational Justice:** This approach prioritizes the *immediate* preservation of existing communities and assets for the current generation. However, it likely burdens future generations with a perpetually escalating maintenance cost, a constant battle against rising seas, and the risk of catastrophic failure (e.g., a dike breaking). It defers the inevitable decision, potentially leaving future generations with fewer resources and options.
#     *   **Rights of Vulnerable Groups:** While appearing to keep communities together, this approach could disproportionately affect the poor. Expensive adaptations like elevating homes or building private defenses are beyond the reach of many. Those unable to adapt might be marginalized or forced to leave anyway, creating an "adaptation apartheid." Furthermore, the engineering solutions often destroy natural habitats that vulnerable groups rely on for livelihoods (e.g., fishing grounds, mangrove forests).
# *   **Viability for our Nation:** Given "annual flooding of capital and 40% of arable land in 20 years," this approach is **untenable and represents maladaptation.** The scale of engineering required for continuous protection against annual flooding of such a large and vital area would be astronomically expensive, likely beyond our GDP, and unsustainable in the long term. It would merely delay the inevitable and potentially lead to a more abrupt, catastrophic failure later.
#
# #### **2. Approach Centered on Planned Retreat/Relocation (Managed Transformation):**
#
# *   **Focus:** Proactive and strategic movement of populations, infrastructure, and economic activities to safer, higher ground within national territory.
# *   **Key Strategies:** Comprehensive national resettlement plans, development of new urban centers and agricultural zones, economic diversification towards resilient sectors, legal frameworks for statehood continuity.
# *   **Ethical Trade-offs:**
#     *   **Intergenerational Justice:** This approach demands significant sacrifices from the *current* generation (dislocation, disruption of livelihoods, loss of ancestral lands) but aims to secure a viable, sustainable future for *future* generations. It is a long-term investment in national survival, reducing future vulnerability and the burden of constant climate defense. It enables a proactive response, minimizing future crisis-driven migration.
#     *   **Rights of Vulnerable Groups:** The risks here are significant if not managed equitably. Forced relocation can be traumatic, leading to loss of social networks, identity, and livelihoods. It risks dispossessing landholders on higher ground or creating new inequalities if relocation benefits are not distributed fairly. However, with careful planning, robust compensation frameworks, community participation, and dedicated support services, it offers the opportunity to build *more resilient and equitable* communities with improved infrastructure and access to services, potentially uplifting marginalized groups in the long run. The strategy above specifically addresses these risks through equitable planning and social support.
# *   **Viability for our Nation:** This approach is **the only viable long-term solution** for our nation given the specific threats outlined. While challenging, it directly confronts the physical reality of impending inundation and offers a pathway to national continuity.
#
# ---
#
# ### **Single Best Policy Recommendation and Robustness**
#
# My single best policy recommendation is the **Proactive Resilience & Managed Transformation** strategy, fundamentally centered on **Planned Retreat/Relocation** as the overarching principle, complemented by strategic, targeted environmental adaptation.
#
# **Why it is Robust Across Optimistic and Pessimistic Climate and Geopolitical Scenarios:**
#
# 1.  **Directly Addresses the Core Physical Threat:** The "annual flooding of capital and 40% of arable land" makes pure in-place adaptation a fantasy. Planned retreat is the only strategy that acknowledges this reality and offers a sustainable physical future for our people within our borders.
# 2.  **Adaptive Capacity:**
#     *   **Optimistic Climate Scenario (Slower SLR):** If SLR is slower than predicted, the planned retreat provides a longer transition period, allowing for more careful planning, better infrastructure development, and smoother social adjustment. Resources initially allocated for rapid relocation can be redirected to further economic diversification, enhanced social services in new settlements, and more robust long-term infrastructure. The national budget gains breathing room.
#     *   **Pessimistic Climate Scenario (Faster SLR/Extreme Events):** If SLR accelerates or extreme weather events become more frequent, the framework for planned retreat is already established. Early investments in vulnerability assessments, legal frameworks, and initial infrastructure mean the nation is better prepared to accelerate relocation, declare emergencies, and quickly access international humanitarian aid. It shifts from reactive crisis management to a proactive, albeit faster, implementation of an existing plan.
# 3.  **Economic Resilience:** By diversifying our economy away from vulnerable coastal sectors and investing in new, resilient industries (aquaculture, tech, renewables), we build an economy less susceptible to climate impacts. This protects livelihoods and secures financial stability, regardless of the precise climate trajectory. This also makes us less dependent on a single industry (tourism) which is itself vulnerable to global shocks (pandemics, economic crises) as well as climate change.
# 4.  **Geopolitical Independence:** The strategy prioritizes internal solutions for relocation and livelihood, reducing reliance on neighboring states for mass migration (which they have refused). Our proactive legal strategy for "statehood continuity" aims to secure our sovereignty and international standing, offering a dignified future even if our physical land mass shrinks considerably.
#     *   **Optimistic Geopolitical Scenario (Increased Aid/Recognition):** Strong international support (financial, technical, legal) accelerates the implementation of our strategy, allowing for higher quality housing, faster economic transition, and smoother international legal recognition of our statehood.
#     *   **Pessimistic Geopolitical Scenario (Limited Aid/Non-recognition):** While challenging, the strategy's emphasis on self-reliance (internal relocation, domestic economic diversification, constitutional amendments) means our nation is not solely dependent on external goodwill. We build foundational resilience. The international advocacy campaign continues, but our survival is not predicated on immediate external approval for novel legal concepts. We prepare for a scenario where we manage our destiny primarily through our own means.
# 5.  **Ethical Responsibility:** While demanding immediate sacrifices, planned retreat is ethically superior for intergenerational justice. It ensures a future for our nation and people, rather than condemning successive generations to a losing battle. The strategy includes explicit measures for equitable relocation and cultural preservation, aiming to mitigate the trauma of displacement and build a new, resilient national identity.
#
# In conclusion, "Proactive Resilience & Managed Transformation" through a managed, equitable planned retreat is not merely an option; it is an imperative. It represents the most robust and ethically sound path forward to secure the future of our sovereign island nation in the face of an undeniable climate crisis.
# Competitor: llama3.2
#
# I. Equitable Human Relocation and Housing (5 years, $100M, 7% of national budget)
#
# 1. Conduct inclusive, national-level public consultations (Year 1, $5M) to gather information on existing relocation plans and social, economic, and cultural impacts.
# 2. Establish a National ReLocation Committee (Year 2, $3M) to coordinate a systematic relocation strategy with international guidance on fair distribution, compensation, and social services.
# 3. Construct transitional housing (Year 1-2, $50M) near former flood zones with a mix of affordable and accessible options.
# 4. Implement a fair compensation system (Year 3-5, $30M) that considers the needs and interests of 70% of displaced citizens.
#
# Measurable success metrics: public acceptance rate > 70%, relocation rate > 50% of high-risk area populations.
#
# Key risks and failure modes: public mistrust, insufficient funding, lack of social services.
#
# Contingency triggers: negative consultations outcomes, failure of national consultation engagement.
#
# Assumptions and uncertainties: 10% change in population distribution
#
# II. Economic Transition and Livelihood Preservation (5 years, $500M, 33% of national budget)
#
# 1. Develop and implement a 4-year education and vocational training program (Year 2-5, $100M) for 300,000 small-scale fishermen and 100,000 tourism-related workers.
# 2. Revitalize non-coastal industries through incentives (Year 2-5, $50M) to promote innovation, job creation, and fair labor practices.
# 3. Establish a National Livelihood Fund (Year 1, $50M) to guarantee basic income levels for 60% of citizens.
#
# Measurable success metrics: successful traineeship rate > 50%, increase in coastal non-fishing sector by 15%.
#
# Key risks and failure modes: economic volatility, loss of expertise.
#
# Contingency triggers: government policy shift towards rapid relocation or significant economic fluctuations.
#
# Assumptions and uncertainties: 5% change in GDP growth rate
#
# III. Legal/Political Status and Rights for Displaced Citizens (5 years, $200M, 13% of national budget)
#
# 1. Establish a National Commission for the Rights of Relocation (Year 1, $30M) based on guidelines from international human rights and environmental law.
# 2. Negotiate international cooperation agreements (Year 2, $100M) on displacement impacts on citizenship rights.
#
# Measurable success metrics: acceptance of national human rights protection norms > 80%.
#
# Key risks and failure modes: failure to engage with relevant international governing entities.
#
# Contingency triggers: international refusal to engage, public discontent with human rights standards.
#
# Assumptions and uncertainties: 10% decline in trust of local institutions
#
# IV. Environmental Mitigation/Adaptation (5 years, $500M, 33% of national budget)
#
# 1. Construct coastal barrier system (Year 2-5, $250M) using the most favorable design options.
# 2. Conduct research on sustainable coastal land management (Year 1-2, $50M) and initiate pilot projects for innovative techniques.
#
# Measurable success metrics: 20% increase in projected water depth protection.
#
# Key risks and failure modes: technical complexity issues, public resistance.
#
# Contingency triggers: public discontent, funding shortfalls due to budget constraints.
#
# Assumptions and uncertainties: 10% change in sea-level rise predicted.
#
# V. Environmental Mitigation/Adaptation Alternative (Planned Retreat/Relocation): focus on relocating 90% of population to upperlands before projected flooding and maintaining 10% population in the capital area, prioritizing security, climate and ecological resilience, and human well-being over economic and cultural heritage preservation.
#
# Key benefits: secure future for remaining population, preservation of cultural heritage and biodiversity.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Executive summary
# - Context: A small, low-lying island nation of 200,000 people faces annual flooding of its capital and 40% of arable land within ~20 years due to sea-level rise. The economy depends on tourism and small-scale fishing. GDP is about $1.5B. Emergency reserves cover roughly three years of current spending. Neighbors won’t accept mass migrants; external aid is uncertain.
# - Core objective: A 20-year, prioritized strategy that protects people, preserves livelihoods, safeguards rights and statehood, preserves cultural heritage, and builds resilient environment and economy. The plan emphasizes equity, transparency, and adaptive management.
# - Overall cost/financing sketch: Total program cost in the 20-year horizon is roughly $2.8–3.5B (order of magnitude). Domestic budget allocations will cover a substantial but minority share (roughly 30–40% of the total), with the remainder funded by external sources (grants, concessional loans, climate finance, diaspora investments, and blended finance). Annual domestic allocations will ramp from ~3–7% of GDP early on to ~5–8% later, depending on revenue and debt capacity.
# - Recommendation (single best policy): A hybrid “managed retreat with targeted in-situ adaptation” approach. Protect critical, high-value assets and services in the near term (in-situ adaptation), while planning and executing a staged, rights-based relocation of populations and activities away from the highest-risk zones. This approach minimizes exposure to catastrophic loss, maintains statehood, preserves culture, and remains robust across optimistic and pessimistic climate and geopolitical scenarios.
#
# Section 1. Guiding principles and assumptions
# - Principles
#   - Equity and human rights: prioritize the most vulnerable (elderly, disabled, women-headed households, low-income groups), ensure fair housing, tenure security, social protection, and access to essential services.
#   - Rights and statehood: ensure citizenship, voting rights, access to services, and a credible path to retain or adapt the sovereign status while meeting international human rights obligations.
#   - Cultural preservation: protect heritage, sustain identity, and maintain intergenerational ties to land and community.
#   - Environmental integrity: maximize nature-based solutions where feasible; diversify livelihoods; reduce exposure to climate shocks.
#   - Adaptive governance: phased milestones with review points, transparent reporting, and contingency triggers.
# - Core uncertainties
#   - Rate and pattern of sea-level rise; frequency of extreme events.
#   - Pace and location of migration (internal and external).
#   - Availability and terms of external climate funding.
#   - Economic shifts (tourism demand, fishery sustainability, alternative livelihoods).
#   - Technical feasibility and cost of large-scale in-situ defenses or new-town development.
# - High-level risk categories
#   - Finance (underfunding or aid volatility)
#   - Governance (coordination failures, public trust)
#   - Social (inequitable displacement, social tension)
#   - Environmental (unintended ecological impacts)
#   - Legal/political (constitutional compatibility, rights protections)
#
# Section 2. The 20-year strategy: five elements (a–e)
#
# A. Equitable human relocation and housing
# Objective: Relocate populations and create safe, affordable housing and livelihoods for those at highest risk, while safeguarding family stability, social cohesion, and access to services.
#
# Timeline and concrete steps
# - Years 0–5 (Phase 1)
#   - Establish a National Relocation Authority (NRA) with independent civil-society and territorial representation.
#   - Do a comprehensive risk/household survey to map who is most exposed and who has the least options to stay.
#   - Adopt a rights-centered relocation framework (tenure security, compensation norms, return/participation rights).
#   - Identify 3–5 higher-ground or inland locations for planned settlements; initiate land acquisition, environmental permitting, and master-planning for 2–3 new towns proximal to existing urban networks.
#   - Begin construction of 5,000–8,000 new housing units (modular, climate-resilient, affordable) for early relocations; pilot climate-proofed community facilities (schools, clinics, markets).
#   - Launch social protection and income-support programs (universal social protection floor, stipend for vulnerable groups) tied to relocation progress.
# - Years 6–10 (Phase 2)
#   - Scale housing to 15,000–25,000 units total across new towns and elevated districts; expand job-creating amenities (retail, logistics, healthcare).
#   - Establish relocation grants tied to livelihoods (microenterprise start-up grants, land-based livelihoods training, skilled trades).
#   - Create secure land tenure and property rights in new locations; ensure portability of citizenship status and access to services.
# - Years 11–20 (Phase 3)
#   - Complete staged relocation to a broad, resilient settlement system while maintaining a core, protected urban hub (critical services and economic functions remain accessible on elevated or protected cores).
#   - Optimize and retrofit existing settlements for eventual transition if flood risk recedes or shifts (flexible zoning, phased return options if conditions allow).
#   - Maintain a continuous housing-supply pipeline and disaster-resilient public infrastructure.
#
# Budget and funding
# - Domestic budget: allocate roughly 5–7% of GDP per year during Years 0–10 (roughly $75–105M annually, using a 1.5B GDP baseline), tapering to 3–5% in later years as absorption capacity increases.
# - External funding: target 55–70% of the total relocation/housing cost through grants, concessional loans, and climate finance; engage diaspora investment and private sector partnerships for land development and housing pipelines.
# - Rough cost envelope (order-of-magnitude, 20 years): $1.2–1.8B domestic, $1.0–2.3B external; total program ~ $2.2–3.5B.
# - Measurable success metrics
#   - Number of people relocated to safe zones; share of high-risk population covered.
#   - Number and quality of new housing units delivered; tenure security (lease/purchase rights).
#   - Access to services: people within 30 minutes of essential services; unemployment/employment rates in relocated areas.
#   - Displacement-adjusted poverty rates; social protection coverage.
#
# Risks and failure modes
# - Non-acceptance by communities; migration bottlenecks; price and land-availability constraints.
# - Inadequate or delayed funding; misallocation; governance fragmentation.
# - Social inequities in relocation (e.g., urban-rural divides, marginalized groups).
# - Contingency triggers
#   - If relocation progress stalls below target milestones for two consecutive six-month periods, trigger a management reset: accelerate targeted grants, reallocate funding, intensify community engagement.
#   - If land acquisition costs exceed projections by >25%, adjust site selection and financing mix; explore intergovernmental support and public-private partnerships.
# - Assumptions and uncertainties
#   - Assumes secure land for new settlements; assumes political will and predictable aid flows; assumes adequate domestic revenue.
#
# B. Economic transition and livelihood preservation
# Objective: diversify the economy beyond tourism and small-scale fishing; protect livelihoods during relocation; invest in resilient industries and skills.
#
# Timeline and concrete steps
# - Years 0–5
#   - Define a Climate-Resilient Economic Plan (CREP) with sectors: sustainable tourism (eco/experiential), green energy, aquaculture with sustainable practices, digital services, logistics/port efficiency, and climate-resilient agriculture.
#   - Invest in workforce development: climate-smart agriculture, marine stewardship, hospitality training, and digital/computational skills.
#   - Create a small business resilience fund and access to concessional credit for relocation-related businesses.
# - Years 6–10
#   - Expand green energy capacity (solar, small-scale wind, storage) to reduce exposure to fossil fuel volatility; develop cross-island energy resilience.
#   - Promote export-oriented, value-added seafood processing, agro-processing, and eco-tourism services.
#   - Build climate-resilient supply chains and infrastructure (cold chain for fisheries, logistics hubs).
# - Years 11–20
#   - Scale new industries; promote innovation hubs and partnerships with regional and international research institutions to accelerate adaptation technologies.
#   - Strengthen regional integration; explore niche markets (ecotourism, immersive cultural experiences).
#
# Budget and funding
# - Domestic budget: 2–4% of GDP annually, rising to 4–6% during mid-period as new industries scale.
# - External funding: concessional loans and grants for sector-specific investments; potential private sector co-investments in eco-tourism, aquaculture, and logistics.
# - Rough cost envelope: $0.7–1.6B domestic; $0.8–1.8B external; total $1.5–3.4B over 20 years.
# - Measurable success metrics
#   - Diversification indicators: share of GDP from non-tourism sectors; employment mix by sector.
#   - Job creation rates; youth unemployment declines; SME survival.
#   - Energy mix: share of renewables; grid reliability metrics.
#   - Export growth in value-added products.
# - Risks and failure modes
#   - Tourism demand volatility; global crises; disease outbreaks affecting fisheries; over-reliance on any single sector.
#   - Financing gaps or cost overruns.
# - Contingency triggers
#   - If unemployment remains above baseline for two consecutive years, expand targeted retraining and microfinance programs; boost public procurement for local goods.
#   - If export demand declines globally, accelerate domestic market development and diversify sectors.
# - Assumptions and uncertainties
#   - Assumes consistent global demand for eco-tourism and sustainable seafood; assumes ability to attract technology transfer and investments.
#
# C. Legal/political status and rights for displaced citizens (including options for retaining statehood)
# Objective: Provide legal clarity and rights for displaced citizens, ensure continuity of state functions, and maintain or adapt statehood legitimacy.
#
# Timeline and concrete steps
# - Years 0–5
#   - Enshrine a climate-displacement rights framework, including: citizenship protections, family unity provisions, access to social services, and voting rights protections for relocated populations.
#   - Clarify legal status for displaced residents: temporary protections, long-term residency options, and paths to naturalization with rights matching residents’ circumstances.
#   - Begin constitutional and legal reforms to recognize climate displacement as a material factor in governance, with the option to adjust territorial sovereignty arrangements if needed (without undermining statehood).
# - Years 6–10
#   - Implement a “right to safe housing and livelihoods” baseline across relocated communities; ensure universal access to healthcare, education, and social protection.
#   - Establish a formal mechanism for return or re-claiming homeland rights if conditions allow, with sustainable criteria for return.
# - Years 11–20
#   - Stabilize legal frameworks around citizenship, voting rights, and representation for relocated residents, considering diaspora representation if necessary.
#   - If needed, explore constitutional amendments or interim special arrangements to preserve continuous statehood while ensuring inclusive governance.
#
# Budget and funding
# - Domestic: moderate legal-audit costs; implementation of rights-based programs within existing budgets; minimal new cost but some administrative overhead.
# - External: potential support from multilateral bodies for governance reform and rights protection; technical assistance grants.
#
# Measurable success metrics
# - Proportion of relocated residents with secure housing tenure and access to services.
# - Legal and administrative processing times for residency, citizenship, and rights protections.
# - Representation and participation metrics for relocated populations (voting access, local governance participation).
#
# Risks and failure modes
# - Political resistance to constitutional changes; disputes over sovereignty and relocation rights; risk of statelessness if not managed properly.
# - Contingency triggers
#   - If legal protections are delayed beyond Year 5, appoint an independent rights oversight body to accelerate implementation; provide temporary protections with sunset clauses.
# - Assumptions and uncertainties
#   - Assumes political will to reform and adapt the constitution; assumes international legal norms support rights protections.
#
# D. Cultural heritage preservation
# Objective: Preserve and celebrate cultural heritage, including intangible traditions, while ensuring that relocation does not erode identity.
#
# Timeline and concrete steps
# - Years 0–5
#   - Inventory and digitization of cultural assets (sites, stories, languages, crafts).
#   - Develop a Cultural Heritage Strategy with protections for endangered traditions, recipes, songs, and languages, including intergenerational transfer programs.
#   - Designate and protect key heritage sites; plan for virtual/physical accessibility and relocation considerations when sites are threatened.
# - Years 6–10
#   - Transfer or stabilize heritage sites that are at risk; establish heritage-based tourism experiences in safe zones that align with relocation plans.
#   - Fund culture-based education and intergenerational programs in both origin and relocation communities.
# - Years 11–20
#   - Build a national archive and digital museum; foster international partnerships to preserve and share heritage; ensure inclusion of diaspora narratives.
#   - Evaluate UNESCO or regional heritage status where applicable and pursue inscriptions when appropriate.
#
# Budget and funding
# - Domestic: modest, focused on cultural programs and digitization (tens of millions to low hundreds of millions over 20 years).
# - External: grants for cultural heritage preservation; partnerships with international organizations; museum and digital archive development funds.
# - Measurable success metrics
#   - Number of sites preserved/secured; number of intangible heritage practices documented; audience reach of heritage programs; presence of diaspora voices in cultural policy.
#
# Risks and failure modes
# - Underfunding could erode heritage preservation; misalignment with relocation priorities; cultural homogenization risks.
# - Contingency triggers
#   - If heritage loss accelerates, scale up digitization and community-led heritage programs; adjust relocation plans to protect culturally significant communities.
# - Assumptions and uncertainties
#   - Assumes community willingness to integrate heritage into relocation narratives; assumes stable external support for heritage initiatives.
#
# E. Environmental mitigation/adaptation
# Objective: Protect people and assets via a mix of nature-based solutions and infrastructure, while reducing ecological and climate risks.
#
# Timeline and concrete steps
# - Years 0–5
#   - Conduct a coastal vulnerability atlas; identify priority areas for hard protection and nature-based solutions (mangroves, reefs, living shorelines).
#   - Initiate mangrove restoration and reef-based protection along key coastlines; pilot nature-based flood mitigation in select zones.
#   - Develop disaster risk reduction (DRR) early warning systems and community preparedness programs.
# - Years 6–10
#   - Scale coastal protections (sea walls where needed, elevated structures, flood-proofed public facilities) and continue nature-based approaches.
#   - Implement land-use planning to avoid hazard-prone zones; invest in climate-resilient agriculture and water management (drought/flood resilience).
# - Years 11–20
#   - Maintain, retrofit, and upgrade defenses as climate data evolves; re-evaluate protective strategies with an adaptive-management framework.
#   - Expand green energy and water security to reduce climate-related vulnerabilities.
#
# Budget and funding
# - Domestic: 2–5% of GDP annually (depending on risk exposure and debt capacity); high initial investment phase.
# - External: grants and concessional loans for climate-resilience infrastructure; especially nature-based solutions with co-benefits.
# - Rough cost envelope: $1.0–1.8B domestic; $0.8–1.7B external; total $1.8–3.5B.
#
# Measurable success metrics
# - Percentage of coastline protected by natural and hybrid defenses.
# - Mangrove and reef restoration area; flood event frequency reduction; early-warning reach and effectiveness.
# - Reliability and performance of critical public services during flood events.
#
# Risks and failure modes
# - Inadequate protection where inundation exceeds defenses; ecological trade-offs; land-use conflicts.
# - Contingency triggers
#   - If flood damages exceed forecasted levels for two consecutive years, reallocate funds to accelerate protective measures; increase nature-based solutions.
# - Assumptions and uncertainties
#   - Assumes climate projections and flood modeling are sufficiently reliable to prioritize protections; assumes maintenance capacity and governance to sustain defenses.
#
# Section 3. Governance, implementation, and funding architecture
# - Institutions
#   - National Climate Change Authority (NCCA) to coordinate across sectors.
#   - National Relocation Authority (NRA) for relocation/housing; an Independent Rights Ombudsperson for displacement-related matters.
#   - Cultural Heritage Council; Coastal Resilience Agency for environmental protections.
#   - Disaster Risk Reduction Command (DRRC) for emergency planning and response.
# - Financing mix
#   - Domestic budget allocations: 30–50% of total program funding, with annual targets tied to GDP and revenues.
#   - External funding: 50–70% of total program funding; prioritize grants and concessional loans; blend with diaspora investments and private-sector co-financing.
#   - Climate finance instruments: grants, concessional loans, sovereign green bonds, catastrophe risk insurance/public-private partnerships.
# - Transparency and accountability
#   - Public dashboards with milestone reporting; independent audits; community oversight committees.
# - Contingency planning
#   - Trigger events: failure to meet key milestones, funding shortfalls, or escalating disaster risks; policy adjustments to re-prioritize or reallocate resources.
#
# Section 4. Two high-level policy approaches: in-place adaptation vs planned retreat/relocation
#
# Approach 1: In-place adaptation (protect and buttress the capital and arable land)
# - Core idea: Invest heavily in hard defenses (seawalls, raised platforms), flood-proofing, pumped drainage, and selective land reclamation to keep the capital and 40% of arable land in their current locations.
# - Pros
#   - Preserves current population distribution; continuity of government, services, and identity in the near term.
#   - Potentially lower disruption to existing communities and livelihoods if defenses work.
# - Cons and ethical considerations
#   - High costs and risk of failure if sea-level rise accelerates; long-term burden on future generations; inequitable outcomes if defense advantages accrue to those in protected zones while others remain exposed or displaced.
#   - Intergenerational justice concerns: present-day investment commitments may overwhelm future capacity, and if protections fail or degrade, vulnerable groups bear the brunt.
# - Funding and cost profile
#   - Very high upfront capital costs; ongoing maintenance; reliance on long-term external financing and risk transfer (insurance, guarantees).
# - Contingency risks
#   - If climate risks outpace protection, asset losses could be catastrophic; governance debates around ongoing funding and equity.
#
# Approach 2: Planned retreat/relocation (staged, rights-based relocation)
# - Core idea: Proactively move populations, livelihoods, and critical assets away from high-risk zones to higher ground or new settlements, with a rights-based framework and robust protections for citizenship, livelihoods, and culture.
# - Pros
#   - Reduces exposure to escalating climate risks; more predictable planning environment; can unlock safer, more sustainable long-term development.
# - Cons and ethical considerations
#   - Dislocation costs, cultural disruption, and potential loss of sense of place; risks of unequal treatment where some communities receive infrastructure while others do not; potential impacts on minority or vulnerable groups during relocation.
# - Funding and cost profile
#   - Domestic and external funding balanced to cover housing, infrastructure, services, and livelihoods in relocated areas; upfront investments offset by long-term resilience gains.
# - Contingency risks
#   - Political resistance to relocation; social fracture if relocation is perceived as coercive; insufficient housing supply or job opportunities in relocation areas.
#
# Ethical trade-offs between approaches
# - Intergenerational justice: In-place adaptation can defer relocation costs but raises the risk of catastrophic loss for future generations if protections fail; planned retreat spreads the burden more evenly across generations but concentrates costs now.
# - Rights of vulnerable groups: A plan that focuses on in-situ defense may privilege those who own protected assets, at the expense of marginalized groups who bear higher relative risk; a relocation-focused plan must ensure not to coerce or disproportionately disadvantage any group and must guarantee access to services, livelihoods, and cultural continuity.
# - Justice in voice and participation: A relocation strategy that embeds community-led decision-making, consent, and fair compensation can be more ethically robust than a defense-heavy plan that marginalizes communities.
#
# Section 5. Recommendation and justification
# - The single best policy recommendation: Adopt a hybrid “managed retreat with targeted in-situ adaptation” approach.
#   - Why this is robust across scenarios:
#     - It acknowledges that some areas (especially the capital core and critical arable zones) are high-value, high-risk assets best protected in the near term with targeted defenses, while more exposed areas and populations are relocated in a rights-based, predictable, and participatory way.
#     - It aligns with equity and human rights obligations by ensuring protections, housing, and livelihoods for relocated populations and by preserving cultural heritage and citizenship status.
#     - It is flexible to climate and geopolitical uncertainties: if adaptation costs rise or external aid wanes, the plan can lean more toward retreat in later phases; if climate signals permit, protections can be expanded or refined.
#     - It provides a clear governance and financing framework with phased milestones and contingency triggers, reducing the risk of abrupt, destabilizing shifts.
#   - Operationally, this means:
#     - In the near term (Years 0–5): halt escalation of risk in the capital by deploying a mix of nature-based solutions and critical defenses, while launching the relocation program for the most exposed communities and initiating new safe settlements.
#     - Mid-term (Years 6–15): scale relocation, complete a majority of housing and livelihoods in relocated areas, and consolidate economic diversification; continuously upgrade defenses where cost-effective and necessary for core services.
#     - Long-term (Years 16–20): consolidate gains, re-evaluate risk, adapt to new climate projections, and maintain flexible paths for potential returns or further relocation if conditions permit.
#   - Ethical guardrails: insist on a participatory relocation process; ensure universal access to rights and services; maintain diaspora engagement to sustain cultural and political legitimacy; prioritize vulnerable groups in every phase.
#
# Section 6. Implementation-ready plan: 12–24 month action map (highlights)
# - Governance and institutions
#   - Establish NRA, NCCA, and Coastal Resilience Agency; appoint an Independent Rights Ombudsperson.
#   - Create cross-ministerial coordinating committees for housing, livelihoods, heritage, and DRR.
# - Financing and instruments
#   - Set up a National Climate Resilience Fund; issue sovereign green bonds; explore blended finance with development banks.
#   - Formalize a diaspora investment framework; guarantee investment-friendly conditions for relocation housing and green infrastructure.
# - People and communities
#   - Complete risk and vulnerability census; launch relocation beneficiary selection with inclusive, transparent criteria.
#   - Initiate social protection expansions; begin vocational retraining and entrepreneurship support aligned with relocation sites.
# - Housing and settlement
#   - Finalize master plans for 2–3 new safer towns; commence construction of early housing clusters (5,000–8,000 units) and essential services.
#   - Implement land tenure reforms in relocation areas; provide secure housing rights.
# - Economic diversification
#   - Launch pilots in climate-smart agriculture, sustainable seafood processing, and eco-tourism in relocation zones.
#   - Expand renewable energy and grid resilience; advance inter-island logistics links.
# - Environment and heritage
#   - Initiate mangrove restoration and coastal habitat projects; digitize cultural heritage assets; establish protected heritage zones near relocation sites.
# - Monitoring and risk management
#   - Create a climate-risk dashboard with annual independent evaluations; set trigger thresholds for accelerating or adjusting strategy.
#
# Key assumptions and uncertainties (transparent)
# - Assumptions
#   - External climate finance will be available at predictable terms; there is political will to pursue relocation, rights protections, and heritage preservation; land is available for relocation and safe settlements; diaspora capital is accessible.
# - Major uncertainties
#   - Climate trajectory (rate of sea-level rise, extreme events); economic shocks that affect tourism and fisheries; donor fatigue and policy shifts in neighboring states; feasibility and costs of large-scale in-situ defenses.
# - Risks of misestimation
#   - Over- or under-estimating relocation needs could lead to housing shortfalls or misallocated funds; failure to engage communities could undermine legitimacy.
#
# Narrative wrap-up: what success would look like in 20 years
# - People live in secure homes with reliable access to services in relocated areas, while essential government functions and critical services are safeguarded in a protected core.
# - The economy has diversified beyond tourism and small-scale fishing toward climate-resilient industries, with stable livelihoods for relocated populations and new settlements.
# - Legal provisions provide rights and protections for displaced citizens, with clear pathways for naturalization or residency and sustained citizenship assurances to preserve statehood legitimacy.
# - Cultural heritage is preserved through a combination of digitization, preservation of living practices, and heritage tourism that respects communities.
# - Coastal environments are strengthened through nature-based and hybrid infrastructure strategies, with effective early warning and DRR systems.
#
# Closing note
# - The plan emphasizes equity, adaptability, and the long-term viability of the nation-state. It recognizes the moral imperative to safeguard the most vulnerable while maintaining national sovereignty and cultural integrity. The hybrid approach balances the near-term necessity of protecting core assets and services with the long-term resilience gained by orderly relocation, thereby maximizing the odds of a robust, just, and prosperous trajectory under a wide range of climate and geopolitical conditions.
#
# # Response from competitor 2
#
# As Chief Policy Planner for our sovereign island nation, I present this urgent 20-year strategy to navigate the existential threat of sea-level rise. Our nation of 200,000 faces an unprecedented challenge: the annual inundation of our capital and 40% of our arable land within two decades. Our current reliance on tourism and small-scale fishing, combined with a limited national budget (GDP $1.5B, reserves covering ~3 years of spending), hostile neighboring migration policies, and uncertain international aid, demands a bold, proactive, and self-reliant approach.
#
# Our overarching vision is to secure the long-term survival, prosperity, and cultural identity of our people and nation, even as our physical geography transforms. This strategy acknowledges the inevitability of significant physical changes and prioritizes strategic adaptation and relocation over futile resistance.
#
# ---
#
# ### **Overarching Strategy: Proactive Resilience & Managed Transformation**
#
# Our strategy centers on a **Proactive Resilience & Managed Transformation** approach, blending strategic retreat from the most vulnerable areas with targeted adaptation for essential infrastructure and ecological assets, while fundamentally restructuring our economy and legal framework to ensure national continuity.
#
# ---
#
# ### **Detailed 20-Year Strategy Elements**
#
# **Assumptions & Uncertainties:**
# *   **Assumptions:**
#     *   Sufficient suitable higher ground exists within our sovereign territory for a new capital and resettled communities.
#     *   International climate finance mechanisms (e.g., GCF, Adaptation Fund) will provide *some* level of support, though not comprehensive.
#     *   Our citizens, while potentially resistant initially, will ultimately engage constructively in the planning and implementation process.
#     *   Basic international legal principles (e.g., non-refoulement) will continue to hold, even if specific 'climate refugee' status is denied.
# *   **Uncertainties:**
#     *   The precise rate and severity of sea-level rise and associated storm surges.
#     *   The extent and timing of international financial and technical assistance.
#     *   Geopolitical stability and the willingness of international partners to engage in novel legal concepts like "statehood without contiguous territory."
#     *   The social cohesion and psychological impact of mass internal displacement.
#
# ---
#
# #### **(a) Equitable Human Relocation and Housing**
#
# *   **Goal:** Safely and equitably relocate 100% of at-risk populations and infrastructure to secure, sustainable locations within national territory by Year 20, with minimal social disruption.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-3: Assessment & Planning Phase**
#         *   **0-1:** National Vulnerability & Resettlement Suitability Assessment (NVRS): Map all at-risk areas, identify and survey suitable high-ground locations (geology, water, biodiversity, land ownership). Public consultations initiated.
#         *   **1-2:** Develop National Resettlement Master Plan (NRMP): Detailed plans for new urban centers and agricultural zones, infrastructure (roads, utilities, communication), and community facilities. Legal framework for land acquisition/compensation.
#         *   **2-3:** Pilot Relocation Program (1-2 small communities, ~500 people): Test planning assumptions, identify challenges, refine processes.
#     *   **Years 4-15: Implementation & Phased Relocation**
#         *   **4-8:** Infrastructure Development Phase I: Begin construction of essential roads, power grids, water/sanitation, and initial public buildings in designated new capital and key resettlement sites.
#         *   **6-15:** Phased Community Relocation: Systematically relocate populations from most vulnerable areas. Prioritize communities most impacted by annual flooding and critical government functions. Housing construction using resilient, modular, and locally appropriate designs.
#         *   **10-15:** Infrastructure Development Phase II: Expand and consolidate new urban centers, build schools, hospitals, commercial zones.
#     *   **Years 16-20: Consolidation & Final Relocation**
#         *   **16-20:** Finalize relocation of remaining at-risk populations and transfer of all critical government functions to the new capital. Decommission and ecologically restore abandoned sites where feasible.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $800M - $1.2B over 20 years (53-80% of current GDP).
#     *   **Budget Allocation:** 30% of annual national budget for capital projects; remainder from external funding.
#     *   **External Funding Sources:** Green Climate Fund (GCF), Adaptation Fund, World Bank/ADB concessional loans, bilateral aid from climate-resilient partners (e.g., Japan, Netherlands, EU).
# *   **Measurable Success Metrics:**
#     *   95% of identified at-risk population successfully relocated by Year 20.
#     *   80% of relocated households report satisfaction with new housing and community services within 5 years of relocation.
#     *   Construction of new capital and infrastructure on schedule and within 15% of budget.
#     *   No loss of life due to sea-level rise flooding post-Year 15.
# *   **Key Risks & Failure Modes:**
#     *   **Social Resistance:** Reluctance to move, loss of traditional lands/livelihoods, perceived inequity.
#     *   **Land Scarcity/Conflict:** Insufficient suitable land, disputes over land ownership on higher ground.
#     *   **Funding Shortfall:** Inadequate external aid or domestic budget allocation.
#     *   **Infrastructure Failure:** Poor planning or execution of new infrastructure.
#     *   **Psychological Trauma:** Mental health impacts of displacement.
# *   **Contingency Triggers:**
#     *   **Slower SLR:** Allows for extended timelines, re-prioritization to economic development.
#     *   **Faster SLR:** Accelerate relocation timelines, prioritize critical infrastructure transfer, request emergency international aid.
#     *   **Major Funding Shortfall:** Scale back non-essential infrastructure, focus on basic housing, explore innovative financing (e.g., diaspora bonds), potentially seek direct humanitarian aid for housing.
#     *   **Widespread Social Resistance:** Halt forced relocation, launch intensive community engagement campaigns, revise compensation packages, involve anthropologists/sociologists in planning.
#
# ---
#
# #### **(b) Economic Transition and Livelihood Preservation**
#
# *   **Goal:** Diversify the national economy away from vulnerable coastal sectors, create resilient livelihoods for 90% of the working population, and increase GDP per capita by 25% by Year 20.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Foundation & Capacity Building**
#         *   **0-2:** Economic Vulnerability & Opportunity Assessment: Identify sectors resilient to SLR and attractive for investment (e.g., aquaculture in protected areas, deep-sea fishing, renewable energy, specialized agriculture, tech/BPO services, high-value niche tourism on higher ground).
#         *   **1-4:** National Skills Development & Retraining Program: Establish vocational schools and partnerships for training in identified growth sectors. Prioritize displaced fishers and tourism workers.
#         *   **3-5:** Renewable Energy Transition Plan: Phased shift to solar/wind power, reducing reliance on imported fossil fuels. Attract investment in this sector.
#     *   **Years 6-15: Investment & Sector Growth**
#         *   **6-10:** Develop Agri-Tech & Sustainable Aquaculture Zones: Establish new, elevated agricultural zones using climate-smart practices (hydroponics, vertical farms) and inland/protected aquaculture facilities.
#         *   **8-15:** Foster High-Tech & Services Sector: Create dedicated tech parks, incentivize foreign investment in data centers, call centers, and digital services. Develop fiber optic infrastructure.
#         *   **10-15:** Niche Tourism Development: Promote eco-tourism, cultural tourism, and high-value low-impact tourism on higher ground and protected marine areas.
#     *   **Years 16-20: Consolidation & Export Readiness**
#         *   **16-20:** Expand export capabilities for new sectors. Establish Free Trade Zones in new economic hubs. Support small and medium enterprises (SMEs) with business incubation and microfinance.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $500M - $750M over 20 years (33-50% of current GDP).
#     *   **Budget Allocation:** 25% of annual national budget for economic development, education, and subsidies.
#     *   **External Funding Sources:** Multilateral development banks (World Bank, ADB), private sector investment (e.g., for tech, renewable energy), bilateral development aid.
# *   **Measurable Success Metrics:**
#     *   New economic sectors contribute 50% of GDP by Year 20 (up from <5% currently).
#     *   Unemployment rate for relocated populations remains below 10%.
#     *   70% of displaced workers successfully retrained and employed in new sectors.
#     *   Renewable energy sources account for 80% of national energy consumption by Year 20.
# *   **Key Risks & Failure Modes:**
#     *   **Market Failure:** New industries fail to attract investment or find markets.
#     *   **Skill Mismatch:** Training programs do not align with industry needs.
#     *   **Brain Drain:** Educated youth leave the country for better opportunities.
#     *   **Competition:** Inability to compete with larger economies.
# *   **Contingency Triggers:**
#     *   **Economic Downturn:** Implement emergency stimulus packages, prioritize direct cash transfers for displaced workers, double down on attracting foreign direct investment with enhanced incentives.
#     *   **Low uptake in new sectors:** Re-evaluate training programs, offer more attractive startup grants, conduct market research for alternative industries.
#     *   **High Brain Drain:** Implement retention schemes, provide subsidized housing/healthcare for skilled workers, foster a vibrant social and cultural environment.
#
# ---
#
# #### **(c) Legal/Political Status and Rights for Displaced Citizens (Retaining Statehood)**
#
# *   **Goal:** Secure international recognition for our nation's sovereignty and citizenship rights for all citizens, irrespective of physical displacement, by Year 20. Establish legal frameworks for national continuity.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Legal Foundations & Advocacy**
#         *   **0-2:** Establish a Presidential Commission on Statehood Continuity (PCSC): Comprising legal experts, diplomats, and community leaders to research international precedents and develop a legal strategy.
#         *   **1-3:** Constitutional Review & Amendments: Prepare amendments to define national territory and citizenship in a manner resilient to physical changes (e.g., focus on maritime zones, cultural/historical claims, and a "state in trust" concept).
#         *   **2-5:** International Advocacy Campaign Phase I: Engage the UN, AOSIS, specific nations (e.g., Pacific Forum members, powerful allies) on the concept of "statehood without contiguous land" or "deterritorialized sovereignty." Focus on maintaining UN membership and voting rights.
#     *   **Years 6-15: Legal Implementation & Bilateral Treaties**
#         *   **6-10:** Enact domestic legislation safeguarding rights of internally displaced persons (IDPs): Ensuring access to services, property rights, and political participation.
#         *   **8-15:** Pursue Bilateral Agreements: Seek treaties with key nations to recognize our continued statehood and citizenship rights for our people, potentially including agreements for consular services or even temporary residence options in extreme scenarios (without implying mass migration).
#     *   **Years 16-20: Consolidation & Future Proofing**
#         *   **16-20:** Finalize international legal strategy. Establish a "Sovereign Trust Fund" from salvaged national assets and international contributions to secure a permanent home (physical or virtual) for our nation's identity and governance. Explore creation of a "digital nation" platform.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $100M - $200M over 20 years (6.7-13% of current GDP).
#     *   **Budget Allocation:** 5% of annual national budget for legal fees, diplomatic efforts, and international representation.
#     *   **External Funding Sources:** Philanthropic organizations focused on climate justice, specific international legal funds, technical assistance from UN bodies, grants from nations interested in international legal precedents.
# *   **Measurable Success Metrics:**
#     *   Maintenance of UN membership and voting rights.
#     *   Bilateral treaties for statehood recognition with at least 10 key nations by Year 20.
#     *   Domestic legal framework fully in place protecting IDP rights.
#     *   No citizens rendered stateless by Year 20.
#     *   Establishment of a widely recognized "Sovereign Trust Fund" or similar entity.
# *   **Key Risks & Failure Modes:**
#     *   **International Non-recognition:** Major powers refuse to acknowledge deterritorialized sovereignty.
#     *   **Statelessness:** Citizens lose their nationality if the state is deemed to cease to exist.
#     *   **Loss of Voice:** Inability to participate in international forums.
#     *   **Internal Division:** Disagreement on the concept of statehood.
# *   **Contingency Triggers:**
#     *   **Major power refusal of deterritorialized sovereignty:** Focus on achieving regional recognition, bolster economic ties to leverage influence, explore "associated state" models with a larger nation, intensify advocacy for 'cultural sovereignty'.
#     *   **Loss of UN seat:** Redouble efforts for observer status, focus on gaining recognition through bilateral agreements, shift focus to a "diaspora nation" model.
#     *   **Citizenship challenges abroad:** Launch global legal aid funds for citizens, engage international human rights organizations.
#
# ---
#
# #### **(d) Cultural Heritage Preservation**
#
# *   **Goal:** Preserve 100% of tangible and intangible cultural heritage identified as at-risk due to SLR by Year 15, and integrate it into the national identity in new settlements.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Documentation & Digitalization**
#         *   **0-3:** Comprehensive Cultural Heritage Inventory: Map all significant cultural sites, historical buildings, archaeological areas, and intangible heritage (oral histories, traditional practices, languages). Prioritize most vulnerable sites.
#         *   **1-5:** Digital Archiving Project: High-resolution scanning, photogrammetry, 3D modeling of at-risk tangible heritage. Extensive oral history recording, video documentation of rituals, dances, and traditional skills. Establish a secure national digital archive.
#     *   **Years 6-15: Physical Preservation & Integration**
#         *   **6-10:** Strategic Relocation & Preservation: Carefully relocate or reconstruct iconic cultural artifacts and smaller, portable structures to new cultural centers in the elevated capital. Establish climate-controlled national museum in the new capital.
#         *   **8-15:** Community Cultural Centers: Build dedicated cultural centers in each new settlement to foster traditional arts, language, and storytelling. Integrate heritage narratives into new urban planning.
#     *   **Years 16-20: Legacy & Global Outreach**
#         *   **16-20:** Curriculum Integration: Ensure cultural heritage is a core part of the national education curriculum.
#         *   **18-20:** International Collaboration: Partner with UNESCO and other international cultural institutions to safeguard digital archives and promote global awareness of our disappearing heritage.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $75M - $125M over 20 years (5-8% of current GDP).
#     *   **Budget Allocation:** 3% of annual national budget for cultural preservation.
#     *   **External Funding Sources:** UNESCO, World Monuments Fund, Getty Foundation, bilateral aid from culturally sensitive nations, philanthropic organizations.
# *   **Measurable Success Metrics:**
#     *   100% of at-risk tangible heritage digitally archived by Year 5.
#     *   80% of identified intangible heritage documented and archived by Year 10.
#     *   At least 5 major cultural artifacts or structures successfully relocated/reconstructed.
#     *   Establishment of 5+ vibrant community cultural centers in new settlements.
#     *   National language proficiency maintained or increased among youth by Year 20.
# *   **Key Risks & Failure Modes:**
#     *   **Loss Before Preservation:** Rapid SLR or sudden events destroy sites before documentation.
#     *   **Technological Obsolescence:** Digital formats become unreadable.
#     *   **Loss of Context:** Heritage loses meaning when removed from original environment.
#     *   **Lack of Community Engagement:** Heritage preservation efforts fail to resonate locally.
# *   **Contingency Triggers:**
#     *   **Accelerated SLR affecting heritage sites:** Prioritize emergency salvage and rapid digitalization; partner with marine archaeologists for underwater sites.
#     *   **Low community engagement:** Revamp engagement strategies, offer community-led heritage initiatives, provide direct funding for local cultural groups.
#     *   **Funding shortfall:** Focus solely on digital archiving, rely on volunteer efforts, seek smaller grants for specific projects.
#
# ---
#
# #### **(e) Environmental Mitigation/Adaptation**
#
# *   **Goal:** Implement strategic environmental adaptations to protect critical non-relocatable assets, enhance ecological resilience, and secure vital ecosystem services for the remaining land by Year 10.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Strategic Protection & Ecosystem Restoration**
#         *   **0-2:** Critical Infrastructure Protection Plan: Identify essential, non-relocatable infrastructure (e.g., main port, airport – requiring significant investment for relocation) and develop targeted, high-cost coastal defense plans (sea walls, dykes). *Note: This is highly selective, not a general defense strategy.*
#         *   **1-5:** Large-Scale Mangrove & Coral Reef Restoration Program: Prioritize natural coastal defenses. Restore degraded mangrove forests and coral reefs for their protective and biodiversity benefits.
#         *   **3-5:** National Water Security Plan: Implement rainwater harvesting, groundwater management, and strategic desalination plants in new settlements.
#     *   **Years 6-15: Sustainable Resource Management**
#         *   **6-10:** Sustainable Land Use Planning: Implement strict zoning for remaining high ground, protecting critical ecosystems and water sources. Promote permaculture and agroforestry.
#         *   **8-15:** Waste Management & Circular Economy: Develop modern waste management facilities (waste-to-energy where feasible) and promote circular economy principles.
#     *   **Years 16-20: Monitoring & Advanced Adaptation**
#         *   **16-20:** Climate Monitoring & Early Warning Systems: Install advanced sensors for sea-level, weather, and ocean conditions. Develop robust early warning systems for storms and coastal inundation.
#         *   **18-20:** Research & Development: Invest in local R&D for climate-resilient crops, aquaculture techniques, and renewable energy innovations.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $300M - $500M over 20 years (20-33% of current GDP).
#     *   **Budget Allocation:** 15% of annual national budget for environmental projects and infrastructure.
#     *   **External Funding Sources:** Global Environment Facility (GEF), Adaptation Fund, UN Environment Programme, bilateral aid for specific climate projects, conservation NGOs.
# *   **Measurable Success Metrics:**
#     *   50% increase in mangrove coverage and 20% increase in live coral cover by Year 10.
#     *   Access to potable water for 95% of the population in new settlements.
#     *   Reduced damage to critical port/airport infrastructure by 70% post-Year 15.
#     *   Effective waste management system implemented in all major settlements.
#     *   Early warning systems successfully alert 90% of population before extreme weather events.
# *   **Key Risks & Failure Modes:**
#     *   **Overwhelmed Defenses:** Sea walls/dykes fail against extreme events or accelerated SLR.
#     *   **Ecosystem Collapse:** Restoration efforts fail due to continued climate stress or pollution.
#     *   **Water Scarcity:** Insufficient freshwater sources for growing populations.
#     *   **Resource Depletion:** Over-extraction of fish or other natural resources.
# *   **Contingency Triggers:**
#     *   **Faster ecosystem degradation:** Increase investment in restoration, explore more aggressive conservation measures (e.g., marine protected areas), seek emergency ecological funding.
#     *   **Failure of hard defenses:** Re-evaluate and potentially decommission assets, accelerate relocation from those areas, focus solely on natural defenses.
#     *   **Water shortages:** Implement stricter water rationing, invest in additional desalination capacity, explore inter-island water transfer (if feasible).
#
# ---
#
# ### **Comparison of Alternative High-Level Approaches**
#
# #### **1. Approach Centered on In-Place Adaptation (Status Quo++):**
#
# *   **Focus:** Intensive protection of existing coastal areas, infrastructure, and agricultural lands through large-scale engineering.
# *   **Key Strategies:** Massive sea walls, dikes, polders, land reclamation, elevating existing buildings and infrastructure, extensive pumping systems, salt-tolerant crops.
# *   **Ethical Trade-offs:**
#     *   **Intergenerational Justice:** This approach prioritizes the *immediate* preservation of existing communities and assets for the current generation. However, it likely burdens future generations with a perpetually escalating maintenance cost, a constant battle against rising seas, and the risk of catastrophic failure (e.g., a dike breaking). It defers the inevitable decision, potentially leaving future generations with fewer resources and options.
#     *   **Rights of Vulnerable Groups:** While appearing to keep communities together, this approach could disproportionately affect the poor. Expensive adaptations like elevating homes or building private defenses are beyond the reach of many. Those unable to adapt might be marginalized or forced to leave anyway, creating an "adaptation apartheid." Furthermore, the engineering solutions often destroy natural habitats that vulnerable groups rely on for livelihoods (e.g., fishing grounds, mangrove forests).
# *   **Viability for our Nation:** Given "annual flooding of capital and 40% of arable land in 20 years," this approach is **untenable and represents maladaptation.** The scale of engineering required for continuous protection against annual flooding of such a large and vital area would be astronomically expensive, likely beyond our GDP, and unsustainable in the long term. It would merely delay the inevitable and potentially lead to a more abrupt, catastrophic failure later.
#
# #### **2. Approach Centered on Planned Retreat/Relocation (Managed Transformation):**
#
# *   **Focus:** Proactive and strategic movement of populations, infrastructure, and economic activities to safer, higher ground within national territory.
# *   **Key Strategies:** Comprehensive national resettlement plans, development of new urban centers and agricultural zones, economic diversification towards resilient sectors, legal frameworks for statehood continuity.
# *   **Ethical Trade-offs:**
#     *   **Intergenerational Justice:** This approach demands significant sacrifices from the *current* generation (dislocation, disruption of livelihoods, loss of ancestral lands) but aims to secure a viable, sustainable future for *future* generations. It is a long-term investment in national survival, reducing future vulnerability and the burden of constant climate defense. It enables a proactive response, minimizing future crisis-driven migration.
#     *   **Rights of Vulnerable Groups:** The risks here are significant if not managed equitably. Forced relocation can be traumatic, leading to loss of social networks, identity, and livelihoods. It risks dispossessing landholders on higher ground or creating new inequalities if relocation benefits are not distributed fairly. However, with careful planning, robust compensation frameworks, community participation, and dedicated support services, it offers the opportunity to build *more resilient and equitable* communities with improved infrastructure and access to services, potentially uplifting marginalized groups in the long run. The strategy above specifically addresses these risks through equitable planning and social support.
# *   **Viability for our Nation:** This approach is **the only viable long-term solution** for our nation given the specific threats outlined. While challenging, it directly confronts the physical reality of impending inundation and offers a pathway to national continuity.
#
# ---
#
# ### **Single Best Policy Recommendation and Robustness**
#
# My single best policy recommendation is the **Proactive Resilience & Managed Transformation** strategy, fundamentally centered on **Planned Retreat/Relocation** as the overarching principle, complemented by strategic, targeted environmental adaptation.
#
# **Why it is Robust Across Optimistic and Pessimistic Climate and Geopolitical Scenarios:**
#
# 1.  **Directly Addresses the Core Physical Threat:** The "annual flooding of capital and 40% of arable land" makes pure in-place adaptation a fantasy. Planned retreat is the only strategy that acknowledges this reality and offers a sustainable physical future for our people within our borders.
# 2.  **Adaptive Capacity:**
#     *   **Optimistic Climate Scenario (Slower SLR):** If SLR is slower than predicted, the planned retreat provides a longer transition period, allowing for more careful planning, better infrastructure development, and smoother social adjustment. Resources initially allocated for rapid relocation can be redirected to further economic diversification, enhanced social services in new settlements, and more robust long-term infrastructure. The national budget gains breathing room.
#     *   **Pessimistic Climate Scenario (Faster SLR/Extreme Events):** If SLR accelerates or extreme weather events become more frequent, the framework for planned retreat is already established. Early investments in vulnerability assessments, legal frameworks, and initial infrastructure mean the nation is better prepared to accelerate relocation, declare emergencies, and quickly access international humanitarian aid. It shifts from reactive crisis management to a proactive, albeit faster, implementation of an existing plan.
# 3.  **Economic Resilience:** By diversifying our economy away from vulnerable coastal sectors and investing in new, resilient industries (aquaculture, tech, renewables), we build an economy less susceptible to climate impacts. This protects livelihoods and secures financial stability, regardless of the precise climate trajectory. This also makes us less dependent on a single industry (tourism) which is itself vulnerable to global shocks (pandemics, economic crises) as well as climate change.
# 4.  **Geopolitical Independence:** The strategy prioritizes internal solutions for relocation and livelihood, reducing reliance on neighboring states for mass migration (which they have refused). Our proactive legal strategy for "statehood continuity" aims to secure our sovereignty and international standing, offering a dignified future even if our physical land mass shrinks considerably.
#     *   **Optimistic Geopolitical Scenario (Increased Aid/Recognition):** Strong international support (financial, technical, legal) accelerates the implementation of our strategy, allowing for higher quality housing, faster economic transition, and smoother international legal recognition of our statehood.
#     *   **Pessimistic Geopolitical Scenario (Limited Aid/Non-recognition):** While challenging, the strategy's emphasis on self-reliance (internal relocation, domestic economic diversification, constitutional amendments) means our nation is not solely dependent on external goodwill. We build foundational resilience. The international advocacy campaign continues, but our survival is not predicated on immediate external approval for novel legal concepts. We prepare for a scenario where we manage our destiny primarily through our own means.
# 5.  **Ethical Responsibility:** While demanding immediate sacrifices, planned retreat is ethically superior for intergenerational justice. It ensures a future for our nation and people, rather than condemning successive generations to a losing battle. The strategy includes explicit measures for equitable relocation and cultural preservation, aiming to mitigate the trauma of displacement and build a new, resilient national identity.
#
# In conclusion, "Proactive Resilience & Managed Transformation" through a managed, equitable planned retreat is not merely an option; it is an imperative. It represents the most robust and ethically sound path forward to secure the future of our sovereign island nation in the face of an undeniable climate crisis.
#
# # Response from competitor 3
#
# I. Equitable Human Relocation and Housing (5 years, $100M, 7% of national budget)
#
# 1. Conduct inclusive, national-level public consultations (Year 1, $5M) to gather information on existing relocation plans and social, economic, and cultural impacts.
# 2. Establish a National ReLocation Committee (Year 2, $3M) to coordinate a systematic relocation strategy with international guidance on fair distribution, compensation, and social services.
# 3. Construct transitional housing (Year 1-2, $50M) near former flood zones with a mix of affordable and accessible options.
# 4. Implement a fair compensation system (Year 3-5, $30M) that considers the needs and interests of 70% of displaced citizens.
#
# Measurable success metrics: public acceptance rate > 70%, relocation rate > 50% of high-risk area populations.
#
# Key risks and failure modes: public mistrust, insufficient funding, lack of social services.
#
# Contingency triggers: negative consultations outcomes, failure of national consultation engagement.
#
# Assumptions and uncertainties: 10% change in population distribution
#
# II. Economic Transition and Livelihood Preservation (5 years, $500M, 33% of national budget)
#
# 1. Develop and implement a 4-year education and vocational training program (Year 2-5, $100M) for 300,000 small-scale fishermen and 100,000 tourism-related workers.
# 2. Revitalize non-coastal industries through incentives (Year 2-5, $50M) to promote innovation, job creation, and fair labor practices.
# 3. Establish a National Livelihood Fund (Year 1, $50M) to guarantee basic income levels for 60% of citizens.
#
# Measurable success metrics: successful traineeship rate > 50%, increase in coastal non-fishing sector by 15%.
#
# Key risks and failure modes: economic volatility, loss of expertise.
#
# Contingency triggers: government policy shift towards rapid relocation or significant economic fluctuations.
#
# Assumptions and uncertainties: 5% change in GDP growth rate
#
# III. Legal/Political Status and Rights for Displaced Citizens (5 years, $200M, 13% of national budget)
#
# 1. Establish a National Commission for the Rights of Relocation (Year 1, $30M) based on guidelines from international human rights and environmental law.
# 2. Negotiate international cooperation agreements (Year 2, $100M) on displacement impacts on citizenship rights.
#
# Measurable success metrics: acceptance of national human rights protection norms > 80%.
#
# Key risks and failure modes: failure to engage with relevant international governing entities.
#
# Contingency triggers: international refusal to engage, public discontent with human rights standards.
#
# Assumptions and uncertainties: 10% decline in trust of local institutions
#
# IV. Environmental Mitigation/Adaptation (5 years, $500M, 33% of national budget)
#
# 1. Construct coastal barrier system (Year 2-5, $250M) using the most favorable design options.
# 2. Conduct research on sustainable coastal land management (Year 1-2, $50M) and initiate pilot projects for innovative techniques.
#
# Measurable success metrics: 20% increase in projected water depth protection.
#
# Key risks and failure modes: technical complexity issues, public resistance.
#
# Contingency triggers: public discontent, funding shortfalls due to budget constraints.
#
# Assumptions and uncertainties: 10% change in sea-level rise predicted.
#
# V. Environmental Mitigation/Adaptation Alternative (Planned Retreat/Relocation): focus on relocating 90% of population to upperlands before projected flooding and maintaining 10% population in the capital area, prioritizing security, climate and ecological resilience, and human well-being over economic and cultural heritage preservation.
#
# Key benefits: secure future for remaining population, preservation of cultural heritage and biodiversity.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 3 competitors.
# Each model has been given this question:
#
# You are the chief policy planner for a sovereign island nation of 200,000 people whose low-lying capital and 40% of its arable land will be annually flooded beginning in approximately 20 years due to sea-level rise; the economy currently relies on tourism and small-scale fishing, the national budget is limited (GDP $1.5B, emergency reserves cover ~3 years of current spending), neighboring states have publicly refused to accept mass migration, and international aid is politically uncertain. Develop a prioritized, actionable 20‑year strategy that addresses (a) equitable human relocation and housing, (b) economic transition and livelihood preservation, (c) legal/political status and rights for displaced citizens (including options for retaining statehood), (d) cultural heritage preservation, and (e) environmental mitigation/adaptation; for each element provide concrete steps with timelines, rough cost estimates or percentage allocations of the national budget and likely external funding sources, measurable success metrics, key risks and failure modes, contingency triggers that change priorities, and a transparent account of assumptions and uncertainties—then compare two alternative high‑level approaches (one centered on in‑place adaptation and one centered on planned retreat/relocation), evaluate their ethical trade‑offs (including intergenerational justice and rights of vulnerable groups), and conclude with the single best policy recommendation and why it is robust across optimistic and pessimistic climate and geopolitical scenarios.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Executive summary
# - Context: A small, low-lying island nation of 200,000 people faces annual flooding of its capital and 40% of arable land within ~20 years due to sea-level rise. The economy depends on tourism and small-scale fishing. GDP is about $1.5B. Emergency reserves cover roughly three years of current spending. Neighbors won’t accept mass migrants; external aid is uncertain.
# - Core objective: A 20-year, prioritized strategy that protects people, preserves livelihoods, safeguards rights and statehood, preserves cultural heritage, and builds resilient environment and economy. The plan emphasizes equity, transparency, and adaptive management.
# - Overall cost/financing sketch: Total program cost in the 20-year horizon is roughly $2.8–3.5B (order of magnitude). Domestic budget allocations will cover a substantial but minority share (roughly 30–40% of the total), with the remainder funded by external sources (grants, concessional loans, climate finance, diaspora investments, and blended finance). Annual domestic allocations will ramp from ~3–7% of GDP early on to ~5–8% later, depending on revenue and debt capacity.
# - Recommendation (single best policy): A hybrid “managed retreat with targeted in-situ adaptation” approach. Protect critical, high-value assets and services in the near term (in-situ adaptation), while planning and executing a staged, rights-based relocation of populations and activities away from the highest-risk zones. This approach minimizes exposure to catastrophic loss, maintains statehood, preserves culture, and remains robust across optimistic and pessimistic climate and geopolitical scenarios.
#
# Section 1. Guiding principles and assumptions
# - Principles
#   - Equity and human rights: prioritize the most vulnerable (elderly, disabled, women-headed households, low-income groups), ensure fair housing, tenure security, social protection, and access to essential services.
#   - Rights and statehood: ensure citizenship, voting rights, access to services, and a credible path to retain or adapt the sovereign status while meeting international human rights obligations.
#   - Cultural preservation: protect heritage, sustain identity, and maintain intergenerational ties to land and community.
#   - Environmental integrity: maximize nature-based solutions where feasible; diversify livelihoods; reduce exposure to climate shocks.
#   - Adaptive governance: phased milestones with review points, transparent reporting, and contingency triggers.
# - Core uncertainties
#   - Rate and pattern of sea-level rise; frequency of extreme events.
#   - Pace and location of migration (internal and external).
#   - Availability and terms of external climate funding.
#   - Economic shifts (tourism demand, fishery sustainability, alternative livelihoods).
#   - Technical feasibility and cost of large-scale in-situ defenses or new-town development.
# - High-level risk categories
#   - Finance (underfunding or aid volatility)
#   - Governance (coordination failures, public trust)
#   - Social (inequitable displacement, social tension)
#   - Environmental (unintended ecological impacts)
#   - Legal/political (constitutional compatibility, rights protections)
#
# Section 2. The 20-year strategy: five elements (a–e)
#
# A. Equitable human relocation and housing
# Objective: Relocate populations and create safe, affordable housing and livelihoods for those at highest risk, while safeguarding family stability, social cohesion, and access to services.
#
# Timeline and concrete steps
# - Years 0–5 (Phase 1)
#   - Establish a National Relocation Authority (NRA) with independent civil-society and territorial representation.
#   - Do a comprehensive risk/household survey to map who is most exposed and who has the least options to stay.
#   - Adopt a rights-centered relocation framework (tenure security, compensation norms, return/participation rights).
#   - Identify 3–5 higher-ground or inland locations for planned settlements; initiate land acquisition, environmental permitting, and master-planning for 2–3 new towns proximal to existing urban networks.
#   - Begin construction of 5,000–8,000 new housing units (modular, climate-resilient, affordable) for early relocations; pilot climate-proofed community facilities (schools, clinics, markets).
#   - Launch social protection and income-support programs (universal social protection floor, stipend for vulnerable groups) tied to relocation progress.
# - Years 6–10 (Phase 2)
#   - Scale housing to 15,000–25,000 units total across new towns and elevated districts; expand job-creating amenities (retail, logistics, healthcare).
#   - Establish relocation grants tied to livelihoods (microenterprise start-up grants, land-based livelihoods training, skilled trades).
#   - Create secure land tenure and property rights in new locations; ensure portability of citizenship status and access to services.
# - Years 11–20 (Phase 3)
#   - Complete staged relocation to a broad, resilient settlement system while maintaining a core, protected urban hub (critical services and economic functions remain accessible on elevated or protected cores).
#   - Optimize and retrofit existing settlements for eventual transition if flood risk recedes or shifts (flexible zoning, phased return options if conditions allow).
#   - Maintain a continuous housing-supply pipeline and disaster-resilient public infrastructure.
#
# Budget and funding
# - Domestic budget: allocate roughly 5–7% of GDP per year during Years 0–10 (roughly $75–105M annually, using a 1.5B GDP baseline), tapering to 3–5% in later years as absorption capacity increases.
# - External funding: target 55–70% of the total relocation/housing cost through grants, concessional loans, and climate finance; engage diaspora investment and private sector partnerships for land development and housing pipelines.
# - Rough cost envelope (order-of-magnitude, 20 years): $1.2–1.8B domestic, $1.0–2.3B external; total program ~ $2.2–3.5B.
# - Measurable success metrics
#   - Number of people relocated to safe zones; share of high-risk population covered.
#   - Number and quality of new housing units delivered; tenure security (lease/purchase rights).
#   - Access to services: people within 30 minutes of essential services; unemployment/employment rates in relocated areas.
#   - Displacement-adjusted poverty rates; social protection coverage.
#
# Risks and failure modes
# - Non-acceptance by communities; migration bottlenecks; price and land-availability constraints.
# - Inadequate or delayed funding; misallocation; governance fragmentation.
# - Social inequities in relocation (e.g., urban-rural divides, marginalized groups).
# - Contingency triggers
#   - If relocation progress stalls below target milestones for two consecutive six-month periods, trigger a management reset: accelerate targeted grants, reallocate funding, intensify community engagement.
#   - If land acquisition costs exceed projections by >25%, adjust site selection and financing mix; explore intergovernmental support and public-private partnerships.
# - Assumptions and uncertainties
#   - Assumes secure land for new settlements; assumes political will and predictable aid flows; assumes adequate domestic revenue.
#
# B. Economic transition and livelihood preservation
# Objective: diversify the economy beyond tourism and small-scale fishing; protect livelihoods during relocation; invest in resilient industries and skills.
#
# Timeline and concrete steps
# - Years 0–5
#   - Define a Climate-Resilient Economic Plan (CREP) with sectors: sustainable tourism (eco/experiential), green energy, aquaculture with sustainable practices, digital services, logistics/port efficiency, and climate-resilient agriculture.
#   - Invest in workforce development: climate-smart agriculture, marine stewardship, hospitality training, and digital/computational skills.
#   - Create a small business resilience fund and access to concessional credit for relocation-related businesses.
# - Years 6–10
#   - Expand green energy capacity (solar, small-scale wind, storage) to reduce exposure to fossil fuel volatility; develop cross-island energy resilience.
#   - Promote export-oriented, value-added seafood processing, agro-processing, and eco-tourism services.
#   - Build climate-resilient supply chains and infrastructure (cold chain for fisheries, logistics hubs).
# - Years 11–20
#   - Scale new industries; promote innovation hubs and partnerships with regional and international research institutions to accelerate adaptation technologies.
#   - Strengthen regional integration; explore niche markets (ecotourism, immersive cultural experiences).
#
# Budget and funding
# - Domestic budget: 2–4% of GDP annually, rising to 4–6% during mid-period as new industries scale.
# - External funding: concessional loans and grants for sector-specific investments; potential private sector co-investments in eco-tourism, aquaculture, and logistics.
# - Rough cost envelope: $0.7–1.6B domestic; $0.8–1.8B external; total $1.5–3.4B over 20 years.
# - Measurable success metrics
#   - Diversification indicators: share of GDP from non-tourism sectors; employment mix by sector.
#   - Job creation rates; youth unemployment declines; SME survival.
#   - Energy mix: share of renewables; grid reliability metrics.
#   - Export growth in value-added products.
# - Risks and failure modes
#   - Tourism demand volatility; global crises; disease outbreaks affecting fisheries; over-reliance on any single sector.
#   - Financing gaps or cost overruns.
# - Contingency triggers
#   - If unemployment remains above baseline for two consecutive years, expand targeted retraining and microfinance programs; boost public procurement for local goods.
#   - If export demand declines globally, accelerate domestic market development and diversify sectors.
# - Assumptions and uncertainties
#   - Assumes consistent global demand for eco-tourism and sustainable seafood; assumes ability to attract technology transfer and investments.
#
# C. Legal/political status and rights for displaced citizens (including options for retaining statehood)
# Objective: Provide legal clarity and rights for displaced citizens, ensure continuity of state functions, and maintain or adapt statehood legitimacy.
#
# Timeline and concrete steps
# - Years 0–5
#   - Enshrine a climate-displacement rights framework, including: citizenship protections, family unity provisions, access to social services, and voting rights protections for relocated populations.
#   - Clarify legal status for displaced residents: temporary protections, long-term residency options, and paths to naturalization with rights matching residents’ circumstances.
#   - Begin constitutional and legal reforms to recognize climate displacement as a material factor in governance, with the option to adjust territorial sovereignty arrangements if needed (without undermining statehood).
# - Years 6–10
#   - Implement a “right to safe housing and livelihoods” baseline across relocated communities; ensure universal access to healthcare, education, and social protection.
#   - Establish a formal mechanism for return or re-claiming homeland rights if conditions allow, with sustainable criteria for return.
# - Years 11–20
#   - Stabilize legal frameworks around citizenship, voting rights, and representation for relocated residents, considering diaspora representation if necessary.
#   - If needed, explore constitutional amendments or interim special arrangements to preserve continuous statehood while ensuring inclusive governance.
#
# Budget and funding
# - Domestic: moderate legal-audit costs; implementation of rights-based programs within existing budgets; minimal new cost but some administrative overhead.
# - External: potential support from multilateral bodies for governance reform and rights protection; technical assistance grants.
#
# Measurable success metrics
# - Proportion of relocated residents with secure housing tenure and access to services.
# - Legal and administrative processing times for residency, citizenship, and rights protections.
# - Representation and participation metrics for relocated populations (voting access, local governance participation).
#
# Risks and failure modes
# - Political resistance to constitutional changes; disputes over sovereignty and relocation rights; risk of statelessness if not managed properly.
# - Contingency triggers
#   - If legal protections are delayed beyond Year 5, appoint an independent rights oversight body to accelerate implementation; provide temporary protections with sunset clauses.
# - Assumptions and uncertainties
#   - Assumes political will to reform and adapt the constitution; assumes international legal norms support rights protections.
#
# D. Cultural heritage preservation
# Objective: Preserve and celebrate cultural heritage, including intangible traditions, while ensuring that relocation does not erode identity.
#
# Timeline and concrete steps
# - Years 0–5
#   - Inventory and digitization of cultural assets (sites, stories, languages, crafts).
#   - Develop a Cultural Heritage Strategy with protections for endangered traditions, recipes, songs, and languages, including intergenerational transfer programs.
#   - Designate and protect key heritage sites; plan for virtual/physical accessibility and relocation considerations when sites are threatened.
# - Years 6–10
#   - Transfer or stabilize heritage sites that are at risk; establish heritage-based tourism experiences in safe zones that align with relocation plans.
#   - Fund culture-based education and intergenerational programs in both origin and relocation communities.
# - Years 11–20
#   - Build a national archive and digital museum; foster international partnerships to preserve and share heritage; ensure inclusion of diaspora narratives.
#   - Evaluate UNESCO or regional heritage status where applicable and pursue inscriptions when appropriate.
#
# Budget and funding
# - Domestic: modest, focused on cultural programs and digitization (tens of millions to low hundreds of millions over 20 years).
# - External: grants for cultural heritage preservation; partnerships with international organizations; museum and digital archive development funds.
# - Measurable success metrics
#   - Number of sites preserved/secured; number of intangible heritage practices documented; audience reach of heritage programs; presence of diaspora voices in cultural policy.
#
# Risks and failure modes
# - Underfunding could erode heritage preservation; misalignment with relocation priorities; cultural homogenization risks.
# - Contingency triggers
#   - If heritage loss accelerates, scale up digitization and community-led heritage programs; adjust relocation plans to protect culturally significant communities.
# - Assumptions and uncertainties
#   - Assumes community willingness to integrate heritage into relocation narratives; assumes stable external support for heritage initiatives.
#
# E. Environmental mitigation/adaptation
# Objective: Protect people and assets via a mix of nature-based solutions and infrastructure, while reducing ecological and climate risks.
#
# Timeline and concrete steps
# - Years 0–5
#   - Conduct a coastal vulnerability atlas; identify priority areas for hard protection and nature-based solutions (mangroves, reefs, living shorelines).
#   - Initiate mangrove restoration and reef-based protection along key coastlines; pilot nature-based flood mitigation in select zones.
#   - Develop disaster risk reduction (DRR) early warning systems and community preparedness programs.
# - Years 6–10
#   - Scale coastal protections (sea walls where needed, elevated structures, flood-proofed public facilities) and continue nature-based approaches.
#   - Implement land-use planning to avoid hazard-prone zones; invest in climate-resilient agriculture and water management (drought/flood resilience).
# - Years 11–20
#   - Maintain, retrofit, and upgrade defenses as climate data evolves; re-evaluate protective strategies with an adaptive-management framework.
#   - Expand green energy and water security to reduce climate-related vulnerabilities.
#
# Budget and funding
# - Domestic: 2–5% of GDP annually (depending on risk exposure and debt capacity); high initial investment phase.
# - External: grants and concessional loans for climate-resilience infrastructure; especially nature-based solutions with co-benefits.
# - Rough cost envelope: $1.0–1.8B domestic; $0.8–1.7B external; total $1.8–3.5B.
#
# Measurable success metrics
# - Percentage of coastline protected by natural and hybrid defenses.
# - Mangrove and reef restoration area; flood event frequency reduction; early-warning reach and effectiveness.
# - Reliability and performance of critical public services during flood events.
#
# Risks and failure modes
# - Inadequate protection where inundation exceeds defenses; ecological trade-offs; land-use conflicts.
# - Contingency triggers
#   - If flood damages exceed forecasted levels for two consecutive years, reallocate funds to accelerate protective measures; increase nature-based solutions.
# - Assumptions and uncertainties
#   - Assumes climate projections and flood modeling are sufficiently reliable to prioritize protections; assumes maintenance capacity and governance to sustain defenses.
#
# Section 3. Governance, implementation, and funding architecture
# - Institutions
#   - National Climate Change Authority (NCCA) to coordinate across sectors.
#   - National Relocation Authority (NRA) for relocation/housing; an Independent Rights Ombudsperson for displacement-related matters.
#   - Cultural Heritage Council; Coastal Resilience Agency for environmental protections.
#   - Disaster Risk Reduction Command (DRRC) for emergency planning and response.
# - Financing mix
#   - Domestic budget allocations: 30–50% of total program funding, with annual targets tied to GDP and revenues.
#   - External funding: 50–70% of total program funding; prioritize grants and concessional loans; blend with diaspora investments and private-sector co-financing.
#   - Climate finance instruments: grants, concessional loans, sovereign green bonds, catastrophe risk insurance/public-private partnerships.
# - Transparency and accountability
#   - Public dashboards with milestone reporting; independent audits; community oversight committees.
# - Contingency planning
#   - Trigger events: failure to meet key milestones, funding shortfalls, or escalating disaster risks; policy adjustments to re-prioritize or reallocate resources.
#
# Section 4. Two high-level policy approaches: in-place adaptation vs planned retreat/relocation
#
# Approach 1: In-place adaptation (protect and buttress the capital and arable land)
# - Core idea: Invest heavily in hard defenses (seawalls, raised platforms), flood-proofing, pumped drainage, and selective land reclamation to keep the capital and 40% of arable land in their current locations.
# - Pros
#   - Preserves current population distribution; continuity of government, services, and identity in the near term.
#   - Potentially lower disruption to existing communities and livelihoods if defenses work.
# - Cons and ethical considerations
#   - High costs and risk of failure if sea-level rise accelerates; long-term burden on future generations; inequitable outcomes if defense advantages accrue to those in protected zones while others remain exposed or displaced.
#   - Intergenerational justice concerns: present-day investment commitments may overwhelm future capacity, and if protections fail or degrade, vulnerable groups bear the brunt.
# - Funding and cost profile
#   - Very high upfront capital costs; ongoing maintenance; reliance on long-term external financing and risk transfer (insurance, guarantees).
# - Contingency risks
#   - If climate risks outpace protection, asset losses could be catastrophic; governance debates around ongoing funding and equity.
#
# Approach 2: Planned retreat/relocation (staged, rights-based relocation)
# - Core idea: Proactively move populations, livelihoods, and critical assets away from high-risk zones to higher ground or new settlements, with a rights-based framework and robust protections for citizenship, livelihoods, and culture.
# - Pros
#   - Reduces exposure to escalating climate risks; more predictable planning environment; can unlock safer, more sustainable long-term development.
# - Cons and ethical considerations
#   - Dislocation costs, cultural disruption, and potential loss of sense of place; risks of unequal treatment where some communities receive infrastructure while others do not; potential impacts on minority or vulnerable groups during relocation.
# - Funding and cost profile
#   - Domestic and external funding balanced to cover housing, infrastructure, services, and livelihoods in relocated areas; upfront investments offset by long-term resilience gains.
# - Contingency risks
#   - Political resistance to relocation; social fracture if relocation is perceived as coercive; insufficient housing supply or job opportunities in relocation areas.
#
# Ethical trade-offs between approaches
# - Intergenerational justice: In-place adaptation can defer relocation costs but raises the risk of catastrophic loss for future generations if protections fail; planned retreat spreads the burden more evenly across generations but concentrates costs now.
# - Rights of vulnerable groups: A plan that focuses on in-situ defense may privilege those who own protected assets, at the expense of marginalized groups who bear higher relative risk; a relocation-focused plan must ensure not to coerce or disproportionately disadvantage any group and must guarantee access to services, livelihoods, and cultural continuity.
# - Justice in voice and participation: A relocation strategy that embeds community-led decision-making, consent, and fair compensation can be more ethically robust than a defense-heavy plan that marginalizes communities.
#
# Section 5. Recommendation and justification
# - The single best policy recommendation: Adopt a hybrid “managed retreat with targeted in-situ adaptation” approach.
#   - Why this is robust across scenarios:
#     - It acknowledges that some areas (especially the capital core and critical arable zones) are high-value, high-risk assets best protected in the near term with targeted defenses, while more exposed areas and populations are relocated in a rights-based, predictable, and participatory way.
#     - It aligns with equity and human rights obligations by ensuring protections, housing, and livelihoods for relocated populations and by preserving cultural heritage and citizenship status.
#     - It is flexible to climate and geopolitical uncertainties: if adaptation costs rise or external aid wanes, the plan can lean more toward retreat in later phases; if climate signals permit, protections can be expanded or refined.
#     - It provides a clear governance and financing framework with phased milestones and contingency triggers, reducing the risk of abrupt, destabilizing shifts.
#   - Operationally, this means:
#     - In the near term (Years 0–5): halt escalation of risk in the capital by deploying a mix of nature-based solutions and critical defenses, while launching the relocation program for the most exposed communities and initiating new safe settlements.
#     - Mid-term (Years 6–15): scale relocation, complete a majority of housing and livelihoods in relocated areas, and consolidate economic diversification; continuously upgrade defenses where cost-effective and necessary for core services.
#     - Long-term (Years 16–20): consolidate gains, re-evaluate risk, adapt to new climate projections, and maintain flexible paths for potential returns or further relocation if conditions permit.
#   - Ethical guardrails: insist on a participatory relocation process; ensure universal access to rights and services; maintain diaspora engagement to sustain cultural and political legitimacy; prioritize vulnerable groups in every phase.
#
# Section 6. Implementation-ready plan: 12–24 month action map (highlights)
# - Governance and institutions
#   - Establish NRA, NCCA, and Coastal Resilience Agency; appoint an Independent Rights Ombudsperson.
#   - Create cross-ministerial coordinating committees for housing, livelihoods, heritage, and DRR.
# - Financing and instruments
#   - Set up a National Climate Resilience Fund; issue sovereign green bonds; explore blended finance with development banks.
#   - Formalize a diaspora investment framework; guarantee investment-friendly conditions for relocation housing and green infrastructure.
# - People and communities
#   - Complete risk and vulnerability census; launch relocation beneficiary selection with inclusive, transparent criteria.
#   - Initiate social protection expansions; begin vocational retraining and entrepreneurship support aligned with relocation sites.
# - Housing and settlement
#   - Finalize master plans for 2–3 new safer towns; commence construction of early housing clusters (5,000–8,000 units) and essential services.
#   - Implement land tenure reforms in relocation areas; provide secure housing rights.
# - Economic diversification
#   - Launch pilots in climate-smart agriculture, sustainable seafood processing, and eco-tourism in relocation zones.
#   - Expand renewable energy and grid resilience; advance inter-island logistics links.
# - Environment and heritage
#   - Initiate mangrove restoration and coastal habitat projects; digitize cultural heritage assets; establish protected heritage zones near relocation sites.
# - Monitoring and risk management
#   - Create a climate-risk dashboard with annual independent evaluations; set trigger thresholds for accelerating or adjusting strategy.
#
# Key assumptions and uncertainties (transparent)
# - Assumptions
#   - External climate finance will be available at predictable terms; there is political will to pursue relocation, rights protections, and heritage preservation; land is available for relocation and safe settlements; diaspora capital is accessible.
# - Major uncertainties
#   - Climate trajectory (rate of sea-level rise, extreme events); economic shocks that affect tourism and fisheries; donor fatigue and policy shifts in neighboring states; feasibility and costs of large-scale in-situ defenses.
# - Risks of misestimation
#   - Over- or under-estimating relocation needs could lead to housing shortfalls or misallocated funds; failure to engage communities could undermine legitimacy.
#
# Narrative wrap-up: what success would look like in 20 years
# - People live in secure homes with reliable access to services in relocated areas, while essential government functions and critical services are safeguarded in a protected core.
# - The economy has diversified beyond tourism and small-scale fishing toward climate-resilient industries, with stable livelihoods for relocated populations and new settlements.
# - Legal provisions provide rights and protections for displaced citizens, with clear pathways for naturalization or residency and sustained citizenship assurances to preserve statehood legitimacy.
# - Cultural heritage is preserved through a combination of digitization, preservation of living practices, and heritage tourism that respects communities.
# - Coastal environments are strengthened through nature-based and hybrid infrastructure strategies, with effective early warning and DRR systems.
#
# Closing note
# - The plan emphasizes equity, adaptability, and the long-term viability of the nation-state. It recognizes the moral imperative to safeguard the most vulnerable while maintaining national sovereignty and cultural integrity. The hybrid approach balances the near-term necessity of protecting core assets and services with the long-term resilience gained by orderly relocation, thereby maximizing the odds of a robust, just, and prosperous trajectory under a wide range of climate and geopolitical conditions.
#
# # Response from competitor 2
#
# As Chief Policy Planner for our sovereign island nation, I present this urgent 20-year strategy to navigate the existential threat of sea-level rise. Our nation of 200,000 faces an unprecedented challenge: the annual inundation of our capital and 40% of our arable land within two decades. Our current reliance on tourism and small-scale fishing, combined with a limited national budget (GDP $1.5B, reserves covering ~3 years of spending), hostile neighboring migration policies, and uncertain international aid, demands a bold, proactive, and self-reliant approach.
#
# Our overarching vision is to secure the long-term survival, prosperity, and cultural identity of our people and nation, even as our physical geography transforms. This strategy acknowledges the inevitability of significant physical changes and prioritizes strategic adaptation and relocation over futile resistance.
#
# ---
#
# ### **Overarching Strategy: Proactive Resilience & Managed Transformation**
#
# Our strategy centers on a **Proactive Resilience & Managed Transformation** approach, blending strategic retreat from the most vulnerable areas with targeted adaptation for essential infrastructure and ecological assets, while fundamentally restructuring our economy and legal framework to ensure national continuity.
#
# ---
#
# ### **Detailed 20-Year Strategy Elements**
#
# **Assumptions & Uncertainties:**
# *   **Assumptions:**
#     *   Sufficient suitable higher ground exists within our sovereign territory for a new capital and resettled communities.
#     *   International climate finance mechanisms (e.g., GCF, Adaptation Fund) will provide *some* level of support, though not comprehensive.
#     *   Our citizens, while potentially resistant initially, will ultimately engage constructively in the planning and implementation process.
#     *   Basic international legal principles (e.g., non-refoulement) will continue to hold, even if specific 'climate refugee' status is denied.
# *   **Uncertainties:**
#     *   The precise rate and severity of sea-level rise and associated storm surges.
#     *   The extent and timing of international financial and technical assistance.
#     *   Geopolitical stability and the willingness of international partners to engage in novel legal concepts like "statehood without contiguous territory."
#     *   The social cohesion and psychological impact of mass internal displacement.
#
# ---
#
# #### **(a) Equitable Human Relocation and Housing**
#
# *   **Goal:** Safely and equitably relocate 100% of at-risk populations and infrastructure to secure, sustainable locations within national territory by Year 20, with minimal social disruption.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-3: Assessment & Planning Phase**
#         *   **0-1:** National Vulnerability & Resettlement Suitability Assessment (NVRS): Map all at-risk areas, identify and survey suitable high-ground locations (geology, water, biodiversity, land ownership). Public consultations initiated.
#         *   **1-2:** Develop National Resettlement Master Plan (NRMP): Detailed plans for new urban centers and agricultural zones, infrastructure (roads, utilities, communication), and community facilities. Legal framework for land acquisition/compensation.
#         *   **2-3:** Pilot Relocation Program (1-2 small communities, ~500 people): Test planning assumptions, identify challenges, refine processes.
#     *   **Years 4-15: Implementation & Phased Relocation**
#         *   **4-8:** Infrastructure Development Phase I: Begin construction of essential roads, power grids, water/sanitation, and initial public buildings in designated new capital and key resettlement sites.
#         *   **6-15:** Phased Community Relocation: Systematically relocate populations from most vulnerable areas. Prioritize communities most impacted by annual flooding and critical government functions. Housing construction using resilient, modular, and locally appropriate designs.
#         *   **10-15:** Infrastructure Development Phase II: Expand and consolidate new urban centers, build schools, hospitals, commercial zones.
#     *   **Years 16-20: Consolidation & Final Relocation**
#         *   **16-20:** Finalize relocation of remaining at-risk populations and transfer of all critical government functions to the new capital. Decommission and ecologically restore abandoned sites where feasible.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $800M - $1.2B over 20 years (53-80% of current GDP).
#     *   **Budget Allocation:** 30% of annual national budget for capital projects; remainder from external funding.
#     *   **External Funding Sources:** Green Climate Fund (GCF), Adaptation Fund, World Bank/ADB concessional loans, bilateral aid from climate-resilient partners (e.g., Japan, Netherlands, EU).
# *   **Measurable Success Metrics:**
#     *   95% of identified at-risk population successfully relocated by Year 20.
#     *   80% of relocated households report satisfaction with new housing and community services within 5 years of relocation.
#     *   Construction of new capital and infrastructure on schedule and within 15% of budget.
#     *   No loss of life due to sea-level rise flooding post-Year 15.
# *   **Key Risks & Failure Modes:**
#     *   **Social Resistance:** Reluctance to move, loss of traditional lands/livelihoods, perceived inequity.
#     *   **Land Scarcity/Conflict:** Insufficient suitable land, disputes over land ownership on higher ground.
#     *   **Funding Shortfall:** Inadequate external aid or domestic budget allocation.
#     *   **Infrastructure Failure:** Poor planning or execution of new infrastructure.
#     *   **Psychological Trauma:** Mental health impacts of displacement.
# *   **Contingency Triggers:**
#     *   **Slower SLR:** Allows for extended timelines, re-prioritization to economic development.
#     *   **Faster SLR:** Accelerate relocation timelines, prioritize critical infrastructure transfer, request emergency international aid.
#     *   **Major Funding Shortfall:** Scale back non-essential infrastructure, focus on basic housing, explore innovative financing (e.g., diaspora bonds), potentially seek direct humanitarian aid for housing.
#     *   **Widespread Social Resistance:** Halt forced relocation, launch intensive community engagement campaigns, revise compensation packages, involve anthropologists/sociologists in planning.
#
# ---
#
# #### **(b) Economic Transition and Livelihood Preservation**
#
# *   **Goal:** Diversify the national economy away from vulnerable coastal sectors, create resilient livelihoods for 90% of the working population, and increase GDP per capita by 25% by Year 20.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Foundation & Capacity Building**
#         *   **0-2:** Economic Vulnerability & Opportunity Assessment: Identify sectors resilient to SLR and attractive for investment (e.g., aquaculture in protected areas, deep-sea fishing, renewable energy, specialized agriculture, tech/BPO services, high-value niche tourism on higher ground).
#         *   **1-4:** National Skills Development & Retraining Program: Establish vocational schools and partnerships for training in identified growth sectors. Prioritize displaced fishers and tourism workers.
#         *   **3-5:** Renewable Energy Transition Plan: Phased shift to solar/wind power, reducing reliance on imported fossil fuels. Attract investment in this sector.
#     *   **Years 6-15: Investment & Sector Growth**
#         *   **6-10:** Develop Agri-Tech & Sustainable Aquaculture Zones: Establish new, elevated agricultural zones using climate-smart practices (hydroponics, vertical farms) and inland/protected aquaculture facilities.
#         *   **8-15:** Foster High-Tech & Services Sector: Create dedicated tech parks, incentivize foreign investment in data centers, call centers, and digital services. Develop fiber optic infrastructure.
#         *   **10-15:** Niche Tourism Development: Promote eco-tourism, cultural tourism, and high-value low-impact tourism on higher ground and protected marine areas.
#     *   **Years 16-20: Consolidation & Export Readiness**
#         *   **16-20:** Expand export capabilities for new sectors. Establish Free Trade Zones in new economic hubs. Support small and medium enterprises (SMEs) with business incubation and microfinance.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $500M - $750M over 20 years (33-50% of current GDP).
#     *   **Budget Allocation:** 25% of annual national budget for economic development, education, and subsidies.
#     *   **External Funding Sources:** Multilateral development banks (World Bank, ADB), private sector investment (e.g., for tech, renewable energy), bilateral development aid.
# *   **Measurable Success Metrics:**
#     *   New economic sectors contribute 50% of GDP by Year 20 (up from <5% currently).
#     *   Unemployment rate for relocated populations remains below 10%.
#     *   70% of displaced workers successfully retrained and employed in new sectors.
#     *   Renewable energy sources account for 80% of national energy consumption by Year 20.
# *   **Key Risks & Failure Modes:**
#     *   **Market Failure:** New industries fail to attract investment or find markets.
#     *   **Skill Mismatch:** Training programs do not align with industry needs.
#     *   **Brain Drain:** Educated youth leave the country for better opportunities.
#     *   **Competition:** Inability to compete with larger economies.
# *   **Contingency Triggers:**
#     *   **Economic Downturn:** Implement emergency stimulus packages, prioritize direct cash transfers for displaced workers, double down on attracting foreign direct investment with enhanced incentives.
#     *   **Low uptake in new sectors:** Re-evaluate training programs, offer more attractive startup grants, conduct market research for alternative industries.
#     *   **High Brain Drain:** Implement retention schemes, provide subsidized housing/healthcare for skilled workers, foster a vibrant social and cultural environment.
#
# ---
#
# #### **(c) Legal/Political Status and Rights for Displaced Citizens (Retaining Statehood)**
#
# *   **Goal:** Secure international recognition for our nation's sovereignty and citizenship rights for all citizens, irrespective of physical displacement, by Year 20. Establish legal frameworks for national continuity.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Legal Foundations & Advocacy**
#         *   **0-2:** Establish a Presidential Commission on Statehood Continuity (PCSC): Comprising legal experts, diplomats, and community leaders to research international precedents and develop a legal strategy.
#         *   **1-3:** Constitutional Review & Amendments: Prepare amendments to define national territory and citizenship in a manner resilient to physical changes (e.g., focus on maritime zones, cultural/historical claims, and a "state in trust" concept).
#         *   **2-5:** International Advocacy Campaign Phase I: Engage the UN, AOSIS, specific nations (e.g., Pacific Forum members, powerful allies) on the concept of "statehood without contiguous land" or "deterritorialized sovereignty." Focus on maintaining UN membership and voting rights.
#     *   **Years 6-15: Legal Implementation & Bilateral Treaties**
#         *   **6-10:** Enact domestic legislation safeguarding rights of internally displaced persons (IDPs): Ensuring access to services, property rights, and political participation.
#         *   **8-15:** Pursue Bilateral Agreements: Seek treaties with key nations to recognize our continued statehood and citizenship rights for our people, potentially including agreements for consular services or even temporary residence options in extreme scenarios (without implying mass migration).
#     *   **Years 16-20: Consolidation & Future Proofing**
#         *   **16-20:** Finalize international legal strategy. Establish a "Sovereign Trust Fund" from salvaged national assets and international contributions to secure a permanent home (physical or virtual) for our nation's identity and governance. Explore creation of a "digital nation" platform.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $100M - $200M over 20 years (6.7-13% of current GDP).
#     *   **Budget Allocation:** 5% of annual national budget for legal fees, diplomatic efforts, and international representation.
#     *   **External Funding Sources:** Philanthropic organizations focused on climate justice, specific international legal funds, technical assistance from UN bodies, grants from nations interested in international legal precedents.
# *   **Measurable Success Metrics:**
#     *   Maintenance of UN membership and voting rights.
#     *   Bilateral treaties for statehood recognition with at least 10 key nations by Year 20.
#     *   Domestic legal framework fully in place protecting IDP rights.
#     *   No citizens rendered stateless by Year 20.
#     *   Establishment of a widely recognized "Sovereign Trust Fund" or similar entity.
# *   **Key Risks & Failure Modes:**
#     *   **International Non-recognition:** Major powers refuse to acknowledge deterritorialized sovereignty.
#     *   **Statelessness:** Citizens lose their nationality if the state is deemed to cease to exist.
#     *   **Loss of Voice:** Inability to participate in international forums.
#     *   **Internal Division:** Disagreement on the concept of statehood.
# *   **Contingency Triggers:**
#     *   **Major power refusal of deterritorialized sovereignty:** Focus on achieving regional recognition, bolster economic ties to leverage influence, explore "associated state" models with a larger nation, intensify advocacy for 'cultural sovereignty'.
#     *   **Loss of UN seat:** Redouble efforts for observer status, focus on gaining recognition through bilateral agreements, shift focus to a "diaspora nation" model.
#     *   **Citizenship challenges abroad:** Launch global legal aid funds for citizens, engage international human rights organizations.
#
# ---
#
# #### **(d) Cultural Heritage Preservation**
#
# *   **Goal:** Preserve 100% of tangible and intangible cultural heritage identified as at-risk due to SLR by Year 15, and integrate it into the national identity in new settlements.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Documentation & Digitalization**
#         *   **0-3:** Comprehensive Cultural Heritage Inventory: Map all significant cultural sites, historical buildings, archaeological areas, and intangible heritage (oral histories, traditional practices, languages). Prioritize most vulnerable sites.
#         *   **1-5:** Digital Archiving Project: High-resolution scanning, photogrammetry, 3D modeling of at-risk tangible heritage. Extensive oral history recording, video documentation of rituals, dances, and traditional skills. Establish a secure national digital archive.
#     *   **Years 6-15: Physical Preservation & Integration**
#         *   **6-10:** Strategic Relocation & Preservation: Carefully relocate or reconstruct iconic cultural artifacts and smaller, portable structures to new cultural centers in the elevated capital. Establish climate-controlled national museum in the new capital.
#         *   **8-15:** Community Cultural Centers: Build dedicated cultural centers in each new settlement to foster traditional arts, language, and storytelling. Integrate heritage narratives into new urban planning.
#     *   **Years 16-20: Legacy & Global Outreach**
#         *   **16-20:** Curriculum Integration: Ensure cultural heritage is a core part of the national education curriculum.
#         *   **18-20:** International Collaboration: Partner with UNESCO and other international cultural institutions to safeguard digital archives and promote global awareness of our disappearing heritage.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $75M - $125M over 20 years (5-8% of current GDP).
#     *   **Budget Allocation:** 3% of annual national budget for cultural preservation.
#     *   **External Funding Sources:** UNESCO, World Monuments Fund, Getty Foundation, bilateral aid from culturally sensitive nations, philanthropic organizations.
# *   **Measurable Success Metrics:**
#     *   100% of at-risk tangible heritage digitally archived by Year 5.
#     *   80% of identified intangible heritage documented and archived by Year 10.
#     *   At least 5 major cultural artifacts or structures successfully relocated/reconstructed.
#     *   Establishment of 5+ vibrant community cultural centers in new settlements.
#     *   National language proficiency maintained or increased among youth by Year 20.
# *   **Key Risks & Failure Modes:**
#     *   **Loss Before Preservation:** Rapid SLR or sudden events destroy sites before documentation.
#     *   **Technological Obsolescence:** Digital formats become unreadable.
#     *   **Loss of Context:** Heritage loses meaning when removed from original environment.
#     *   **Lack of Community Engagement:** Heritage preservation efforts fail to resonate locally.
# *   **Contingency Triggers:**
#     *   **Accelerated SLR affecting heritage sites:** Prioritize emergency salvage and rapid digitalization; partner with marine archaeologists for underwater sites.
#     *   **Low community engagement:** Revamp engagement strategies, offer community-led heritage initiatives, provide direct funding for local cultural groups.
#     *   **Funding shortfall:** Focus solely on digital archiving, rely on volunteer efforts, seek smaller grants for specific projects.
#
# ---
#
# #### **(e) Environmental Mitigation/Adaptation**
#
# *   **Goal:** Implement strategic environmental adaptations to protect critical non-relocatable assets, enhance ecological resilience, and secure vital ecosystem services for the remaining land by Year 10.
# *   **Concrete Steps & Timelines:**
#     *   **Years 0-5: Strategic Protection & Ecosystem Restoration**
#         *   **0-2:** Critical Infrastructure Protection Plan: Identify essential, non-relocatable infrastructure (e.g., main port, airport – requiring significant investment for relocation) and develop targeted, high-cost coastal defense plans (sea walls, dykes). *Note: This is highly selective, not a general defense strategy.*
#         *   **1-5:** Large-Scale Mangrove & Coral Reef Restoration Program: Prioritize natural coastal defenses. Restore degraded mangrove forests and coral reefs for their protective and biodiversity benefits.
#         *   **3-5:** National Water Security Plan: Implement rainwater harvesting, groundwater management, and strategic desalination plants in new settlements.
#     *   **Years 6-15: Sustainable Resource Management**
#         *   **6-10:** Sustainable Land Use Planning: Implement strict zoning for remaining high ground, protecting critical ecosystems and water sources. Promote permaculture and agroforestry.
#         *   **8-15:** Waste Management & Circular Economy: Develop modern waste management facilities (waste-to-energy where feasible) and promote circular economy principles.
#     *   **Years 16-20: Monitoring & Advanced Adaptation**
#         *   **16-20:** Climate Monitoring & Early Warning Systems: Install advanced sensors for sea-level, weather, and ocean conditions. Develop robust early warning systems for storms and coastal inundation.
#         *   **18-20:** Research & Development: Invest in local R&D for climate-resilient crops, aquaculture techniques, and renewable energy innovations.
# *   **Rough Cost Estimates / Budget Allocation:**
#     *   **Total:** Estimated $300M - $500M over 20 years (20-33% of current GDP).
#     *   **Budget Allocation:** 15% of annual national budget for environmental projects and infrastructure.
#     *   **External Funding Sources:** Global Environment Facility (GEF), Adaptation Fund, UN Environment Programme, bilateral aid for specific climate projects, conservation NGOs.
# *   **Measurable Success Metrics:**
#     *   50% increase in mangrove coverage and 20% increase in live coral cover by Year 10.
#     *   Access to potable water for 95% of the population in new settlements.
#     *   Reduced damage to critical port/airport infrastructure by 70% post-Year 15.
#     *   Effective waste management system implemented in all major settlements.
#     *   Early warning systems successfully alert 90% of population before extreme weather events.
# *   **Key Risks & Failure Modes:**
#     *   **Overwhelmed Defenses:** Sea walls/dykes fail against extreme events or accelerated SLR.
#     *   **Ecosystem Collapse:** Restoration efforts fail due to continued climate stress or pollution.
#     *   **Water Scarcity:** Insufficient freshwater sources for growing populations.
#     *   **Resource Depletion:** Over-extraction of fish or other natural resources.
# *   **Contingency Triggers:**
#     *   **Faster ecosystem degradation:** Increase investment in restoration, explore more aggressive conservation measures (e.g., marine protected areas), seek emergency ecological funding.
#     *   **Failure of hard defenses:** Re-evaluate and potentially decommission assets, accelerate relocation from those areas, focus solely on natural defenses.
#     *   **Water shortages:** Implement stricter water rationing, invest in additional desalination capacity, explore inter-island water transfer (if feasible).
#
# ---
#
# ### **Comparison of Alternative High-Level Approaches**
#
# #### **1. Approach Centered on In-Place Adaptation (Status Quo++):**
#
# *   **Focus:** Intensive protection of existing coastal areas, infrastructure, and agricultural lands through large-scale engineering.
# *   **Key Strategies:** Massive sea walls, dikes, polders, land reclamation, elevating existing buildings and infrastructure, extensive pumping systems, salt-tolerant crops.
# *   **Ethical Trade-offs:**
#     *   **Intergenerational Justice:** This approach prioritizes the *immediate* preservation of existing communities and assets for the current generation. However, it likely burdens future generations with a perpetually escalating maintenance cost, a constant battle against rising seas, and the risk of catastrophic failure (e.g., a dike breaking). It defers the inevitable decision, potentially leaving future generations with fewer resources and options.
#     *   **Rights of Vulnerable Groups:** While appearing to keep communities together, this approach could disproportionately affect the poor. Expensive adaptations like elevating homes or building private defenses are beyond the reach of many. Those unable to adapt might be marginalized or forced to leave anyway, creating an "adaptation apartheid." Furthermore, the engineering solutions often destroy natural habitats that vulnerable groups rely on for livelihoods (e.g., fishing grounds, mangrove forests).
# *   **Viability for our Nation:** Given "annual flooding of capital and 40% of arable land in 20 years," this approach is **untenable and represents maladaptation.** The scale of engineering required for continuous protection against annual flooding of such a large and vital area would be astronomically expensive, likely beyond our GDP, and unsustainable in the long term. It would merely delay the inevitable and potentially lead to a more abrupt, catastrophic failure later.
#
# #### **2. Approach Centered on Planned Retreat/Relocation (Managed Transformation):**
#
# *   **Focus:** Proactive and strategic movement of populations, infrastructure, and economic activities to safer, higher ground within national territory.
# *   **Key Strategies:** Comprehensive national resettlement plans, development of new urban centers and agricultural zones, economic diversification towards resilient sectors, legal frameworks for statehood continuity.
# *   **Ethical Trade-offs:**
#     *   **Intergenerational Justice:** This approach demands significant sacrifices from the *current* generation (dislocation, disruption of livelihoods, loss of ancestral lands) but aims to secure a viable, sustainable future for *future* generations. It is a long-term investment in national survival, reducing future vulnerability and the burden of constant climate defense. It enables a proactive response, minimizing future crisis-driven migration.
#     *   **Rights of Vulnerable Groups:** The risks here are significant if not managed equitably. Forced relocation can be traumatic, leading to loss of social networks, identity, and livelihoods. It risks dispossessing landholders on higher ground or creating new inequalities if relocation benefits are not distributed fairly. However, with careful planning, robust compensation frameworks, community participation, and dedicated support services, it offers the opportunity to build *more resilient and equitable* communities with improved infrastructure and access to services, potentially uplifting marginalized groups in the long run. The strategy above specifically addresses these risks through equitable planning and social support.
# *   **Viability for our Nation:** This approach is **the only viable long-term solution** for our nation given the specific threats outlined. While challenging, it directly confronts the physical reality of impending inundation and offers a pathway to national continuity.
#
# ---
#
# ### **Single Best Policy Recommendation and Robustness**
#
# My single best policy recommendation is the **Proactive Resilience & Managed Transformation** strategy, fundamentally centered on **Planned Retreat/Relocation** as the overarching principle, complemented by strategic, targeted environmental adaptation.
#
# **Why it is Robust Across Optimistic and Pessimistic Climate and Geopolitical Scenarios:**
#
# 1.  **Directly Addresses the Core Physical Threat:** The "annual flooding of capital and 40% of arable land" makes pure in-place adaptation a fantasy. Planned retreat is the only strategy that acknowledges this reality and offers a sustainable physical future for our people within our borders.
# 2.  **Adaptive Capacity:**
#     *   **Optimistic Climate Scenario (Slower SLR):** If SLR is slower than predicted, the planned retreat provides a longer transition period, allowing for more careful planning, better infrastructure development, and smoother social adjustment. Resources initially allocated for rapid relocation can be redirected to further economic diversification, enhanced social services in new settlements, and more robust long-term infrastructure. The national budget gains breathing room.
#     *   **Pessimistic Climate Scenario (Faster SLR/Extreme Events):** If SLR accelerates or extreme weather events become more frequent, the framework for planned retreat is already established. Early investments in vulnerability assessments, legal frameworks, and initial infrastructure mean the nation is better prepared to accelerate relocation, declare emergencies, and quickly access international humanitarian aid. It shifts from reactive crisis management to a proactive, albeit faster, implementation of an existing plan.
# 3.  **Economic Resilience:** By diversifying our economy away from vulnerable coastal sectors and investing in new, resilient industries (aquaculture, tech, renewables), we build an economy less susceptible to climate impacts. This protects livelihoods and secures financial stability, regardless of the precise climate trajectory. This also makes us less dependent on a single industry (tourism) which is itself vulnerable to global shocks (pandemics, economic crises) as well as climate change.
# 4.  **Geopolitical Independence:** The strategy prioritizes internal solutions for relocation and livelihood, reducing reliance on neighboring states for mass migration (which they have refused). Our proactive legal strategy for "statehood continuity" aims to secure our sovereignty and international standing, offering a dignified future even if our physical land mass shrinks considerably.
#     *   **Optimistic Geopolitical Scenario (Increased Aid/Recognition):** Strong international support (financial, technical, legal) accelerates the implementation of our strategy, allowing for higher quality housing, faster economic transition, and smoother international legal recognition of our statehood.
#     *   **Pessimistic Geopolitical Scenario (Limited Aid/Non-recognition):** While challenging, the strategy's emphasis on self-reliance (internal relocation, domestic economic diversification, constitutional amendments) means our nation is not solely dependent on external goodwill. We build foundational resilience. The international advocacy campaign continues, but our survival is not predicated on immediate external approval for novel legal concepts. We prepare for a scenario where we manage our destiny primarily through our own means.
# 5.  **Ethical Responsibility:** While demanding immediate sacrifices, planned retreat is ethically superior for intergenerational justice. It ensures a future for our nation and people, rather than condemning successive generations to a losing battle. The strategy includes explicit measures for equitable relocation and cultural preservation, aiming to mitigate the trauma of displacement and build a new, resilient national identity.
#
# In conclusion, "Proactive Resilience & Managed Transformation" through a managed, equitable planned retreat is not merely an option; it is an imperative. It represents the most robust and ethically sound path forward to secure the future of our sovereign island nation in the face of an undeniable climate crisis.
#
# # Response from competitor 3
#
# I. Equitable Human Relocation and Housing (5 years, $100M, 7% of national budget)
#
# 1. Conduct inclusive, national-level public consultations (Year 1, $5M) to gather information on existing relocation plans and social, economic, and cultural impacts.
# 2. Establish a National ReLocation Committee (Year 2, $3M) to coordinate a systematic relocation strategy with international guidance on fair distribution, compensation, and social services.
# 3. Construct transitional housing (Year 1-2, $50M) near former flood zones with a mix of affordable and accessible options.
# 4. Implement a fair compensation system (Year 3-5, $30M) that considers the needs and interests of 70% of displaced citizens.
#
# Measurable success metrics: public acceptance rate > 70%, relocation rate > 50% of high-risk area populations.
#
# Key risks and failure modes: public mistrust, insufficient funding, lack of social services.
#
# Contingency triggers: negative consultations outcomes, failure of national consultation engagement.
#
# Assumptions and uncertainties: 10% change in population distribution
#
# II. Economic Transition and Livelihood Preservation (5 years, $500M, 33% of national budget)
#
# 1. Develop and implement a 4-year education and vocational training program (Year 2-5, $100M) for 300,000 small-scale fishermen and 100,000 tourism-related workers.
# 2. Revitalize non-coastal industries through incentives (Year 2-5, $50M) to promote innovation, job creation, and fair labor practices.
# 3. Establish a National Livelihood Fund (Year 1, $50M) to guarantee basic income levels for 60% of citizens.
#
# Measurable success metrics: successful traineeship rate > 50%, increase in coastal non-fishing sector by 15%.
#
# Key risks and failure modes: economic volatility, loss of expertise.
#
# Contingency triggers: government policy shift towards rapid relocation or significant economic fluctuations.
#
# Assumptions and uncertainties: 5% change in GDP growth rate
#
# III. Legal/Political Status and Rights for Displaced Citizens (5 years, $200M, 13% of national budget)
#
# 1. Establish a National Commission for the Rights of Relocation (Year 1, $30M) based on guidelines from international human rights and environmental law.
# 2. Negotiate international cooperation agreements (Year 2, $100M) on displacement impacts on citizenship rights.
#
# Measurable success metrics: acceptance of national human rights protection norms > 80%.
#
# Key risks and failure modes: failure to engage with relevant international governing entities.
#
# Contingency triggers: international refusal to engage, public discontent with human rights standards.
#
# Assumptions and uncertainties: 10% decline in trust of local institutions
#
# IV. Environmental Mitigation/Adaptation (5 years, $500M, 33% of national budget)
#
# 1. Construct coastal barrier system (Year 2-5, $250M) using the most favorable design options.
# 2. Conduct research on sustainable coastal land management (Year 1-2, $50M) and initiate pilot projects for innovative techniques.
#
# Measurable success metrics: 20% increase in projected water depth protection.
#
# Key risks and failure modes: technical complexity issues, public resistance.
#
# Contingency triggers: public discontent, funding shortfalls due to budget constraints.
#
# Assumptions and uncertainties: 10% change in sea-level rise predicted.
#
# V. Environmental Mitigation/Adaptation Alternative (Planned Retreat/Relocation): focus on relocating 90% of population to upperlands before projected flooding and maintaining 10% population in the capital area, prioritizing security, climate and ecological resilience, and human well-being over economic and cultural heritage preservation.
#
# Key benefits: secure future for remaining population, preservation of cultural heritage and biodiversity.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2", "3"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gpt-5-nano
# Rank 2: gemini-2.5-flash
# Rank 3: llama3.2

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
